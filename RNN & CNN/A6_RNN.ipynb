# %%
# !pip3 install wget
import wget
wget.download("https://s3.amazonaws.com/chrisjermainebucket/text/war.txt")
# Out:
# Requirement already satisfied: wget in /Users/mikey/miniforge3/envs/enc_tensorflow/lib/python3.9/site-packages (3.2)
# 100% [......................................................] 3288707 / 3288707
# 'war (1).txt'

# %%
wget.download("https://s3.amazonaws.com/chrisjermainebucket/text/william.txt")
wget.download("https://s3.amazonaws.com/chrisjermainebucket/text/Holmes.txt")
# Out:
# 100% [........................................................] 594933 / 594933
# 'Holmes (1).txt'

# %%
import numpy as np
import tensorflow.compat.v1 as tf
import random
tf.disable_v2_behavior()

# the number of iterations to train for
numTrainingIters = 10000

# the number of hidden neurons that hold the state of the RNN
hiddenUnits = 500

# the number of classes that we are learning over
numClasses = 3

# the number of data points in a batch
batchSize = 100

# size of the sliding window
windowSize = 10

numOfChannels = 8

dataID_trained = set()

# %%
# this function takes a dictionary (called data) which contains 
# of (dataPointID, (classNumber, matrix)) entries.  Each matrix
# is a sequence of vectors; each vector has a one-hot-encoding of
# an ascii character, and the sequence of vectors corresponds to
# one line of text.  classNumber indicates which file the line of
# text came from.  
# 
# The argument maxSeqLen is the maximum length of a line of text
# seen so far.  fileName is the name of a file whose contents
# we want to add to data.  classNum is an indicator of the class
# we are going to associate with text from that file.  linesToUse
# tells us how many lines to sample from the file.
#
# The return val is the new maxSeqLen, as well as the new data
# dictionary with the additional lines of text added
def addToData (maxSeqLen, data, fileName, classNum, linesToUse):
    #
    # open the file and read it in
    with open(fileName) as f:
        content = f.readlines()
    #
    # sample linesToUse numbers; these will tell us what lines
    # from the text file we will use
    myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
    #
    # i is the key of the next line of text to add to the dictionary
    # i:0 --> i:linesToUse
    i = len(data)
    #
    # loop thru and add the lines of text to the dictionary
    for whichLine in myInts.flat:
        #
        # get the line and ignore it if it has nothing in it
        line = content[whichLine]
        if line.isspace () or len(line) == 0:
            continue;
        #
        # take note if this is the longest line we've seen
        if len (line) > maxSeqLen:
            maxSeqLen = len (line)
        #
        # create the matrix that will hold this line
        temp = np.zeros((len(line), 256))
        #
        # j is the character we are on
        j = 0
        # 
        # loop thru the characters
        for ch in line:
            #
            # non-ascii? ignore
            if ord(ch) >= 256:
                continue
            #
            # one hot!
            temp[j][ord(ch)] = 1
            # 
            # move onto the next character
            j = j + 1
            #
        # remember the line of text
        data[i] = (classNum, temp)
        #
        # move onto the next line
        i = i + 1
    #
    # and return the dictionary with the new data
    return (maxSeqLen, data)

# %%
# this function takes as input a data set encoded as a dictionary
# (same encoding as the last function) and pre-pends every line of
# text with empty characters so that each line of text is exactly
# maxSeqLen characters in size
def pad (maxSeqLen, data):
   #
   # loop thru every line of text
   for i in data:
        #
        # access the matrix and the label
        temp = data[i][1]       # data[i][1] is a len(line) * 256 matrix
        label = data[i][0]
        # 
        # get the number of chatacters in this line
        len = temp.shape[0]
        #
        # and then pad so the line is the correct length
        padding = np.zeros ((maxSeqLen - len, 256)) 
        data[i] = (label, np.transpose (np.concatenate ((padding, temp), axis = 0)))
   #
   # return the new data set
   return data

# %%
# this generates a new batch of training data of size batchSize from the
# list of lines of text data. This version of generateData is useful for
# an RNN because the data set x is a NumPy array with dimensions
# [batchSize, 256, maxSeqLen]; it can be unstacked into a series of
# matrices containing one-hot character encodings for each data point
# using tf.unstack(inputX, axis=2)
def generateDataRNN (maxSeqLen, data):

    #
    # randomly sample batchSize lines of text
    keys = list(data.keys())
    # myInts = np.random.random_integers(0, len(data) - 1, batchSize)          # an array of length batchSize
    myInts = np.random.choice(keys, batchSize)

    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack (data[i][1] for i in myInts.flat)
    # print(x)
    #
    # and stack all of the labels into a vector of labels
    y = np.stack (np.array((data[i][0])) for i in myInts.flat)
    # print(y)
    
    #
    # return the pair
    return (x, y)

# %%
# this also generates a new batch of training data, but it represents
# the data as a NumPy array with dimensions [batchSize, 256 * maxSeqLen]
# where for each data point, all characters have been appended.  Useful
# for feed-forward network training
def generateDataFeedForward (maxSeqLen, data):
    #
    # randomly sample batchSize lines of text
    keys = list(data.keys())
    # myInts = np.random.random_integers(0, len(data) - 1, batchSize)
    myInts = np.random.choice(keys, batchSize)
    
    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack(data[i][1].flatten() for i in myInts.flat)
    #
    # and stack all of the labels into a vector of labels
    y = np.stack(np.array((data[i][0])) for i in myInts.flat)
    #
    # return the pair
    return (x, y)

# %% [markdown]
# ## Task 2: Adding “Time Warping” to the RNN

# %%
# create the data dictionary

maxSeqLen = 0
data = {}

# load up the three data sets
(maxSeqLen, data) = addToData (maxSeqLen, data, "Holmes.txt", 0, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "war.txt", 1, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "william.txt", 2, 10000)

# pad each entry in the dictionary with empty characters as needed so
# that the sequences are all of the same length
# 裏面transpose變成 256 * maxSeqLen 的shape
data = pad (maxSeqLen, data)
allDataID = [i for i in range(len(data))]
# print(len(data))    25041
testDataID = random.sample(allDataID[0:7000], 1000) + random.sample(allDataID[10000:18000], 1000) + random.sample(allDataID[19500:], 1000)
trainDataID = list(set(allDataID) - set(testDataID))
data_train = dict()
data_test = dict()
for train_id in trainDataID:
    data_train[train_id] = data[train_id]
for test_id in testDataID:
    data_test[test_id] = data[test_id]

        
# now we build the TensorFlow computation... there are two inputs, 
# a batch of text lines and a batch of labels
inputX = tf.placeholder(tf.float32, [batchSize, 256, maxSeqLen])
inputY = tf.placeholder(tf.int32, [batchSize])

# this is the inital state of the RNN, before processing any data
initialState = tf.placeholder(tf.float32, [batchSize, hiddenUnits])

# the weight matrix that maps the inputs and hidden state to a set of values
# W is modified to include the hidden state at t-10 -> so 256 + hiddenUnits + hiddenUnits
W = tf.Variable(np.random.normal(0, 0.05, (256 + hiddenUnits + hiddenUnits, hiddenUnits)), dtype=tf.float32)

# biaes for the hidden values
b = tf.Variable(np.zeros((1, hiddenUnits)), dtype=tf.float32)

# weights and bias for the final classification
W2 = tf.Variable(np.random.normal (0, 0.05, (hiddenUnits, numClasses)),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,numClasses)), dtype=tf.float32)

# unpack the input sequences so that we have a series of matrices,
# each of which has a one-hot encoding of the current character from
# every input sequence
sequenceOfLetters = tf.unstack(inputX, axis=2)

# now we implement the forward pass
currentState = initialState
timeWarpStates = [initialState] * 10
for idx,timeTick in enumerate(sequenceOfLetters):
    # concatenate the state with the input, then compute the next state
    # Add time warpping -> append the state at t-10 as input
    inputPlusState = tf.concat([timeTick, currentState, timeWarpStates[idx%10]], 1)     # shape: batchsize * (256 + hiddenUnits + hiddenUnits)
    next_state = tf.tanh(tf.matmul(inputPlusState, W) + b)      # W shape: (256 + hiddenUnits + hiddenUnits) * hiddenUnits
    currentState = next_state
    timeWarpStates[idx%10] = next_state    # Update the previous 10 states for future time warp


# compute the set of outputs
outputs = tf.matmul(currentState, W2) + b2

predictions = tf.nn.softmax(outputs)

# compute the loss
losses = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=outputs, labels=inputY)
totalLoss = tf.reduce_mean(losses)  # take mean of losses

# use gradient descent to train
#trainingAlg = tf.train.GradientDescentOptimizer(0.02).minimize(totalLoss)
trainingAlg = tf.train.AdagradOptimizer(0.02).minimize(totalLoss)

# and train!!
with tf.Session() as sess:
    #
    # initialize everything
    sess.run(tf.global_variables_initializer())
    #
    # and run the training iters
    # _finalState = np.zeros((batchSize, hiddenUnits))
    for epoch in range(10000):
        # 
        # get some data
        x, y = generateDataRNN(maxSeqLen, data_train)

        #
        # do the training epoch
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _trainingAlg, _currentState, _predictions, _outputs = sess.run(
                [totalLoss, trainingAlg, currentState, predictions, outputs],
                feed_dict={
                    inputX:x,
                    inputY:y,
                    initialState:_currentState
                })

        #
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y)):
           maxPos = -1
           maxVal = 0.0
           for j in range (numClasses):
               if maxVal < _predictions[i][j]:
                   maxVal = _predictions[i][j]
                   maxPos = j
           if maxPos == y[i]:
               numCorrect = numCorrect + 1
        #
        # print out to the screen
        print("Step", epoch, "Loss", _totalLoss, "Correct", numCorrect, "out of", batchSize)


    
    # Testing
    _avgTestLoss = 0
    totalNumCorrect = 0
    x_test, y_test = generateDataRNN(maxSeqLen, data_test)
    _currentState = np.zeros((batchSize, hiddenUnits))
    for i in range(30):
        _testLoss, _testPredictions = sess.run([totalLoss, predictions], feed_dict = {
                            inputX:x_test,
                            inputY:y_test,
                            initialState:_currentState
                            })
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y_test)):
            maxPos = -1
            maxVal = 0.0
            for j in range (numClasses):
                if maxVal < _testPredictions[i][j]:
                    maxVal = _testPredictions[i][j]
                    maxPos = j
            if maxPos == y_test[i]:
                numCorrect = numCorrect + 1
        totalNumCorrect += numCorrect
        _avgTestLoss += _testLoss
        
    _avgTestLoss /= 30
    print("Loss for 3000 randomly chosen documents is ", _avgTestLoss, " number of correct labels is ", totalNumCorrect, " out of 3000")
# Out:
# /var/folders/76/0jylnbrx4p7_yl5fmv0d39yr0000gn/T/ipykernel_79440/2724516542.py:24: DeprecationWarning: This function is deprecated. Please call randint(0, 13051 + 1) instead
#   myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
# /var/folders/76/0jylnbrx4p7_yl5fmv0d39yr0000gn/T/ipykernel_79440/2724516542.py:24: DeprecationWarning: This function is deprecated. Please call randint(0, 65334 + 1) instead
#   myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
# /var/folders/76/0jylnbrx4p7_yl5fmv0d39yr0000gn/T/ipykernel_79440/2724516542.py:24: DeprecationWarning: This function is deprecated. Please call randint(0, 124795 + 1) instead
#   myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
# 2021-12-05 12:14:43.392784: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-12-05 12:14:43.392840: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-12-05 12:14:43.695296: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-12-05 12:14:43.915980: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Step 0 Loss 1.2628633 Correct 30 out of 100
# Step 1 Loss 1.6495037 Correct 29 out of 100
# Step 2 Loss 1.4240527 Correct 26 out of 100
# Step 3 Loss 1.9104358 Correct 35 out of 100
# Step 4 Loss 3.0538805 Correct 32 out of 100
# Step 5 Loss 5.4023643 Correct 36 out of 100
# Step 6 Loss 1.896705 Correct 29 out of 100
# Step 7 Loss 1.3688481 Correct 36 out of 100
# Step 8 Loss 2.712275 Correct 26 out of 100
# Step 9 Loss 3.1859426 Correct 34 out of 100
# Step 10 Loss 2.9094408 Correct 42 out of 100
# Step 11 Loss 1.5881045 Correct 36 out of 100
# Step 12 Loss 2.4083629 Correct 33 out of 100
# Step 13 Loss 3.7269158 Correct 38 out of 100
# Step 14 Loss 2.9805605 Correct 21 out of 100
# Step 15 Loss 1.6653514 Correct 32 out of 100
# Step 16 Loss 2.877238 Correct 29 out of 100
# Step 17 Loss 3.437582 Correct 26 out of 100
# Step 18 Loss 1.3295876 Correct 39 out of 100
# Step 19 Loss 2.2800493 Correct 38 out of 100
# Step 20 Loss 1.2402952 Correct 32 out of 100
# Step 21 Loss 1.8895581 Correct 41 out of 100
# Step 22 Loss 1.2401823 Correct 24 out of 100
# Step 23 Loss 1.8945924 Correct 35 out of 100
# Step 24 Loss 1.2816556 Correct 32 out of 100
# Step 25 Loss 1.220652 Correct 28 out of 100
# Step 26 Loss 1.4589697 Correct 33 out of 100
# Step 27 Loss 1.3002414 Correct 30 out of 100
# Step 28 Loss 1.3183602 Correct 33 out of 100
# Step 29 Loss 1.9286472 Correct 36 out of 100
# Step 30 Loss 2.0515943 Correct 29 out of 100
# Step 31 Loss 1.5415502 Correct 33 out of 100
# Step 32 Loss 1.8605862 Correct 25 out of 100
# Step 33 Loss 2.1830938 Correct 25 out of 100
# Step 34 Loss 1.2201148 Correct 34 out of 100
# Step 35 Loss 1.4084835 Correct 34 out of 100
# Step 36 Loss 1.2740148 Correct 35 out of 100
# Step 37 Loss 1.7779088 Correct 27 out of 100
# Step 38 Loss 1.2745442 Correct 37 out of 100
# Step 39 Loss 1.1604286 Correct 32 out of 100
# Step 40 Loss 1.252018 Correct 32 out of 100
# Step 41 Loss 1.615095 Correct 33 out of 100
# Step 42 Loss 1.2981575 Correct 30 out of 100
# Step 43 Loss 1.2066075 Correct 31 out of 100
# Step 44 Loss 1.2249699 Correct 26 out of 100
# Step 45 Loss 1.1930878 Correct 40 out of 100
# Step 46 Loss 1.1111746 Correct 34 out of 100
# Step 47 Loss 1.1772546 Correct 36 out of 100
# Step 48 Loss 1.2011778 Correct 37 out of 100
# Step 49 Loss 1.1551609 Correct 42 out of 100
# Step 50 Loss 1.136128 Correct 34 out of 100
# Step 51 Loss 1.1450815 Correct 36 out of 100
# Step 52 Loss 1.1341935 Correct 36 out of 100
# Step 53 Loss 1.1249214 Correct 35 out of 100
# Step 54 Loss 1.0873762 Correct 43 out of 100
# Step 55 Loss 1.1483579 Correct 27 out of 100
# Step 56 Loss 1.1922593 Correct 26 out of 100
# Step 57 Loss 1.2523081 Correct 23 out of 100
# Step 58 Loss 1.174405 Correct 35 out of 100
# Step 59 Loss 1.0963019 Correct 42 out of 100
# Step 60 Loss 1.1039196 Correct 32 out of 100
# Step 61 Loss 1.1100633 Correct 38 out of 100
# Step 62 Loss 1.0779026 Correct 40 out of 100
# Step 63 Loss 1.0884802 Correct 40 out of 100
# Step 64 Loss 1.0953541 Correct 32 out of 100
# Step 65 Loss 1.0968602 Correct 38 out of 100
# Step 66 Loss 1.0935652 Correct 39 out of 100
# Step 67 Loss 1.1167461 Correct 36 out of 100
# Step 68 Loss 1.1057262 Correct 33 out of 100
# Step 69 Loss 1.1022449 Correct 34 out of 100
# Step 70 Loss 1.0920717 Correct 44 out of 100
# Step 71 Loss 1.1155787 Correct 34 out of 100
# Step 72 Loss 1.120682 Correct 42 out of 100
# Step 73 Loss 1.1146092 Correct 34 out of 100
# Step 74 Loss 1.0891356 Correct 40 out of 100
# Step 75 Loss 1.1128415 Correct 32 out of 100
# Step 76 Loss 1.1842192 Correct 30 out of 100
# Step 77 Loss 1.2609373 Correct 36 out of 100
# Step 78 Loss 1.1803671 Correct 33 out of 100
# Step 79 Loss 1.1414222 Correct 28 out of 100
# Step 80 Loss 1.1005436 Correct 42 out of 100
# Step 81 Loss 1.1132755 Correct 34 out of 100
# Step 82 Loss 1.103797 Correct 37 out of 100
# Step 83 Loss 1.1070191 Correct 36 out of 100
# Step 84 Loss 1.0948094 Correct 39 out of 100
# Step 85 Loss 1.1898342 Correct 28 out of 100
# Step 86 Loss 1.2378014 Correct 28 out of 100
# Step 87 Loss 1.2443117 Correct 38 out of 100
# Step 88 Loss 1.1685785 Correct 37 out of 100
# Step 89 Loss 1.0722067 Correct 43 out of 100
# Step 90 Loss 1.1280599 Correct 34 out of 100
# Step 91 Loss 1.1176319 Correct 30 out of 100
# Step 92 Loss 1.1569881 Correct 33 out of 100
# Step 93 Loss 1.1639873 Correct 34 out of 100
# Step 94 Loss 1.1165721 Correct 39 out of 100
# Step 95 Loss 1.1023281 Correct 37 out of 100
# Step 96 Loss 1.0992271 Correct 37 out of 100
# Step 97 Loss 1.2317232 Correct 27 out of 100
# Step 98 Loss 1.1627148 Correct 34 out of 100
# Step 99 Loss 1.0910696 Correct 38 out of 100
# Step 100 Loss 1.1019025 Correct 30 out of 100
# Step 101 Loss 1.1337059 Correct 34 out of 100
# Step 102 Loss 1.1279082 Correct 32 out of 100
# Step 103 Loss 1.0989931 Correct 37 out of 100
# Step 104 Loss 1.1002591 Correct 34 out of 100
# Step 105 Loss 1.0961819 Correct 38 out of 100
# Step 106 Loss 1.1598332 Correct 32 out of 100
# Step 107 Loss 1.1623086 Correct 25 out of 100
# Step 108 Loss 1.1370912 Correct 44 out of 100
# Step 109 Loss 1.1216635 Correct 39 out of 100
# Step 110 Loss 1.1347953 Correct 33 out of 100
# Step 111 Loss 1.1002878 Correct 34 out of 100
# Step 112 Loss 1.0971173 Correct 36 out of 100
# Step 113 Loss 1.0848693 Correct 35 out of 100
# Step 114 Loss 1.1573849 Correct 37 out of 100
# Step 115 Loss 1.1941376 Correct 23 out of 100
# Step 116 Loss 1.14745 Correct 47 out of 100
# Step 117 Loss 1.0987537 Correct 33 out of 100
# Step 118 Loss 1.1181717 Correct 33 out of 100
# Step 119 Loss 1.0950115 Correct 35 out of 100
# Step 120 Loss 1.1000367 Correct 36 out of 100
# Step 121 Loss 1.1018803 Correct 36 out of 100
# Step 122 Loss 1.1119466 Correct 37 out of 100
# Step 123 Loss 1.1977067 Correct 23 out of 100
# Step 124 Loss 1.1896558 Correct 40 out of 100
# Step 125 Loss 1.1323279 Correct 32 out of 100
# Step 126 Loss 1.1043518 Correct 39 out of 100
# Step 127 Loss 1.1197973 Correct 26 out of 100
# Step 128 Loss 1.1395837 Correct 34 out of 100
# Step 129 Loss 1.13207 Correct 34 out of 100
# Step 130 Loss 1.0863374 Correct 42 out of 100
# Step 131 Loss 1.1029072 Correct 37 out of 100
# Step 132 Loss 1.0982393 Correct 38 out of 100
# Step 133 Loss 1.1029259 Correct 34 out of 100
# Step 134 Loss 1.1173191 Correct 33 out of 100
# Step 135 Loss 1.1517035 Correct 31 out of 100
# Step 136 Loss 1.1179681 Correct 40 out of 100
# Step 137 Loss 1.1011628 Correct 43 out of 100
# Step 138 Loss 1.1598965 Correct 33 out of 100
# Step 139 Loss 1.1022455 Correct 40 out of 100
# Step 140 Loss 1.0977489 Correct 29 out of 100
# Step 141 Loss 1.138017 Correct 34 out of 100
# Step 142 Loss 1.099474 Correct 33 out of 100
# Step 143 Loss 1.1828107 Correct 26 out of 100
# Step 144 Loss 1.252276 Correct 32 out of 100
# Step 145 Loss 1.1738044 Correct 34 out of 100
# Step 146 Loss 1.1322048 Correct 34 out of 100
# Step 147 Loss 1.1021212 Correct 35 out of 100
# Step 148 Loss 1.1048657 Correct 38 out of 100
# Step 149 Loss 1.0914218 Correct 41 out of 100
# Step 150 Loss 1.1103297 Correct 39 out of 100
# Step 151 Loss 1.1190906 Correct 31 out of 100
# Step 152 Loss 1.1143926 Correct 37 out of 100
# Step 153 Loss 1.1152855 Correct 34 out of 100
# Step 154 Loss 1.1067246 Correct 28 out of 100
# Step 155 Loss 1.124435 Correct 39 out of 100
# Step 156 Loss 1.0869435 Correct 34 out of 100
# Step 157 Loss 1.0677067 Correct 45 out of 100
# Step 158 Loss 1.1271499 Correct 35 out of 100
# Step 159 Loss 1.1163183 Correct 30 out of 100
# Step 160 Loss 1.08946 Correct 41 out of 100
# Step 161 Loss 1.099568 Correct 37 out of 100
# Step 162 Loss 1.1214157 Correct 26 out of 100
# Step 163 Loss 1.135681 Correct 32 out of 100
# Step 164 Loss 1.1324253 Correct 37 out of 100
# Step 165 Loss 1.1946417 Correct 28 out of 100
# Step 166 Loss 1.1469476 Correct 38 out of 100
# Step 167 Loss 1.1091237 Correct 29 out of 100
# Step 168 Loss 1.1155176 Correct 37 out of 100
# Step 169 Loss 1.0921135 Correct 43 out of 100
# Step 170 Loss 1.1093998 Correct 36 out of 100
# Step 171 Loss 1.0891666 Correct 41 out of 100
# Step 172 Loss 1.1445467 Correct 24 out of 100
# Step 173 Loss 1.1190469 Correct 41 out of 100
# Step 174 Loss 1.1142948 Correct 32 out of 100
# Step 175 Loss 1.1816262 Correct 26 out of 100
# Step 176 Loss 1.168783 Correct 30 out of 100
# Step 177 Loss 1.1106799 Correct 28 out of 100
# Step 178 Loss 1.1256672 Correct 27 out of 100
# Step 179 Loss 1.163578 Correct 34 out of 100
# Step 180 Loss 1.1513385 Correct 29 out of 100
# Step 181 Loss 1.1412636 Correct 36 out of 100
# Step 182 Loss 1.1203634 Correct 35 out of 100
# Step 183 Loss 1.1112474 Correct 33 out of 100
# Step 184 Loss 1.0925453 Correct 40 out of 100
# Step 185 Loss 1.0975057 Correct 38 out of 100
# Step 186 Loss 1.1040497 Correct 31 out of 100
# Step 187 Loss 1.1396396 Correct 29 out of 100
# Step 188 Loss 1.0966265 Correct 45 out of 100
# Step 189 Loss 1.0744209 Correct 42 out of 100
# Step 190 Loss 1.1377894 Correct 36 out of 100
# Step 191 Loss 1.1232982 Correct 29 out of 100
# Step 192 Loss 1.1388282 Correct 35 out of 100
# Step 193 Loss 1.0987349 Correct 32 out of 100
# Step 194 Loss 1.1222988 Correct 27 out of 100
# Step 195 Loss 1.2296921 Correct 31 out of 100
# Step 196 Loss 1.1600751 Correct 38 out of 100
# Step 197 Loss 1.1227511 Correct 27 out of 100
# Step 198 Loss 1.1222904 Correct 39 out of 100
# Step 199 Loss 1.1268141 Correct 28 out of 100
# Step 200 Loss 1.1196318 Correct 25 out of 100
# Step 201 Loss 1.1671503 Correct 30 out of 100
# Step 202 Loss 1.1720647 Correct 33 out of 100
# Step 203 Loss 1.1604308 Correct 37 out of 100
# Step 204 Loss 1.1381754 Correct 34 out of 100
# Step 205 Loss 1.1312191 Correct 31 out of 100
# Step 206 Loss 1.0962731 Correct 35 out of 100
# Step 207 Loss 1.1072466 Correct 33 out of 100
# Step 208 Loss 1.0968915 Correct 38 out of 100
# Step 209 Loss 1.1037507 Correct 40 out of 100
# Step 210 Loss 1.1297858 Correct 35 out of 100
# Step 211 Loss 1.1001413 Correct 33 out of 100
# Step 212 Loss 1.088047 Correct 37 out of 100
# Step 213 Loss 1.2209327 Correct 26 out of 100
# Step 214 Loss 1.150843 Correct 39 out of 100
# Step 215 Loss 1.0688285 Correct 46 out of 100
# Step 216 Loss 1.1206613 Correct 41 out of 100
# Step 217 Loss 1.1091 Correct 36 out of 100
# Step 218 Loss 1.1076118 Correct 35 out of 100
# Step 219 Loss 1.100848 Correct 28 out of 100
# Step 220 Loss 1.1269773 Correct 33 out of 100
# Step 221 Loss 1.1535033 Correct 24 out of 100
# Step 222 Loss 1.1419609 Correct 39 out of 100
# Step 223 Loss 1.1064178 Correct 37 out of 100
# Step 224 Loss 1.101872 Correct 37 out of 100
# Step 225 Loss 1.1071256 Correct 29 out of 100
# Step 226 Loss 1.1028144 Correct 39 out of 100
# Step 227 Loss 1.1066136 Correct 35 out of 100
# Step 228 Loss 1.1004804 Correct 30 out of 100
# Step 229 Loss 1.0870808 Correct 42 out of 100
# Step 230 Loss 1.1415081 Correct 29 out of 100
# Step 231 Loss 1.1279312 Correct 29 out of 100
# Step 232 Loss 1.1061087 Correct 38 out of 100
# Step 233 Loss 1.1103885 Correct 36 out of 100
# Step 234 Loss 1.1425214 Correct 33 out of 100
# Step 235 Loss 1.132551 Correct 33 out of 100
# Step 236 Loss 1.0907295 Correct 40 out of 100
# Step 237 Loss 1.0856462 Correct 41 out of 100
# Step 238 Loss 1.0748596 Correct 44 out of 100
# Step 239 Loss 1.1081698 Correct 37 out of 100
# Step 240 Loss 1.1135411 Correct 32 out of 100
# Step 241 Loss 1.111119 Correct 34 out of 100
# Step 242 Loss 1.1046532 Correct 33 out of 100
# Step 243 Loss 1.119506 Correct 31 out of 100
# Step 244 Loss 1.1007212 Correct 35 out of 100
# Step 245 Loss 1.1076417 Correct 25 out of 100
# Step 246 Loss 1.1444825 Correct 39 out of 100
# Step 247 Loss 1.1013817 Correct 37 out of 100
# Step 248 Loss 1.0973568 Correct 34 out of 100
# Step 249 Loss 1.1017243 Correct 33 out of 100
# Step 250 Loss 1.1042563 Correct 33 out of 100
# Step 251 Loss 1.0973527 Correct 39 out of 100
# Step 252 Loss 1.1281717 Correct 34 out of 100
# Step 253 Loss 1.1133425 Correct 30 out of 100
# Step 254 Loss 1.1113552 Correct 39 out of 100
# Step 255 Loss 1.0903131 Correct 38 out of 100
# Step 256 Loss 1.093448 Correct 46 out of 100
# Step 257 Loss 1.2304088 Correct 31 out of 100
# Step 258 Loss 1.2230607 Correct 30 out of 100
# Step 259 Loss 1.12267 Correct 42 out of 100
# Step 260 Loss 1.1116344 Correct 47 out of 100
# Step 261 Loss 1.1922002 Correct 35 out of 100
# Step 262 Loss 1.1245973 Correct 24 out of 100
# Step 263 Loss 1.0827518 Correct 43 out of 100
# Step 264 Loss 1.0982254 Correct 34 out of 100
# Step 265 Loss 1.071955 Correct 45 out of 100
# Step 266 Loss 1.1447968 Correct 34 out of 100
# Step 267 Loss 1.124539 Correct 30 out of 100
# Step 268 Loss 1.1226943 Correct 31 out of 100
# Step 269 Loss 1.1152836 Correct 33 out of 100
# Step 270 Loss 1.1088243 Correct 33 out of 100
# Step 271 Loss 1.1223629 Correct 28 out of 100
# Step 272 Loss 1.06854 Correct 42 out of 100
# Step 273 Loss 1.1475593 Correct 37 out of 100
# Step 274 Loss 1.1471359 Correct 23 out of 100
# Step 275 Loss 1.1869553 Correct 35 out of 100
# Step 276 Loss 1.1395919 Correct 27 out of 100
# Step 277 Loss 1.1084273 Correct 38 out of 100
# Step 278 Loss 1.1067942 Correct 30 out of 100
# Step 279 Loss 1.173249 Correct 21 out of 100
# Step 280 Loss 1.2127928 Correct 27 out of 100
# Step 281 Loss 1.1115272 Correct 44 out of 100
# Step 282 Loss 1.0938671 Correct 39 out of 100
# Step 283 Loss 1.1002067 Correct 36 out of 100
# Step 284 Loss 1.1000111 Correct 37 out of 100
# Step 285 Loss 1.1132647 Correct 30 out of 100
# Step 286 Loss 1.0902483 Correct 37 out of 100
# Step 287 Loss 1.0834911 Correct 36 out of 100
# Step 288 Loss 1.1183103 Correct 36 out of 100
# Step 289 Loss 1.1127799 Correct 28 out of 100
# Step 290 Loss 1.1219296 Correct 29 out of 100
# Step 291 Loss 1.0899119 Correct 42 out of 100
# Step 292 Loss 1.1165247 Correct 35 out of 100
# Step 293 Loss 1.0969076 Correct 37 out of 100
# Step 294 Loss 1.1471165 Correct 30 out of 100
# Step 295 Loss 1.1143714 Correct 37 out of 100
# Step 296 Loss 1.1014205 Correct 35 out of 100
# Step 297 Loss 1.1518106 Correct 22 out of 100
# Step 298 Loss 1.0603596 Correct 44 out of 100
# Step 299 Loss 1.1188688 Correct 36 out of 100
# Step 300 Loss 1.0912097 Correct 45 out of 100
# Step 301 Loss 1.1799016 Correct 30 out of 100
# Step 302 Loss 1.1696664 Correct 26 out of 100
# Step 303 Loss 1.1927736 Correct 29 out of 100
# Step 304 Loss 1.1239245 Correct 40 out of 100
# Step 305 Loss 1.1411103 Correct 38 out of 100
# Step 306 Loss 1.0826178 Correct 36 out of 100
# Step 307 Loss 1.1411898 Correct 31 out of 100
# Step 308 Loss 1.1262978 Correct 33 out of 100
# Step 309 Loss 1.1290708 Correct 32 out of 100
# Step 310 Loss 1.1225424 Correct 33 out of 100
# Step 311 Loss 1.0824438 Correct 42 out of 100
# Step 312 Loss 1.0911424 Correct 37 out of 100
# Step 313 Loss 1.2529746 Correct 25 out of 100
# Step 314 Loss 1.1070398 Correct 36 out of 100
# Step 315 Loss 1.0899895 Correct 37 out of 100
# Step 316 Loss 1.1153084 Correct 29 out of 100
# Step 317 Loss 1.1299694 Correct 36 out of 100
# Step 318 Loss 1.148297 Correct 33 out of 100
# Step 319 Loss 1.077758 Correct 48 out of 100
# Step 320 Loss 1.1430556 Correct 38 out of 100
# Step 321 Loss 1.1006387 Correct 33 out of 100
# Step 322 Loss 1.1433189 Correct 31 out of 100
# Step 323 Loss 1.1613643 Correct 31 out of 100
# Step 324 Loss 1.1523587 Correct 35 out of 100
# Step 325 Loss 1.1347315 Correct 37 out of 100
# Step 326 Loss 1.1049248 Correct 35 out of 100
# Step 327 Loss 1.1273974 Correct 28 out of 100
# Step 328 Loss 1.1371186 Correct 36 out of 100
# Step 329 Loss 1.121216 Correct 30 out of 100
# Step 330 Loss 1.1073166 Correct 32 out of 100
# Step 331 Loss 1.107413 Correct 32 out of 100
# Step 332 Loss 1.101218 Correct 29 out of 100
# Step 333 Loss 1.110366 Correct 33 out of 100
# Step 334 Loss 1.0899336 Correct 41 out of 100
# Step 335 Loss 1.0720397 Correct 40 out of 100
# Step 336 Loss 1.1414132 Correct 37 out of 100
# Step 337 Loss 1.0933533 Correct 42 out of 100
# Step 338 Loss 1.1462764 Correct 29 out of 100
# Step 339 Loss 1.1095273 Correct 31 out of 100
# Step 340 Loss 1.103398 Correct 34 out of 100
# Step 341 Loss 1.1003855 Correct 32 out of 100
# Step 342 Loss 1.0887654 Correct 40 out of 100
# Step 343 Loss 1.1009334 Correct 36 out of 100
# Step 344 Loss 1.0998352 Correct 35 out of 100
# Step 345 Loss 1.1028801 Correct 30 out of 100
# Step 346 Loss 1.1038144 Correct 37 out of 100
# Step 347 Loss 1.1102889 Correct 32 out of 100
# Step 348 Loss 1.1068298 Correct 30 out of 100
# Step 349 Loss 1.1217186 Correct 31 out of 100
# Step 350 Loss 1.1274313 Correct 31 out of 100
# Step 351 Loss 1.0993216 Correct 39 out of 100
# Step 352 Loss 1.1110244 Correct 33 out of 100
# Step 353 Loss 1.0956063 Correct 37 out of 100
# Step 354 Loss 1.106546 Correct 30 out of 100
# Step 355 Loss 1.0954149 Correct 31 out of 100
# Step 356 Loss 1.1232811 Correct 33 out of 100
# Step 357 Loss 1.0946461 Correct 39 out of 100
# Step 358 Loss 1.1148646 Correct 31 out of 100
# Step 359 Loss 1.1266463 Correct 28 out of 100
# Step 360 Loss 1.1378062 Correct 29 out of 100
# Step 361 Loss 1.1263047 Correct 33 out of 100
# Step 362 Loss 1.1139253 Correct 32 out of 100
# Step 363 Loss 1.0998136 Correct 38 out of 100
# Step 364 Loss 1.1241575 Correct 30 out of 100
# Step 365 Loss 1.0966357 Correct 34 out of 100
# Step 366 Loss 1.1113899 Correct 26 out of 100
# Step 367 Loss 1.2252333 Correct 24 out of 100
# Step 368 Loss 1.2000271 Correct 35 out of 100
# Step 369 Loss 1.1137362 Correct 29 out of 100
# Step 370 Loss 1.1513934 Correct 28 out of 100
# Step 371 Loss 1.1050365 Correct 30 out of 100
# Step 372 Loss 1.1261908 Correct 31 out of 100
# Step 373 Loss 1.1225381 Correct 34 out of 100
# Step 374 Loss 1.0901096 Correct 41 out of 100
# Step 375 Loss 1.0978503 Correct 38 out of 100
# Step 376 Loss 1.0921483 Correct 34 out of 100
# Step 377 Loss 1.1159905 Correct 31 out of 100
# Step 378 Loss 1.0742176 Correct 45 out of 100
# Step 379 Loss 1.1233586 Correct 33 out of 100
# Step 380 Loss 1.1358806 Correct 35 out of 100
# Step 381 Loss 1.1082383 Correct 35 out of 100
# Step 382 Loss 1.0633917 Correct 51 out of 100
# Step 383 Loss 1.1499857 Correct 39 out of 100
# Step 384 Loss 1.0995296 Correct 34 out of 100
# Step 385 Loss 1.0981562 Correct 37 out of 100
# Step 386 Loss 1.0965054 Correct 35 out of 100
# Step 387 Loss 1.1801826 Correct 33 out of 100
# Step 388 Loss 1.1823934 Correct 28 out of 100
# Step 389 Loss 1.1621903 Correct 35 out of 100
# Step 390 Loss 1.1410153 Correct 35 out of 100
# Step 391 Loss 1.1114316 Correct 35 out of 100
# Step 392 Loss 1.0970011 Correct 37 out of 100
# Step 393 Loss 1.0990955 Correct 34 out of 100
# Step 394 Loss 1.0806619 Correct 41 out of 100
# Step 395 Loss 1.1305515 Correct 27 out of 100
# Step 396 Loss 1.1059477 Correct 36 out of 100
# Step 397 Loss 1.1133746 Correct 32 out of 100
# Step 398 Loss 1.1190292 Correct 31 out of 100
# Step 399 Loss 1.0891701 Correct 40 out of 100
# Step 400 Loss 1.1196883 Correct 29 out of 100
# Step 401 Loss 1.1147926 Correct 29 out of 100
# Step 402 Loss 1.1075276 Correct 32 out of 100
# Step 403 Loss 1.1041515 Correct 36 out of 100
# Step 404 Loss 1.1159035 Correct 34 out of 100
# Step 405 Loss 1.0952388 Correct 38 out of 100
# Step 406 Loss 1.1483209 Correct 31 out of 100
# Step 407 Loss 1.1183286 Correct 34 out of 100
# Step 408 Loss 1.1684804 Correct 20 out of 100
# Step 409 Loss 1.1519936 Correct 39 out of 100
# Step 410 Loss 1.1048003 Correct 32 out of 100
# Step 411 Loss 1.0974227 Correct 35 out of 100
# Step 412 Loss 1.1045266 Correct 29 out of 100
# Step 413 Loss 1.1285229 Correct 33 out of 100
# Step 414 Loss 1.2770518 Correct 21 out of 100
# Step 415 Loss 1.2640132 Correct 24 out of 100
# Step 416 Loss 1.2058179 Correct 35 out of 100
# Step 417 Loss 1.1275547 Correct 32 out of 100
# Step 418 Loss 1.1066575 Correct 36 out of 100
# Step 419 Loss 1.1032739 Correct 31 out of 100
# Step 420 Loss 1.1070218 Correct 34 out of 100
# Step 421 Loss 1.1078982 Correct 33 out of 100
# Step 422 Loss 1.0963005 Correct 27 out of 100
# Step 423 Loss 1.2377834 Correct 29 out of 100
# Step 424 Loss 1.1375748 Correct 40 out of 100
# Step 425 Loss 1.0826998 Correct 31 out of 100
# Step 426 Loss 1.1548904 Correct 29 out of 100
# Step 427 Loss 1.1783869 Correct 30 out of 100
# Step 428 Loss 1.138773 Correct 37 out of 100
# Step 429 Loss 1.098419 Correct 37 out of 100
# Step 430 Loss 1.1040096 Correct 32 out of 100
# Step 431 Loss 1.0990341 Correct 35 out of 100
# Step 432 Loss 1.0989332 Correct 37 out of 100
# Step 433 Loss 1.1009796 Correct 45 out of 100
# Step 434 Loss 1.1727163 Correct 31 out of 100
# Step 435 Loss 1.1353201 Correct 29 out of 100
# Step 436 Loss 1.0864781 Correct 39 out of 100
# Step 437 Loss 1.1214846 Correct 33 out of 100
# Step 438 Loss 1.1000267 Correct 34 out of 100
# Step 439 Loss 1.0984493 Correct 32 out of 100
# Step 440 Loss 1.1087246 Correct 35 out of 100
# Step 441 Loss 1.0968959 Correct 38 out of 100
# Step 442 Loss 1.113939 Correct 30 out of 100
# Step 443 Loss 1.1088734 Correct 34 out of 100
# Step 444 Loss 1.1085516 Correct 29 out of 100
# Step 445 Loss 1.1059055 Correct 30 out of 100
# Step 446 Loss 1.09893 Correct 38 out of 100
# Step 447 Loss 1.1119385 Correct 25 out of 100
# Step 448 Loss 1.0933459 Correct 37 out of 100
# Step 449 Loss 1.1240627 Correct 30 out of 100
# Step 450 Loss 1.0973731 Correct 38 out of 100
# Step 451 Loss 1.0988055 Correct 36 out of 100
# Step 452 Loss 1.1030024 Correct 31 out of 100
# Step 453 Loss 1.1226588 Correct 24 out of 100
# Step 454 Loss 1.1340742 Correct 30 out of 100
# Step 455 Loss 1.1114098 Correct 38 out of 100
# Step 456 Loss 1.1044842 Correct 40 out of 100
# Step 457 Loss 1.09963 Correct 36 out of 100
# Step 458 Loss 1.115236 Correct 26 out of 100
# Step 459 Loss 1.1081483 Correct 30 out of 100
# Step 460 Loss 1.1115743 Correct 35 out of 100
# Step 461 Loss 1.1208259 Correct 27 out of 100
# Step 462 Loss 1.1445253 Correct 29 out of 100
# Step 463 Loss 1.1313335 Correct 30 out of 100
# Step 464 Loss 1.1061512 Correct 35 out of 100
# Step 465 Loss 1.1032711 Correct 32 out of 100
# Step 466 Loss 1.1060469 Correct 33 out of 100
# Step 467 Loss 1.1274246 Correct 27 out of 100
# Step 468 Loss 1.1224344 Correct 31 out of 100
# Step 469 Loss 1.0890971 Correct 38 out of 100
# Step 470 Loss 1.1112533 Correct 35 out of 100
# Step 471 Loss 1.0976377 Correct 31 out of 100
# Step 472 Loss 1.097807 Correct 37 out of 100
# Step 473 Loss 1.1194142 Correct 32 out of 100
# Step 474 Loss 1.1134899 Correct 25 out of 100
# Step 475 Loss 1.1083567 Correct 36 out of 100
# Step 476 Loss 1.1240603 Correct 21 out of 100
# Step 477 Loss 1.1937759 Correct 27 out of 100
# Step 478 Loss 1.1545753 Correct 33 out of 100
# Step 479 Loss 1.2016771 Correct 28 out of 100
# Step 480 Loss 1.1388286 Correct 36 out of 100
# Step 481 Loss 1.0886514 Correct 40 out of 100
# Step 482 Loss 1.1181115 Correct 28 out of 100
# Step 483 Loss 1.1036536 Correct 39 out of 100
# Step 484 Loss 1.1316574 Correct 25 out of 100
# Step 485 Loss 1.2004695 Correct 27 out of 100
# Step 486 Loss 1.1604294 Correct 30 out of 100
# Step 487 Loss 1.121716 Correct 23 out of 100
# Step 488 Loss 1.0995194 Correct 40 out of 100
# Step 489 Loss 1.1274256 Correct 26 out of 100
# Step 490 Loss 1.1327193 Correct 33 out of 100
# Step 491 Loss 1.1103019 Correct 24 out of 100
# Step 492 Loss 1.1035986 Correct 37 out of 100
# Step 493 Loss 1.0896857 Correct 38 out of 100
# Step 494 Loss 1.0892802 Correct 43 out of 100
# Step 495 Loss 1.1042434 Correct 37 out of 100
# Step 496 Loss 1.1281221 Correct 31 out of 100
# Step 497 Loss 1.0822806 Correct 41 out of 100
# Step 498 Loss 1.1257541 Correct 32 out of 100
# Step 499 Loss 1.1004864 Correct 32 out of 100
# Step 500 Loss 1.1094719 Correct 29 out of 100
# Step 501 Loss 1.0988919 Correct 39 out of 100
# Step 502 Loss 1.1050812 Correct 31 out of 100
# Step 503 Loss 1.1084784 Correct 34 out of 100
# Step 504 Loss 1.10747 Correct 36 out of 100
# Step 505 Loss 1.1116484 Correct 34 out of 100
# Step 506 Loss 1.0931776 Correct 37 out of 100
# Step 507 Loss 1.100559 Correct 38 out of 100
# Step 508 Loss 1.0790925 Correct 45 out of 100
# Step 509 Loss 1.1409737 Correct 33 out of 100
# Step 510 Loss 1.1050951 Correct 31 out of 100
# Step 511 Loss 1.0989263 Correct 32 out of 100
# Step 512 Loss 1.0889539 Correct 41 out of 100
# Step 513 Loss 1.1044971 Correct 38 out of 100
# Step 514 Loss 1.0947628 Correct 38 out of 100
# Step 515 Loss 1.0914401 Correct 40 out of 100
# Step 516 Loss 1.092805 Correct 39 out of 100
# Step 517 Loss 1.10624 Correct 33 out of 100
# Step 518 Loss 1.0858219 Correct 41 out of 100
# Step 519 Loss 1.1051191 Correct 35 out of 100
# Step 520 Loss 1.0983075 Correct 36 out of 100
# Step 521 Loss 1.0948194 Correct 36 out of 100
# Step 522 Loss 1.093227 Correct 41 out of 100
# Step 523 Loss 1.1263859 Correct 31 out of 100
# Step 524 Loss 1.1000985 Correct 38 out of 100
# Step 525 Loss 1.1285805 Correct 30 out of 100
# Step 526 Loss 1.1026893 Correct 37 out of 100
# Step 527 Loss 1.1404629 Correct 28 out of 100
# Step 528 Loss 1.125175 Correct 31 out of 100
# Step 529 Loss 1.1102362 Correct 30 out of 100
# Step 530 Loss 1.1008615 Correct 35 out of 100
# Step 531 Loss 1.0978149 Correct 35 out of 100
# Step 532 Loss 1.0927753 Correct 35 out of 100
# Step 533 Loss 1.1220826 Correct 26 out of 100
# Step 534 Loss 1.0833197 Correct 41 out of 100
# Step 535 Loss 1.1226794 Correct 31 out of 100
# Step 536 Loss 1.0950876 Correct 40 out of 100
# Step 537 Loss 1.132349 Correct 24 out of 100
# Step 538 Loss 1.1795616 Correct 31 out of 100
# Step 539 Loss 1.0938219 Correct 38 out of 100
# Step 540 Loss 1.0876862 Correct 40 out of 100
# Step 541 Loss 1.128092 Correct 30 out of 100
# Step 542 Loss 1.1049271 Correct 29 out of 100
# Step 543 Loss 1.1068436 Correct 38 out of 100
# Step 544 Loss 1.103841 Correct 33 out of 100
# Step 545 Loss 1.097036 Correct 35 out of 100
# Step 546 Loss 1.1024607 Correct 31 out of 100
# Step 547 Loss 1.0990714 Correct 33 out of 100
# Step 548 Loss 1.147002 Correct 26 out of 100
# Step 549 Loss 1.1207739 Correct 32 out of 100
# Step 550 Loss 1.1052848 Correct 32 out of 100
# Step 551 Loss 1.1066264 Correct 32 out of 100
# Step 552 Loss 1.0978659 Correct 33 out of 100
# Step 553 Loss 1.1150453 Correct 29 out of 100
# Step 554 Loss 1.1421034 Correct 27 out of 100
# Step 555 Loss 1.1123267 Correct 40 out of 100
# Step 556 Loss 1.0988818 Correct 24 out of 100
# Step 557 Loss 1.1485236 Correct 36 out of 100
# Step 558 Loss 1.0957252 Correct 36 out of 100
# Step 559 Loss 1.1117097 Correct 28 out of 100
# Step 560 Loss 1.1153177 Correct 27 out of 100
# Step 561 Loss 1.1298778 Correct 35 out of 100
# Step 562 Loss 1.1530137 Correct 25 out of 100
# Step 563 Loss 1.1294473 Correct 32 out of 100
# Step 564 Loss 1.0963241 Correct 35 out of 100
# Step 565 Loss 1.0994669 Correct 31 out of 100
# Step 566 Loss 1.0938214 Correct 35 out of 100
# Step 567 Loss 1.1489853 Correct 33 out of 100
# Step 568 Loss 1.1272291 Correct 24 out of 100
# Step 569 Loss 1.1142025 Correct 37 out of 100
# Step 570 Loss 1.101504 Correct 37 out of 100
# Step 571 Loss 1.074549 Correct 40 out of 100
# Step 572 Loss 1.1200942 Correct 32 out of 100
# Step 573 Loss 1.0913432 Correct 39 out of 100
# Step 574 Loss 1.1093212 Correct 32 out of 100
# Step 575 Loss 1.1007199 Correct 32 out of 100
# Step 576 Loss 1.1048993 Correct 34 out of 100
# Step 577 Loss 1.1051112 Correct 24 out of 100
# Step 578 Loss 1.1420993 Correct 31 out of 100
# Step 579 Loss 1.0964248 Correct 46 out of 100
# Step 580 Loss 1.1819148 Correct 29 out of 100
# Step 581 Loss 1.0728596 Correct 45 out of 100
# Step 582 Loss 1.116332 Correct 40 out of 100
# Step 583 Loss 1.1060672 Correct 36 out of 100
# Step 584 Loss 1.0972548 Correct 36 out of 100
# Step 585 Loss 1.0908344 Correct 42 out of 100
# Step 586 Loss 1.1044277 Correct 37 out of 100
# Step 587 Loss 1.110063 Correct 23 out of 100
# Step 588 Loss 1.1446168 Correct 35 out of 100
# Step 589 Loss 1.109362 Correct 28 out of 100
# Step 590 Loss 1.1044679 Correct 39 out of 100
# Step 591 Loss 1.112842 Correct 31 out of 100
# Step 592 Loss 1.1019605 Correct 32 out of 100
# Step 593 Loss 1.0947025 Correct 37 out of 100
# Step 594 Loss 1.0905141 Correct 34 out of 100
# Step 595 Loss 1.1100539 Correct 33 out of 100
# Step 596 Loss 1.0997812 Correct 35 out of 100
# Step 597 Loss 1.0935003 Correct 33 out of 100
# Step 598 Loss 1.1475605 Correct 24 out of 100
# Step 599 Loss 1.1120535 Correct 38 out of 100
# Step 600 Loss 1.087699 Correct 41 out of 100
# Step 601 Loss 1.084123 Correct 42 out of 100
# Step 602 Loss 1.1186682 Correct 34 out of 100
# Step 603 Loss 1.1385825 Correct 29 out of 100
# Step 604 Loss 1.1237153 Correct 33 out of 100
# Step 605 Loss 1.1052325 Correct 32 out of 100
# Step 606 Loss 1.0978819 Correct 34 out of 100
# Step 607 Loss 1.1215148 Correct 35 out of 100
# Step 608 Loss 1.0891732 Correct 36 out of 100
# Step 609 Loss 1.1243427 Correct 36 out of 100
# Step 610 Loss 1.0939014 Correct 46 out of 100
# Step 611 Loss 1.1432834 Correct 35 out of 100
# Step 612 Loss 1.1078904 Correct 32 out of 100
# Step 613 Loss 1.0956169 Correct 38 out of 100
# Step 614 Loss 1.0920771 Correct 39 out of 100
# Step 615 Loss 1.1159494 Correct 30 out of 100
# Step 616 Loss 1.1076655 Correct 34 out of 100
# Step 617 Loss 1.0988783 Correct 33 out of 100
# Step 618 Loss 1.107858 Correct 28 out of 100
# Step 619 Loss 1.0863273 Correct 41 out of 100
# Step 620 Loss 1.1125741 Correct 37 out of 100
# Step 621 Loss 1.1473353 Correct 25 out of 100
# Step 622 Loss 1.0997132 Correct 30 out of 100
# Step 623 Loss 1.1649348 Correct 30 out of 100
# Step 624 Loss 1.1102344 Correct 36 out of 100
# Step 625 Loss 1.1070185 Correct 27 out of 100
# Step 626 Loss 1.1402428 Correct 34 out of 100
# Step 627 Loss 1.1120518 Correct 30 out of 100
# Step 628 Loss 1.131611 Correct 32 out of 100
# Step 629 Loss 1.126562 Correct 30 out of 100
# Step 630 Loss 1.2185549 Correct 35 out of 100
# Step 631 Loss 1.1471257 Correct 28 out of 100
# Step 632 Loss 1.0915039 Correct 36 out of 100
# Step 633 Loss 1.0745736 Correct 43 out of 100
# Step 634 Loss 1.099986 Correct 41 out of 100
# Step 635 Loss 1.100615 Correct 36 out of 100
# Step 636 Loss 1.0815231 Correct 43 out of 100
# Step 637 Loss 1.1247942 Correct 36 out of 100
# Step 638 Loss 1.0887414 Correct 40 out of 100
# Step 639 Loss 1.1001354 Correct 33 out of 100
# Step 640 Loss 1.1375395 Correct 27 out of 100
# Step 641 Loss 1.1357784 Correct 32 out of 100
# Step 642 Loss 1.1119307 Correct 32 out of 100
# Step 643 Loss 1.0976086 Correct 35 out of 100
# Step 644 Loss 1.118013 Correct 20 out of 100
# Step 645 Loss 1.1530285 Correct 30 out of 100
# Step 646 Loss 1.1439177 Correct 24 out of 100
# Step 647 Loss 1.1332091 Correct 41 out of 100
# Step 648 Loss 1.1195886 Correct 36 out of 100
# Step 649 Loss 1.0934843 Correct 39 out of 100
# Step 650 Loss 1.1145295 Correct 32 out of 100
# Step 651 Loss 1.0981218 Correct 40 out of 100
# Step 652 Loss 1.1216028 Correct 30 out of 100
# Step 653 Loss 1.1137398 Correct 31 out of 100
# Step 654 Loss 1.0948702 Correct 38 out of 100
# Step 655 Loss 1.121516 Correct 25 out of 100
# Step 656 Loss 1.1034839 Correct 40 out of 100
# Step 657 Loss 1.1247575 Correct 29 out of 100
# Step 658 Loss 1.1093872 Correct 35 out of 100
# Step 659 Loss 1.0996652 Correct 28 out of 100
# Step 660 Loss 1.0945526 Correct 54 out of 100
# Step 661 Loss 1.0991982 Correct 37 out of 100
# Step 662 Loss 1.103618 Correct 33 out of 100
# Step 663 Loss 1.0958226 Correct 37 out of 100
# Step 664 Loss 1.1020085 Correct 37 out of 100
# Step 665 Loss 1.1008106 Correct 34 out of 100
# Step 666 Loss 1.095752 Correct 32 out of 100
# Step 667 Loss 1.0977012 Correct 36 out of 100
# Step 668 Loss 1.1183988 Correct 37 out of 100
# Step 669 Loss 1.1012523 Correct 33 out of 100
# Step 670 Loss 1.1038711 Correct 31 out of 100
# Step 671 Loss 1.107246 Correct 32 out of 100
# Step 672 Loss 1.1114937 Correct 31 out of 100
# Step 673 Loss 1.0807872 Correct 49 out of 100
# Step 674 Loss 1.1428547 Correct 38 out of 100
# Step 675 Loss 1.0972049 Correct 35 out of 100
# Step 676 Loss 1.0985373 Correct 39 out of 100
# Step 677 Loss 1.1051159 Correct 34 out of 100
# Step 678 Loss 1.1027244 Correct 33 out of 100
# Step 679 Loss 1.0962981 Correct 38 out of 100
# Step 680 Loss 1.1081434 Correct 30 out of 100
# Step 681 Loss 1.1071266 Correct 34 out of 100
# Step 682 Loss 1.095652 Correct 33 out of 100
# Step 683 Loss 1.0895582 Correct 38 out of 100
# Step 684 Loss 1.123151 Correct 36 out of 100
# Step 685 Loss 1.0985788 Correct 31 out of 100
# Step 686 Loss 1.1155173 Correct 33 out of 100
# Step 687 Loss 1.1234112 Correct 30 out of 100
# Step 688 Loss 1.1007314 Correct 33 out of 100
# Step 689 Loss 1.1066045 Correct 32 out of 100
# Step 690 Loss 1.1146803 Correct 21 out of 100
# Step 691 Loss 1.1129822 Correct 40 out of 100
# Step 692 Loss 1.1004014 Correct 36 out of 100
# Step 693 Loss 1.0961704 Correct 37 out of 100
# Step 694 Loss 1.1099328 Correct 28 out of 100
# Step 695 Loss 1.144818 Correct 29 out of 100
# Step 696 Loss 1.1163049 Correct 37 out of 100
# Step 697 Loss 1.1030318 Correct 30 out of 100
# Step 698 Loss 1.112224 Correct 32 out of 100
# Step 699 Loss 1.0935761 Correct 38 out of 100
# Step 700 Loss 1.1091839 Correct 30 out of 100
# Step 701 Loss 1.093172 Correct 40 out of 100
# Step 702 Loss 1.1379632 Correct 25 out of 100
# Step 703 Loss 1.1407948 Correct 34 out of 100
# Step 704 Loss 1.0902189 Correct 40 out of 100
# Step 705 Loss 1.0977286 Correct 37 out of 100
# Step 706 Loss 1.1156127 Correct 30 out of 100
# Step 707 Loss 1.1020802 Correct 35 out of 100
# Step 708 Loss 1.0953674 Correct 31 out of 100
# Step 709 Loss 1.1027395 Correct 37 out of 100
# Step 710 Loss 1.0942593 Correct 40 out of 100
# Step 711 Loss 1.1019582 Correct 36 out of 100
# Step 712 Loss 1.0947976 Correct 42 out of 100
# Step 713 Loss 1.0671214 Correct 47 out of 100
# Step 714 Loss 1.1286932 Correct 36 out of 100
# Step 715 Loss 1.0995202 Correct 31 out of 100
# Step 716 Loss 1.0881004 Correct 40 out of 100
# Step 717 Loss 1.1415135 Correct 35 out of 100
# Step 718 Loss 1.1190548 Correct 33 out of 100
# Step 719 Loss 1.1021894 Correct 31 out of 100
# Step 720 Loss 1.1000167 Correct 35 out of 100
# Step 721 Loss 1.0950096 Correct 33 out of 100
# Step 722 Loss 1.1756452 Correct 26 out of 100
# Step 723 Loss 1.1208085 Correct 30 out of 100
# Step 724 Loss 1.108766 Correct 31 out of 100
# Step 725 Loss 1.126849 Correct 26 out of 100
# Step 726 Loss 1.128255 Correct 36 out of 100
# Step 727 Loss 1.1078341 Correct 37 out of 100
# Step 728 Loss 1.1262882 Correct 29 out of 100
# Step 729 Loss 1.1071976 Correct 38 out of 100
# Step 730 Loss 1.1454551 Correct 22 out of 100
# Step 731 Loss 1.1435633 Correct 25 out of 100
# Step 732 Loss 1.1126955 Correct 39 out of 100
# Step 733 Loss 1.1133449 Correct 23 out of 100
# Step 734 Loss 1.1287478 Correct 36 out of 100
# Step 735 Loss 1.0966656 Correct 37 out of 100
# Step 736 Loss 1.0989652 Correct 35 out of 100
# Step 737 Loss 1.093049 Correct 39 out of 100
# Step 738 Loss 1.145163 Correct 31 out of 100
# Step 739 Loss 1.1195426 Correct 26 out of 100
# Step 740 Loss 1.1306748 Correct 34 out of 100
# Step 741 Loss 1.1026222 Correct 32 out of 100
# Step 742 Loss 1.1121682 Correct 29 out of 100
# Step 743 Loss 1.1071447 Correct 36 out of 100
# Step 744 Loss 1.0946497 Correct 32 out of 100
# Step 745 Loss 1.0806383 Correct 40 out of 100
# Step 746 Loss 1.1162128 Correct 35 out of 100
# Step 747 Loss 1.1013054 Correct 33 out of 100
# Step 748 Loss 1.1249903 Correct 31 out of 100
# Step 749 Loss 1.1115719 Correct 25 out of 100
# Step 750 Loss 1.0479997 Correct 49 out of 100
# Step 751 Loss 1.136841 Correct 39 out of 100
# Step 752 Loss 1.0943028 Correct 37 out of 100
# Step 753 Loss 1.103801 Correct 32 out of 100
# Step 754 Loss 1.1078764 Correct 30 out of 100
# Step 755 Loss 1.1098609 Correct 36 out of 100
# Step 756 Loss 1.1094884 Correct 32 out of 100
# Step 757 Loss 1.1026878 Correct 27 out of 100
# Step 758 Loss 1.1087767 Correct 33 out of 100
# Step 759 Loss 1.1360266 Correct 27 out of 100
# Step 760 Loss 1.0982151 Correct 35 out of 100
# Step 761 Loss 1.1321212 Correct 31 out of 100
# Step 762 Loss 1.1094444 Correct 36 out of 100
# Step 763 Loss 1.1046593 Correct 32 out of 100
# Step 764 Loss 1.1008335 Correct 34 out of 100
# Step 765 Loss 1.1087679 Correct 26 out of 100
# Step 766 Loss 1.087247 Correct 42 out of 100
# Step 767 Loss 1.0895157 Correct 40 out of 100
# Step 768 Loss 1.1098363 Correct 34 out of 100
# Step 769 Loss 1.0983418 Correct 36 out of 100
# Step 770 Loss 1.1083586 Correct 33 out of 100
# Step 771 Loss 1.1153346 Correct 31 out of 100
# Step 772 Loss 1.089735 Correct 40 out of 100
# Step 773 Loss 1.1067691 Correct 33 out of 100
# Step 774 Loss 1.0973454 Correct 36 out of 100
# Step 775 Loss 1.09284 Correct 35 out of 100
# Step 776 Loss 1.098435 Correct 31 out of 100
# Step 777 Loss 1.1116647 Correct 33 out of 100
# Step 778 Loss 1.1097313 Correct 30 out of 100
# Step 779 Loss 1.1005633 Correct 37 out of 100
# Step 780 Loss 1.125568 Correct 31 out of 100
# Step 781 Loss 1.1362468 Correct 30 out of 100
# Step 782 Loss 1.1026068 Correct 40 out of 100
# Step 783 Loss 1.1168029 Correct 29 out of 100
# Step 784 Loss 1.1107534 Correct 36 out of 100
# Step 785 Loss 1.1023017 Correct 30 out of 100
# Step 786 Loss 1.1411334 Correct 23 out of 100
# Step 787 Loss 1.1490687 Correct 36 out of 100
# Step 788 Loss 1.135092 Correct 23 out of 100
# Step 789 Loss 1.1510649 Correct 29 out of 100
# Step 790 Loss 1.1317893 Correct 33 out of 100
# Step 791 Loss 1.0988418 Correct 33 out of 100
# Step 792 Loss 1.0994314 Correct 33 out of 100
# Step 793 Loss 1.0969491 Correct 38 out of 100
# Step 794 Loss 1.1125557 Correct 40 out of 100
# Step 795 Loss 1.1301022 Correct 31 out of 100
# Step 796 Loss 1.1182103 Correct 23 out of 100
# Step 797 Loss 1.0722419 Correct 44 out of 100
# Step 798 Loss 1.1229692 Correct 36 out of 100
# Step 799 Loss 1.0935568 Correct 37 out of 100
# Step 800 Loss 1.1067793 Correct 29 out of 100
# Step 801 Loss 1.1020491 Correct 33 out of 100
# Step 802 Loss 1.1305358 Correct 21 out of 100
# Step 803 Loss 1.1198696 Correct 32 out of 100
# Step 804 Loss 1.1142398 Correct 38 out of 100
# Step 805 Loss 1.1458158 Correct 28 out of 100
# Step 806 Loss 1.1116709 Correct 31 out of 100
# Step 807 Loss 1.0943506 Correct 40 out of 100
# Step 808 Loss 1.0919948 Correct 39 out of 100
# Step 809 Loss 1.1063281 Correct 33 out of 100
# Step 810 Loss 1.0966837 Correct 37 out of 100
# Step 811 Loss 1.1044791 Correct 32 out of 100
# Step 812 Loss 1.1054635 Correct 31 out of 100
# Step 813 Loss 1.1028534 Correct 38 out of 100
# Step 814 Loss 1.1415024 Correct 36 out of 100
# Step 815 Loss 1.108125 Correct 35 out of 100
# Step 816 Loss 1.129301 Correct 21 out of 100
# Step 817 Loss 1.125983 Correct 34 out of 100
# Step 818 Loss 1.0980502 Correct 34 out of 100
# Step 819 Loss 1.1000831 Correct 32 out of 100
# Step 820 Loss 1.1026127 Correct 28 out of 100
# Step 821 Loss 1.1243769 Correct 31 out of 100
# Step 822 Loss 1.0857674 Correct 41 out of 100
# Step 823 Loss 1.1247115 Correct 32 out of 100
# Step 824 Loss 1.1021467 Correct 33 out of 100
# Step 825 Loss 1.1023829 Correct 34 out of 100
# Step 826 Loss 1.0912088 Correct 40 out of 100
# Step 827 Loss 1.1167287 Correct 31 out of 100
# Step 828 Loss 1.1010361 Correct 37 out of 100
# Step 829 Loss 1.0967793 Correct 28 out of 100
# Step 830 Loss 1.1086771 Correct 35 out of 100
# Step 831 Loss 1.124885 Correct 28 out of 100
# Step 832 Loss 1.0985029 Correct 30 out of 100
# Step 833 Loss 1.1373396 Correct 28 out of 100
# Step 834 Loss 1.1630831 Correct 26 out of 100
# Step 835 Loss 1.0848577 Correct 39 out of 100
# Step 836 Loss 1.108371 Correct 34 out of 100
# Step 837 Loss 1.1023022 Correct 31 out of 100
# Step 838 Loss 1.1019932 Correct 33 out of 100
# Step 839 Loss 1.0987786 Correct 35 out of 100
# Step 840 Loss 1.0997591 Correct 31 out of 100
# Step 841 Loss 1.0955404 Correct 37 out of 100
# Step 842 Loss 1.0925311 Correct 40 out of 100
# Step 843 Loss 1.0912673 Correct 39 out of 100
# Step 844 Loss 1.1016525 Correct 35 out of 100
# Step 845 Loss 1.0956132 Correct 39 out of 100
# Step 846 Loss 1.1038251 Correct 35 out of 100
# Step 847 Loss 1.1098894 Correct 30 out of 100
# Step 848 Loss 1.1087425 Correct 29 out of 100
# Step 849 Loss 1.1208873 Correct 25 out of 100
# Step 850 Loss 1.0943639 Correct 36 out of 100
# Step 851 Loss 1.1264102 Correct 23 out of 100
# Step 852 Loss 1.1540778 Correct 29 out of 100
# Step 853 Loss 1.1089809 Correct 36 out of 100
# Step 854 Loss 1.0928985 Correct 39 out of 100
# Step 855 Loss 1.0922248 Correct 40 out of 100
# Step 856 Loss 1.124781 Correct 29 out of 100
# Step 857 Loss 1.1041687 Correct 35 out of 100
# Step 858 Loss 1.0958174 Correct 36 out of 100
# Step 859 Loss 1.1125396 Correct 30 out of 100
# Step 860 Loss 1.1242819 Correct 23 out of 100
# Step 861 Loss 1.113338 Correct 39 out of 100
# Step 862 Loss 1.0860204 Correct 42 out of 100
# Step 863 Loss 1.1144893 Correct 34 out of 100
# Step 864 Loss 1.1071415 Correct 29 out of 100
# Step 865 Loss 1.0889201 Correct 40 out of 100
# Step 866 Loss 1.091071 Correct 39 out of 100
# Step 867 Loss 1.0942521 Correct 37 out of 100
# Step 868 Loss 1.1133587 Correct 27 out of 100
# Step 869 Loss 1.1010492 Correct 38 out of 100
# Step 870 Loss 1.0999824 Correct 35 out of 100
# Step 871 Loss 1.1089445 Correct 31 out of 100
# Step 872 Loss 1.0954976 Correct 32 out of 100
# Step 873 Loss 1.0676053 Correct 48 out of 100
# Step 874 Loss 1.0756298 Correct 45 out of 100
# Step 875 Loss 1.1052074 Correct 40 out of 100
# Step 876 Loss 1.1133183 Correct 32 out of 100
# Step 877 Loss 1.0913309 Correct 40 out of 100
# Step 878 Loss 1.1287721 Correct 32 out of 100
# Step 879 Loss 1.0975984 Correct 37 out of 100
# Step 880 Loss 1.1014267 Correct 40 out of 100
# Step 881 Loss 1.1305312 Correct 27 out of 100
# Step 882 Loss 1.1110295 Correct 34 out of 100
# Step 883 Loss 1.0996518 Correct 24 out of 100
# Step 884 Loss 1.0897162 Correct 46 out of 100
# Step 885 Loss 1.1205553 Correct 38 out of 100
# Step 886 Loss 1.0792215 Correct 47 out of 100
# Step 887 Loss 1.169229 Correct 32 out of 100
# Step 888 Loss 1.1639329 Correct 30 out of 100
# Step 889 Loss 1.1033847 Correct 42 out of 100
# Step 890 Loss 1.0913397 Correct 40 out of 100
# Step 891 Loss 1.1039326 Correct 38 out of 100
# Step 892 Loss 1.1178674 Correct 35 out of 100
# Step 893 Loss 1.0913265 Correct 34 out of 100
# Step 894 Loss 1.1091299 Correct 35 out of 100
# Step 895 Loss 1.0971867 Correct 43 out of 100
# Step 896 Loss 1.1111467 Correct 37 out of 100
# Step 897 Loss 1.1032777 Correct 30 out of 100
# Step 898 Loss 1.1142474 Correct 32 out of 100
# Step 899 Loss 1.092178 Correct 36 out of 100
# Step 900 Loss 1.1555905 Correct 41 out of 100
# Step 901 Loss 1.0884044 Correct 37 out of 100
# Step 902 Loss 1.1085136 Correct 31 out of 100
# Step 903 Loss 1.1017625 Correct 33 out of 100
# Step 904 Loss 1.098192 Correct 35 out of 100
# Step 905 Loss 1.1026572 Correct 26 out of 100
# Step 906 Loss 1.114992 Correct 32 out of 100
# Step 907 Loss 1.1005352 Correct 34 out of 100
# Step 908 Loss 1.1016055 Correct 34 out of 100
# Step 909 Loss 1.0829223 Correct 39 out of 100
# Step 910 Loss 1.0880816 Correct 34 out of 100
# Step 911 Loss 1.0995605 Correct 36 out of 100
# Step 912 Loss 1.0925592 Correct 31 out of 100
# Step 913 Loss 1.1140318 Correct 33 out of 100
# Step 914 Loss 1.1007402 Correct 34 out of 100
# Step 915 Loss 1.1126614 Correct 27 out of 100
# Step 916 Loss 1.0954617 Correct 33 out of 100
# Step 917 Loss 1.1150416 Correct 35 out of 100
# Step 918 Loss 1.101572 Correct 39 out of 100
# Step 919 Loss 1.1331831 Correct 28 out of 100
# Step 920 Loss 1.127128 Correct 34 out of 100
# Step 921 Loss 1.079735 Correct 41 out of 100
# Step 922 Loss 1.1145959 Correct 36 out of 100
# Step 923 Loss 1.0997692 Correct 31 out of 100
# Step 924 Loss 1.1141967 Correct 27 out of 100
# Step 925 Loss 1.1259291 Correct 31 out of 100
# Step 926 Loss 1.1014401 Correct 34 out of 100
# Step 927 Loss 1.1173968 Correct 27 out of 100
# Step 928 Loss 1.0868794 Correct 42 out of 100
# Step 929 Loss 1.1288525 Correct 30 out of 100
# Step 930 Loss 1.1228104 Correct 26 out of 100
# Step 931 Loss 1.1260982 Correct 26 out of 100
# Step 932 Loss 1.1258461 Correct 32 out of 100
# Step 933 Loss 1.1115036 Correct 28 out of 100
# Step 934 Loss 1.1102318 Correct 39 out of 100
# Step 935 Loss 1.1126509 Correct 28 out of 100
# Step 936 Loss 1.1313255 Correct 31 out of 100
# Step 937 Loss 1.1059097 Correct 34 out of 100
# Step 938 Loss 1.1079665 Correct 29 out of 100
# Step 939 Loss 1.0922719 Correct 35 out of 100
# Step 940 Loss 1.0978159 Correct 37 out of 100
# Step 941 Loss 1.1018412 Correct 34 out of 100
# Step 942 Loss 1.1202213 Correct 24 out of 100
# Step 943 Loss 1.1228577 Correct 33 out of 100
# Step 944 Loss 1.0979595 Correct 37 out of 100
# Step 945 Loss 1.1067349 Correct 34 out of 100
# Step 946 Loss 1.1023734 Correct 37 out of 100
# Step 947 Loss 1.1298566 Correct 31 out of 100
# Step 948 Loss 1.0986844 Correct 34 out of 100
# Step 949 Loss 1.0967506 Correct 34 out of 100
# Step 950 Loss 1.1200824 Correct 23 out of 100
# Step 951 Loss 1.1276857 Correct 35 out of 100
# Step 952 Loss 1.096932 Correct 35 out of 100
# Step 953 Loss 1.1648846 Correct 20 out of 100
# Step 954 Loss 1.1890173 Correct 28 out of 100
# Step 955 Loss 1.0856489 Correct 38 out of 100
# Step 956 Loss 1.1070479 Correct 44 out of 100
# Step 957 Loss 1.1237593 Correct 38 out of 100
# Step 958 Loss 1.0916514 Correct 36 out of 100
# Step 959 Loss 1.1121727 Correct 33 out of 100
# Step 960 Loss 1.0932837 Correct 40 out of 100
# Step 961 Loss 1.1443309 Correct 23 out of 100
# Step 962 Loss 1.1008096 Correct 41 out of 100
# Step 963 Loss 1.0950058 Correct 38 out of 100
# Step 964 Loss 1.0913194 Correct 45 out of 100
# Step 965 Loss 1.1204096 Correct 37 out of 100
# Step 966 Loss 1.0945386 Correct 30 out of 100
# Step 967 Loss 1.1024314 Correct 37 out of 100
# Step 968 Loss 1.0827845 Correct 37 out of 100
# Step 969 Loss 1.0872912 Correct 38 out of 100
# Step 970 Loss 1.1286436 Correct 31 out of 100
# Step 971 Loss 1.0971916 Correct 38 out of 100
# Step 972 Loss 1.111689 Correct 33 out of 100
# Step 973 Loss 1.087966 Correct 42 out of 100
# Step 974 Loss 1.1143783 Correct 34 out of 100
# Step 975 Loss 1.0995245 Correct 38 out of 100
# Step 976 Loss 1.124865 Correct 27 out of 100
# Step 977 Loss 1.1263481 Correct 29 out of 100
# Step 978 Loss 1.1343474 Correct 31 out of 100
# Step 979 Loss 1.0861495 Correct 41 out of 100
# Step 980 Loss 1.1354978 Correct 31 out of 100
# Step 981 Loss 1.1183727 Correct 32 out of 100
# Step 982 Loss 1.0956128 Correct 35 out of 100
# Step 983 Loss 1.0943489 Correct 39 out of 100
# Step 984 Loss 1.1052474 Correct 34 out of 100
# Step 985 Loss 1.0995036 Correct 34 out of 100
# Step 986 Loss 1.104763 Correct 28 out of 100
# Step 987 Loss 1.131868 Correct 32 out of 100
# Step 988 Loss 1.1115535 Correct 31 out of 100
# Step 989 Loss 1.0888327 Correct 40 out of 100
# Step 990 Loss 1.0671395 Correct 45 out of 100
# Step 991 Loss 1.126925 Correct 35 out of 100
# Step 992 Loss 1.1000928 Correct 35 out of 100
# Step 993 Loss 1.1280541 Correct 26 out of 100
# Step 994 Loss 1.1216514 Correct 31 out of 100
# Step 995 Loss 1.0953099 Correct 39 out of 100
# Step 996 Loss 1.1150483 Correct 31 out of 100
# Step 997 Loss 1.086706 Correct 40 out of 100
# Step 998 Loss 1.1172293 Correct 40 out of 100
# Step 999 Loss 1.0688956 Correct 46 out of 100
# Step 1000 Loss 1.1719341 Correct 27 out of 100
# Step 1001 Loss 1.1299616 Correct 31 out of 100
# Step 1002 Loss 1.0931967 Correct 40 out of 100
# Step 1003 Loss 1.0960771 Correct 39 out of 100
# Step 1004 Loss 1.1060597 Correct 33 out of 100
# Step 1005 Loss 1.1045595 Correct 28 out of 100
# Step 1006 Loss 1.1016238 Correct 35 out of 100
# Step 1007 Loss 1.1007376 Correct 28 out of 100
# Step 1008 Loss 1.1150551 Correct 35 out of 100
# Step 1009 Loss 1.0945134 Correct 36 out of 100
# Step 1010 Loss 1.1011844 Correct 38 out of 100
# Step 1011 Loss 1.1023723 Correct 36 out of 100
# Step 1012 Loss 1.0977634 Correct 30 out of 100
# Step 1013 Loss 1.1620237 Correct 26 out of 100
# ...
# Step 9669 Loss 0.51795024 Correct 74 out of 100
# Step 9670 Loss 0.5676604 Correct 70 out of 100
# Step 9671 Loss 0.5240824 Correct 71 out of 100
# Step 9672 Loss 0.6741699 Correct 68 out of 100
# Step 9673 Loss 0.8366909 Correct 54 out of 100
# Step 9674 Loss 0.5169908 Correct 74 out of 100
# Step 9675 Loss 0.47560516 Correct 80 out of 100
# Step 9676 Loss 0.5417434 Correct 75 out of 100
# Step 9677 Loss 0.55664027 Correct 71 out of 100
# Step 9678 Loss 1.1299468 Correct 59 out of 100
# Step 9679 Loss 1.0726838 Correct 48 out of 100
# Step 9680 Loss 0.83208907 Correct 56 out of 100
# Step 9681 Loss 0.63888764 Correct 84 out of 100
# Step 9682 Loss 0.5659069 Correct 70 out of 100
# Step 9683 Loss 0.55237836 Correct 71 out of 100
# Step 9684 Loss 0.45412505 Correct 87 out of 100
# Step 9685 Loss 0.53887445 Correct 74 out of 100
# Step 9686 Loss 0.5350633 Correct 81 out of 100
# Step 9687 Loss 0.5302255 Correct 77 out of 100
# Step 9688 Loss 0.57344633 Correct 76 out of 100
# Step 9689 Loss 0.56034344 Correct 77 out of 100
# Step 9690 Loss 0.42871207 Correct 86 out of 100
# Step 9691 Loss 0.43987083 Correct 83 out of 100
# Step 9692 Loss 0.45014298 Correct 79 out of 100
# Step 9693 Loss 0.5245937 Correct 72 out of 100
# Step 9694 Loss 0.36980787 Correct 86 out of 100
# Step 9695 Loss 0.47177732 Correct 77 out of 100
# Step 9696 Loss 0.40914816 Correct 83 out of 100
# Step 9697 Loss 0.4763823 Correct 80 out of 100
# Step 9698 Loss 0.6383365 Correct 71 out of 100
# Step 9699 Loss 0.43799323 Correct 85 out of 100
# Step 9700 Loss 0.4503629 Correct 79 out of 100
# Step 9701 Loss 0.55486196 Correct 77 out of 100
# Step 9702 Loss 0.666587 Correct 62 out of 100
# Step 9703 Loss 0.48796985 Correct 77 out of 100
# Step 9704 Loss 0.43445623 Correct 82 out of 100
# Step 9705 Loss 0.49478957 Correct 83 out of 100
# Step 9706 Loss 0.5344456 Correct 79 out of 100
# Step 9707 Loss 0.729801 Correct 55 out of 100
# Step 9708 Loss 0.56734425 Correct 72 out of 100
# Step 9709 Loss 0.42863506 Correct 83 out of 100
# Step 9710 Loss 0.39420304 Correct 81 out of 100
# Step 9711 Loss 0.3847802 Correct 87 out of 100
# Step 9712 Loss 0.40221602 Correct 86 out of 100
# Step 9713 Loss 0.52348393 Correct 77 out of 100
# Step 9714 Loss 0.39298424 Correct 85 out of 100
# Step 9715 Loss 0.46971732 Correct 80 out of 100
# Step 9716 Loss 0.44629654 Correct 81 out of 100
# Step 9717 Loss 0.44893804 Correct 79 out of 100
# Step 9718 Loss 0.4074296 Correct 82 out of 100
# Step 9719 Loss 0.44615558 Correct 80 out of 100
# Step 9720 Loss 0.6454975 Correct 72 out of 100
# Step 9721 Loss 0.66526246 Correct 71 out of 100
# Step 9722 Loss 0.8934864 Correct 57 out of 100
# Step 9723 Loss 0.7026893 Correct 64 out of 100
# Step 9724 Loss 0.535001 Correct 80 out of 100
# Step 9725 Loss 0.52840173 Correct 73 out of 100
# Step 9726 Loss 0.4672483 Correct 80 out of 100
# Step 9727 Loss 0.5654219 Correct 64 out of 100
# Step 9728 Loss 0.45746127 Correct 78 out of 100
# Step 9729 Loss 0.5533379 Correct 82 out of 100
# Step 9730 Loss 0.6836726 Correct 67 out of 100
# Step 9731 Loss 0.7411669 Correct 65 out of 100
# Step 9732 Loss 0.6254145 Correct 60 out of 100
# Step 9733 Loss 0.61210454 Correct 66 out of 100
# Step 9734 Loss 0.5759844 Correct 68 out of 100
# Step 9735 Loss 0.5270879 Correct 69 out of 100
# Step 9736 Loss 0.5570424 Correct 77 out of 100
# Step 9737 Loss 0.5750928 Correct 70 out of 100
# Step 9738 Loss 0.68322843 Correct 62 out of 100
# Step 9739 Loss 0.57051826 Correct 71 out of 100
# Step 9740 Loss 0.4437927 Correct 81 out of 100
# Step 9741 Loss 0.39642632 Correct 86 out of 100
# Step 9742 Loss 0.49899277 Correct 77 out of 100
# Step 9743 Loss 0.43934187 Correct 80 out of 100
# Step 9744 Loss 0.64325917 Correct 64 out of 100
# Step 9745 Loss 0.5089488 Correct 73 out of 100
# Step 9746 Loss 0.5286525 Correct 76 out of 100
# Step 9747 Loss 0.4039487 Correct 82 out of 100
# Step 9748 Loss 0.42042235 Correct 83 out of 100
# Step 9749 Loss 0.32623923 Correct 89 out of 100
# Step 9750 Loss 0.41475376 Correct 83 out of 100
# Step 9751 Loss 0.34087223 Correct 89 out of 100
# Step 9752 Loss 0.58250433 Correct 71 out of 100
# Step 9753 Loss 0.73067963 Correct 63 out of 100
# Step 9754 Loss 0.50284564 Correct 67 out of 100
# Step 9755 Loss 0.4827798 Correct 77 out of 100
# Step 9756 Loss 0.531953 Correct 67 out of 100
# Step 9757 Loss 0.57869804 Correct 81 out of 100
# Step 9758 Loss 0.6273963 Correct 68 out of 100
# Step 9759 Loss 0.4923311 Correct 85 out of 100
# Step 9760 Loss 0.4734036 Correct 72 out of 100
# Step 9761 Loss 0.5252526 Correct 76 out of 100
# Step 9762 Loss 0.3961997 Correct 81 out of 100
# Step 9763 Loss 0.38787025 Correct 86 out of 100
# Step 9764 Loss 0.549733 Correct 76 out of 100
# Step 9765 Loss 0.4694703 Correct 82 out of 100
# Step 9766 Loss 0.6001754 Correct 77 out of 100
# Step 9767 Loss 0.4135736 Correct 86 out of 100
# Step 9768 Loss 0.57456815 Correct 76 out of 100
# Step 9769 Loss 0.49855563 Correct 73 out of 100
# Step 9770 Loss 0.4628695 Correct 76 out of 100
# Step 9771 Loss 0.5001571 Correct 83 out of 100
# Step 9772 Loss 0.55502397 Correct 80 out of 100
# Step 9773 Loss 0.9460248 Correct 50 out of 100
# Step 9774 Loss 0.58258796 Correct 70 out of 100
# Step 9775 Loss 0.571652 Correct 73 out of 100
# Step 9776 Loss 0.78286606 Correct 54 out of 100
# Step 9777 Loss 0.5784256 Correct 66 out of 100
# Step 9778 Loss 0.71007186 Correct 54 out of 100
# Step 9779 Loss 0.48863888 Correct 80 out of 100
# Step 9780 Loss 0.4901985 Correct 74 out of 100
# Step 9781 Loss 0.48618606 Correct 81 out of 100
# Step 9782 Loss 0.57251763 Correct 76 out of 100
# Step 9783 Loss 0.68353975 Correct 64 out of 100
# Step 9784 Loss 0.45329046 Correct 72 out of 100
# Step 9785 Loss 0.63888264 Correct 68 out of 100
# Step 9786 Loss 0.51790303 Correct 80 out of 100
# Step 9787 Loss 0.7430601 Correct 69 out of 100
# Step 9788 Loss 0.60925823 Correct 72 out of 100
# Step 9789 Loss 0.4475257 Correct 77 out of 100
# Step 9790 Loss 0.42777428 Correct 85 out of 100
# Step 9791 Loss 0.48822775 Correct 75 out of 100
# Step 9792 Loss 0.51159227 Correct 73 out of 100
# Step 9793 Loss 0.3930699 Correct 84 out of 100
# Step 9794 Loss 0.428373 Correct 85 out of 100
# Step 9795 Loss 0.4304018 Correct 82 out of 100
# Step 9796 Loss 0.72503865 Correct 79 out of 100
# Step 9797 Loss 0.5266244 Correct 79 out of 100
# Step 9798 Loss 0.44742653 Correct 74 out of 100
# Step 9799 Loss 0.52687913 Correct 72 out of 100
# Step 9800 Loss 0.3568492 Correct 86 out of 100
# Step 9801 Loss 0.39129996 Correct 82 out of 100
# Step 9802 Loss 0.3248252 Correct 89 out of 100
# Step 9803 Loss 0.3329592 Correct 90 out of 100
# Step 9804 Loss 0.37744084 Correct 88 out of 100
# Step 9805 Loss 0.45636436 Correct 83 out of 100
# Step 9806 Loss 0.5757365 Correct 71 out of 100
# Step 9807 Loss 0.4355709 Correct 77 out of 100
# Step 9808 Loss 0.4625544 Correct 82 out of 100
# Step 9809 Loss 0.528482 Correct 77 out of 100
# Step 9810 Loss 0.55097646 Correct 70 out of 100
# Step 9811 Loss 0.37744242 Correct 85 out of 100
# Step 9812 Loss 0.44606674 Correct 80 out of 100
# Step 9813 Loss 0.39653036 Correct 90 out of 100
# Step 9814 Loss 0.31288722 Correct 88 out of 100
# Step 9815 Loss 0.44018996 Correct 78 out of 100
# Step 9816 Loss 0.5985362 Correct 68 out of 100
# Step 9817 Loss 0.4115802 Correct 77 out of 100
# Step 9818 Loss 0.5623745 Correct 78 out of 100
# Step 9819 Loss 0.3050178 Correct 89 out of 100
# Step 9820 Loss 0.33604583 Correct 86 out of 100
# Step 9821 Loss 0.4407793 Correct 79 out of 100
# Step 9822 Loss 0.41923514 Correct 83 out of 100
# Step 9823 Loss 0.40302214 Correct 85 out of 100
# Step 9824 Loss 0.40087426 Correct 85 out of 100
# Step 9825 Loss 0.5070713 Correct 79 out of 100
# Step 9826 Loss 0.4941552 Correct 83 out of 100
# Step 9827 Loss 1.0076772 Correct 39 out of 100
# Step 9828 Loss 0.57515794 Correct 82 out of 100
# Step 9829 Loss 0.5843678 Correct 74 out of 100
# Step 9830 Loss 0.67179954 Correct 64 out of 100
# Step 9831 Loss 0.49402687 Correct 78 out of 100
# Step 9832 Loss 0.7627136 Correct 54 out of 100
# Step 9833 Loss 0.5976707 Correct 76 out of 100
# Step 9834 Loss 0.5724735 Correct 80 out of 100
# Step 9835 Loss 1.0668718 Correct 50 out of 100
# Step 9836 Loss 1.203915 Correct 39 out of 100
# Step 9837 Loss 1.1038265 Correct 34 out of 100
# Step 9838 Loss 1.0774174 Correct 41 out of 100
# Step 9839 Loss 1.089899 Correct 35 out of 100
# Step 9840 Loss 1.0747867 Correct 43 out of 100
# Step 9841 Loss 1.077259 Correct 40 out of 100
# Step 9842 Loss 1.0701483 Correct 41 out of 100
# Step 9843 Loss 1.0613828 Correct 47 out of 100
# Step 9844 Loss 1.0624526 Correct 53 out of 100
# Step 9845 Loss 1.0414811 Correct 41 out of 100
# Step 9846 Loss 1.0277107 Correct 48 out of 100
# Step 9847 Loss 1.0237602 Correct 48 out of 100
# Step 9848 Loss 1.0057912 Correct 56 out of 100
# Step 9849 Loss 0.99997437 Correct 45 out of 100
# Step 9850 Loss 0.92962414 Correct 57 out of 100
# Step 9851 Loss 1.0304545 Correct 46 out of 100
# Step 9852 Loss 0.9590461 Correct 53 out of 100
# Step 9853 Loss 0.9360692 Correct 55 out of 100
# Step 9854 Loss 0.83441776 Correct 62 out of 100
# Step 9855 Loss 0.8495021 Correct 57 out of 100
# Step 9856 Loss 0.7550728 Correct 55 out of 100
# Step 9857 Loss 0.77986157 Correct 63 out of 100
# Step 9858 Loss 0.68805146 Correct 66 out of 100
# Step 9859 Loss 0.6367461 Correct 69 out of 100
# Step 9860 Loss 0.59257144 Correct 75 out of 100
# Step 9861 Loss 0.6244042 Correct 66 out of 100
# Step 9862 Loss 0.7618668 Correct 55 out of 100
# Step 9863 Loss 0.7439801 Correct 62 out of 100
# Step 9864 Loss 0.6364398 Correct 70 out of 100
# Step 9865 Loss 0.70391357 Correct 57 out of 100
# Step 9866 Loss 0.7463357 Correct 54 out of 100
# Step 9867 Loss 0.8614421 Correct 46 out of 100
# Step 9868 Loss 0.64486265 Correct 62 out of 100
# Step 9869 Loss 0.664184 Correct 66 out of 100
# Step 9870 Loss 0.68214554 Correct 69 out of 100
# Step 9871 Loss 0.56720304 Correct 62 out of 100
# Step 9872 Loss 0.5587349 Correct 74 out of 100
# Step 9873 Loss 0.5507556 Correct 72 out of 100
# Step 9874 Loss 0.6147312 Correct 68 out of 100
# Step 9875 Loss 0.64859116 Correct 70 out of 100
# Step 9876 Loss 0.6640429 Correct 72 out of 100
# Step 9877 Loss 0.6383912 Correct 61 out of 100
# Step 9878 Loss 0.7218838 Correct 58 out of 100
# Step 9879 Loss 0.48022878 Correct 82 out of 100
# Step 9880 Loss 0.59188664 Correct 67 out of 100
# Step 9881 Loss 0.61427546 Correct 69 out of 100
# Step 9882 Loss 0.4961477 Correct 71 out of 100
# Step 9883 Loss 0.5381344 Correct 76 out of 100
# Step 9884 Loss 0.5584567 Correct 73 out of 100
# Step 9885 Loss 0.7448237 Correct 51 out of 100
# Step 9886 Loss 0.6447458 Correct 69 out of 100
# Step 9887 Loss 0.5302447 Correct 77 out of 100
# Step 9888 Loss 0.62287545 Correct 66 out of 100
# Step 9889 Loss 0.72961867 Correct 55 out of 100
# Step 9890 Loss 0.79940075 Correct 58 out of 100
# Step 9891 Loss 0.5766043 Correct 74 out of 100
# Step 9892 Loss 0.4452751 Correct 81 out of 100
# Step 9893 Loss 0.526808 Correct 72 out of 100
# Step 9894 Loss 0.62897396 Correct 66 out of 100
# Step 9895 Loss 1.020304 Correct 59 out of 100
# Step 9896 Loss 0.69483984 Correct 69 out of 100
# Step 9897 Loss 0.5434352 Correct 68 out of 100
# Step 9898 Loss 0.55308723 Correct 67 out of 100
# Step 9899 Loss 0.6718175 Correct 69 out of 100
# Step 9900 Loss 0.52684253 Correct 78 out of 100
# Step 9901 Loss 0.7055659 Correct 69 out of 100
# Step 9902 Loss 0.75613064 Correct 59 out of 100
# Step 9903 Loss 0.61976105 Correct 64 out of 100
# Step 9904 Loss 0.7570066 Correct 50 out of 100
# Step 9905 Loss 0.54721093 Correct 79 out of 100
# Step 9906 Loss 0.4565124 Correct 74 out of 100
# Step 9907 Loss 0.49365398 Correct 75 out of 100
# Step 9908 Loss 0.5764359 Correct 71 out of 100
# Step 9909 Loss 0.6043997 Correct 73 out of 100
# Step 9910 Loss 0.5003116 Correct 77 out of 100
# Step 9911 Loss 0.4781232 Correct 83 out of 100
# Step 9912 Loss 0.5107991 Correct 78 out of 100
# Step 9913 Loss 0.8044328 Correct 63 out of 100
# Step 9914 Loss 0.95820636 Correct 57 out of 100
# Step 9915 Loss 0.6175668 Correct 68 out of 100
# Step 9916 Loss 0.47674972 Correct 69 out of 100
# Step 9917 Loss 0.5545349 Correct 67 out of 100
# Step 9918 Loss 0.43123373 Correct 85 out of 100
# Step 9919 Loss 0.43411604 Correct 80 out of 100
# Step 9920 Loss 0.47387865 Correct 81 out of 100
# Step 9921 Loss 0.5207889 Correct 78 out of 100
# Step 9922 Loss 0.43591562 Correct 76 out of 100
# Step 9923 Loss 0.36901027 Correct 83 out of 100
# Step 9924 Loss 0.5737221 Correct 69 out of 100
# Step 9925 Loss 0.5412705 Correct 75 out of 100
# Step 9926 Loss 0.5738731 Correct 77 out of 100
# Step 9927 Loss 0.4740071 Correct 82 out of 100
# Step 9928 Loss 0.51109684 Correct 77 out of 100
# Step 9929 Loss 0.34229025 Correct 85 out of 100
# Step 9930 Loss 0.38948196 Correct 85 out of 100
# Step 9931 Loss 0.5680305 Correct 75 out of 100
# Step 9932 Loss 0.35317108 Correct 87 out of 100
# Step 9933 Loss 0.37187147 Correct 86 out of 100
# Step 9934 Loss 0.85133666 Correct 70 out of 100
# Step 9935 Loss 0.6460007 Correct 71 out of 100
# Step 9936 Loss 0.605825 Correct 73 out of 100
# Step 9937 Loss 0.58119726 Correct 69 out of 100
# Step 9938 Loss 0.54450655 Correct 73 out of 100
# Step 9939 Loss 0.53672004 Correct 67 out of 100
# Step 9940 Loss 0.45229766 Correct 80 out of 100
# Step 9941 Loss 0.43362606 Correct 80 out of 100
# Step 9942 Loss 0.40824053 Correct 83 out of 100
# Step 9943 Loss 0.6360633 Correct 69 out of 100
# Step 9944 Loss 0.7227957 Correct 66 out of 100
# Step 9945 Loss 0.48780048 Correct 81 out of 100
# Step 9946 Loss 0.521449 Correct 76 out of 100
# Step 9947 Loss 0.5265506 Correct 77 out of 100
# Step 9948 Loss 0.58407915 Correct 70 out of 100
# Step 9949 Loss 0.5931158 Correct 75 out of 100
# Step 9950 Loss 0.52160835 Correct 75 out of 100
# Step 9951 Loss 0.47584036 Correct 80 out of 100
# Step 9952 Loss 0.3948066 Correct 86 out of 100
# Step 9953 Loss 0.4124759 Correct 85 out of 100
# Step 9954 Loss 0.46370304 Correct 79 out of 100
# Step 9955 Loss 0.50500757 Correct 72 out of 100
# Step 9956 Loss 0.5156861 Correct 74 out of 100
# Step 9957 Loss 0.41352066 Correct 80 out of 100
# Step 9958 Loss 0.42967826 Correct 82 out of 100
# Step 9959 Loss 0.5208702 Correct 78 out of 100
# Step 9960 Loss 0.33058333 Correct 89 out of 100
# Step 9961 Loss 0.38984475 Correct 82 out of 100
# Step 9962 Loss 0.35903484 Correct 86 out of 100
# Step 9963 Loss 0.55141765 Correct 72 out of 100
# Step 9964 Loss 0.5321716 Correct 84 out of 100
# Step 9965 Loss 0.4310118 Correct 78 out of 100
# Step 9966 Loss 0.38058913 Correct 84 out of 100
# Step 9967 Loss 0.50785935 Correct 79 out of 100
# Step 9968 Loss 0.39491683 Correct 83 out of 100
# Step 9969 Loss 0.43211752 Correct 80 out of 100
# Step 9970 Loss 0.40031195 Correct 90 out of 100
# Step 9971 Loss 0.444608 Correct 82 out of 100
# Step 9972 Loss 0.32624656 Correct 87 out of 100
# Step 9973 Loss 0.40750912 Correct 85 out of 100
# Step 9974 Loss 0.36422184 Correct 85 out of 100
# Step 9975 Loss 0.44182757 Correct 82 out of 100
# Step 9976 Loss 0.41254935 Correct 83 out of 100
# Step 9977 Loss 0.43680358 Correct 84 out of 100
# Step 9978 Loss 0.35693812 Correct 87 out of 100
# Step 9979 Loss 0.32312727 Correct 88 out of 100
# Step 9980 Loss 0.30781072 Correct 90 out of 100
# Step 9981 Loss 0.3449192 Correct 88 out of 100
# Step 9982 Loss 0.3618186 Correct 87 out of 100
# Step 9983 Loss 0.48873213 Correct 80 out of 100
# Step 9984 Loss 0.6531917 Correct 63 out of 100
# Step 9985 Loss 0.5182344 Correct 79 out of 100
# Step 9986 Loss 0.59795284 Correct 61 out of 100
# Step 9987 Loss 0.52257043 Correct 71 out of 100
# Step 9988 Loss 0.5212977 Correct 73 out of 100
# Step 9989 Loss 0.40009186 Correct 87 out of 100
# Step 9990 Loss 0.5173408 Correct 78 out of 100
# Step 9991 Loss 0.33670124 Correct 86 out of 100
# Step 9992 Loss 0.47481495 Correct 84 out of 100
# Step 9993 Loss 0.4333543 Correct 78 out of 100
# Step 9994 Loss 0.61992 Correct 72 out of 100
# Step 9995 Loss 0.5209721 Correct 72 out of 100
# Step 9996 Loss 0.5468529 Correct 74 out of 100
# Step 9997 Loss 0.29685688 Correct 88 out of 100
# Step 9998 Loss 0.518859 Correct 77 out of 100
# Step 9999 Loss 0.41926837 Correct 84 out of 100
# 2021-12-05 12:24:55.176513: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Loss for 3000 randomly chosen documents is  0.3361250162124634  number of correct labels is  2730  out of 3000

# %% [markdown]
# ## Task 3: Implementing a Feed-Forward Network
# - change the code so that it no longer implements an RNN, but instead it implements a simple feed-forward network with one hidden layer
# - For the RNN, our line of text representation was a matrix (a sequence of vectors, where each vector was a one-hot encoding of a character).
# - Now, our text representation will be a single vector, where each vector has all of the vectors encoding each of the characters, appended end-on-end. Note that I’ve already supplied you with a function that supplies minibatches of data in this format, so you can just use my function to create batches of training data for learning. All you need to do is to ﬁgure out how to modify the network to make use of this function.
# - this feed-forward network has even higher-accuracy than the RNN with time-warping. Probably better than a human could do!

# %%
hiddenUnits = 1000 # Reset number of hiddenUnit to 1000 from 500(for time warp)

# create the data dictionary
maxSeqLen = 0
data = {}

# load up the three data sets
(maxSeqLen, data) = addToData (maxSeqLen, data, "Holmes.txt", 0, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "war.txt", 1, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "william.txt", 2, 10000)

# pad each entry in the dictionary with empty characters as needed so
# that the sequences are all of the same length
# 裏面transpose變成 256 * maxSeqLen 的shape
data = pad (maxSeqLen, data)
allDataID = [i for i in range(len(data))]
# print(len(data))    25041
testDataID = random.sample(allDataID[0:8000], 1000) + random.sample(allDataID[10000:18000], 1000) + random.sample(allDataID[19500:], 1000)
trainDataID = list(set(allDataID) - set(testDataID))
data_train = dict()
data_test = dict()
for train_id in trainDataID:
    data_train[train_id] = data[train_id]
for test_id in testDataID:
    data_test[test_id] = data[test_id]

        
# now we build the TensorFlow computation... there are two inputs, 
# a batch of text lines and a batch of labels
inputX = tf.placeholder(tf.float32, [batchSize, 256 * maxSeqLen])
inputY = tf.placeholder(tf.int32, [batchSize])

# this is the inital state of the RNN, before processing any data
initialState = tf.placeholder(tf.float32, [batchSize, hiddenUnits])

# the weight matrix that maps the inputs and hidden state to a set of values
W = tf.Variable(np.random.normal(0, 0.05, (256 * maxSeqLen + hiddenUnits, hiddenUnits)), dtype=tf.float32)
print(f"shape of W: {W.shape}")

# biaes for the hidden values
b = tf.Variable(np.zeros((1, hiddenUnits)), dtype=tf.float32)

# weights and bias for the final classification
W2 = tf.Variable(np.random.normal (0, 0.05, (hiddenUnits, numClasses)),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,numClasses)), dtype=tf.float32)

# unpack the input sequences so that we have a series of matrices,
# each of which has a one-hot encoding of the current character from
# every input sequence
# sequenceOfLetters = tf.unstack(inputX, axis=2)

# now we implement the forward pass
currentState = initialState
inputPlusState = tf.concat([inputX, currentState], 1)     # shape: batchsize * (256 + hiddenUnits)
print(f"shape of inputPlusState: {inputPlusState.shape}")
next_state = tf.tanh(tf.matmul(inputPlusState, W) + b)      # W shape: (256 + hiddenUnits + hiddenUnits) * hiddenUnits
currentState = next_state
# for idx,timeTick in enumerate(sequenceOfLetters):
#     # concatenate the state with the input, then compute the next state
#     # Add time warpping -> append the state at t-10 as input
#     inputPlusState = tf.concat([timeTick, currentState], 1)     # shape: batchsize * (256 + hiddenUnits + hiddenUnits)
#     next_state = tf.tanh(tf.matmul(inputPlusState, W) + b)      # W shape: (256 + hiddenUnits + hiddenUnits) * hiddenUnits
#     currentState = next_state


# compute the set of outputs
outputs = tf.matmul(currentState, W2) + b2

predictions = tf.nn.softmax(outputs)

# compute the loss
losses = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=outputs, labels=inputY)
totalLoss = tf.reduce_mean(losses)  # take mean of losses

# use gradient descent to train
#trainingAlg = tf.train.GradientDescentOptimizer(0.02).minimize(totalLoss)
trainingAlg = tf.train.AdagradOptimizer(0.02).minimize(totalLoss)

# and train!!
with tf.Session() as sess:
    #
    # initialize everything
    sess.run(tf.global_variables_initializer())
    #
    # and run the training iters
    # _finalState = np.zeros((batchSize, hiddenUnits))
    for epoch in range(1000):
        # 
        # get some data
        x, y = generateDataFeedForward(maxSeqLen, data_train)

        #
        # do the training epoch
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _trainingAlg, _currentState, _predictions, _outputs = sess.run(
                [totalLoss, trainingAlg, currentState, predictions, outputs],
                feed_dict={
                    inputX:x,
                    inputY:y,
                    initialState:_currentState
                })

        #
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y)):
           maxPos = -1
           maxVal = 0.0
           for j in range (numClasses):
               if maxVal < _predictions[i][j]:
                   maxVal = _predictions[i][j]
                   maxPos = j
           if maxPos == y[i]:
               numCorrect = numCorrect + 1
        #
        # print out to the screen
        print("Step", epoch, "Loss", _totalLoss, "Correct", numCorrect, "out of", batchSize)


    
    # Testing
    _avgTestLoss = 0
    totalNumCorrect = 0
    x_test, y_test = generateDataFeedForward(maxSeqLen, data_test)
    _currentState = np.zeros((batchSize, hiddenUnits))
    for i in range(30):
        _testLoss, _testPredictions = sess.run([totalLoss, predictions], feed_dict = {
                            inputX:x_test,
                            inputY:y_test,
                            initialState:_currentState
                            })
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y_test)):
            maxPos = -1
            maxVal = 0.0
            for j in range (numClasses):
                if maxVal < _testPredictions[i][j]:
                    maxVal = _testPredictions[i][j]
                    maxPos = j
            if maxPos == y_test[i]:
                numCorrect = numCorrect + 1
        totalNumCorrect += numCorrect
        _avgTestLoss += _testLoss
        
    _avgTestLoss /= 30
    print("Loss for 3000 randomly chosen documents is ", _avgTestLoss, " number of correct labels is ", totalNumCorrect, " out of 3000")
# Out:
# /var/folders/76/0jylnbrx4p7_yl5fmv0d39yr0000gn/T/ipykernel_1203/2724516542.py:24: DeprecationWarning: This function is deprecated. Please call randint(0, 13051 + 1) instead
#   myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
# /var/folders/76/0jylnbrx4p7_yl5fmv0d39yr0000gn/T/ipykernel_1203/2724516542.py:24: DeprecationWarning: This function is deprecated. Please call randint(0, 65334 + 1) instead
#   myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
# /var/folders/76/0jylnbrx4p7_yl5fmv0d39yr0000gn/T/ipykernel_1203/2724516542.py:24: DeprecationWarning: This function is deprecated. Please call randint(0, 124795 + 1) instead
#   myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
# shape of W: (20968, 1000)
# shape of inputPlusState: (100, 20968)
# 2021-12-05 14:51:38.918137: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-12-05 14:51:38.918165: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-12-05 14:51:39.490422: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-12-05 14:51:45.252339: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Step 0 Loss 1.2389629 Correct 31 out of 100
# Step 1 Loss 1.1556064 Correct 41 out of 100
# Step 2 Loss 1.1692396 Correct 39 out of 100
# Step 3 Loss 1.2006941 Correct 35 out of 100
# Step 4 Loss 1.150702 Correct 35 out of 100
# Step 5 Loss 1.0554899 Correct 43 out of 100
# Step 6 Loss 1.1095992 Correct 40 out of 100
# Step 7 Loss 1.1090609 Correct 49 out of 100
# Step 8 Loss 1.1089151 Correct 39 out of 100
# Step 9 Loss 1.113307 Correct 43 out of 100
# Step 10 Loss 1.0816805 Correct 47 out of 100
# Step 11 Loss 1.0842494 Correct 46 out of 100
# Step 12 Loss 0.9850821 Correct 53 out of 100
# Step 13 Loss 0.9981682 Correct 53 out of 100
# Step 14 Loss 0.8927123 Correct 65 out of 100
# Step 15 Loss 0.9926849 Correct 50 out of 100
# Step 16 Loss 1.0413277 Correct 46 out of 100
# Step 17 Loss 0.9572999 Correct 55 out of 100
# Step 18 Loss 1.0111554 Correct 47 out of 100
# Step 19 Loss 0.96373504 Correct 53 out of 100
# Step 20 Loss 0.89880806 Correct 54 out of 100
# Step 21 Loss 0.9376332 Correct 55 out of 100
# Step 22 Loss 0.9427589 Correct 56 out of 100
# Step 23 Loss 0.9615153 Correct 49 out of 100
# Step 24 Loss 0.9367947 Correct 59 out of 100
# Step 25 Loss 0.9070831 Correct 53 out of 100
# Step 26 Loss 0.86385834 Correct 64 out of 100
# Step 27 Loss 0.95322937 Correct 55 out of 100
# Step 28 Loss 0.9503215 Correct 53 out of 100
# Step 29 Loss 0.84843135 Correct 69 out of 100
# Step 30 Loss 0.88573074 Correct 61 out of 100
# Step 31 Loss 0.8391014 Correct 60 out of 100
# Step 32 Loss 0.8887855 Correct 59 out of 100
# Step 33 Loss 0.8213298 Correct 67 out of 100
# Step 34 Loss 0.9225366 Correct 55 out of 100
# Step 35 Loss 0.8019764 Correct 68 out of 100
# Step 36 Loss 0.82557815 Correct 62 out of 100
# Step 37 Loss 0.86829716 Correct 64 out of 100
# Step 38 Loss 0.8400465 Correct 62 out of 100
# Step 39 Loss 0.7901222 Correct 69 out of 100
# Step 40 Loss 0.7967369 Correct 67 out of 100
# Step 41 Loss 0.8142554 Correct 68 out of 100
# Step 42 Loss 0.7557828 Correct 71 out of 100
# Step 43 Loss 0.8195344 Correct 68 out of 100
# Step 44 Loss 0.8243884 Correct 68 out of 100
# Step 45 Loss 0.7921762 Correct 66 out of 100
# Step 46 Loss 0.7068156 Correct 78 out of 100
# Step 47 Loss 0.79386216 Correct 63 out of 100
# Step 48 Loss 0.7477284 Correct 76 out of 100
# Step 49 Loss 0.8035522 Correct 68 out of 100
# Step 50 Loss 0.80988145 Correct 64 out of 100
# Step 51 Loss 0.7253007 Correct 70 out of 100
# Step 52 Loss 0.7035919 Correct 71 out of 100
# Step 53 Loss 0.77855045 Correct 69 out of 100
# Step 54 Loss 0.74408036 Correct 72 out of 100
# Step 55 Loss 0.6834091 Correct 75 out of 100
# Step 56 Loss 0.7464987 Correct 68 out of 100
# Step 57 Loss 0.64193463 Correct 79 out of 100
# Step 58 Loss 0.71087795 Correct 74 out of 100
# Step 59 Loss 0.741348 Correct 71 out of 100
# Step 60 Loss 0.740245 Correct 68 out of 100
# Step 61 Loss 0.77598476 Correct 65 out of 100
# Step 62 Loss 0.7304943 Correct 71 out of 100
# Step 63 Loss 0.6796009 Correct 70 out of 100
# Step 64 Loss 0.7377017 Correct 70 out of 100
# Step 65 Loss 0.77531266 Correct 68 out of 100
# Step 66 Loss 0.71397644 Correct 69 out of 100
# Step 67 Loss 0.6157519 Correct 81 out of 100
# Step 68 Loss 0.71846634 Correct 69 out of 100
# Step 69 Loss 0.70527947 Correct 79 out of 100
# Step 70 Loss 0.7055807 Correct 67 out of 100
# Step 71 Loss 0.7096484 Correct 75 out of 100
# Step 72 Loss 0.75076985 Correct 70 out of 100
# Step 73 Loss 0.74658537 Correct 65 out of 100
# Step 74 Loss 0.7068344 Correct 68 out of 100
# Step 75 Loss 0.71244985 Correct 75 out of 100
# Step 76 Loss 0.69351774 Correct 73 out of 100
# Step 77 Loss 0.6755391 Correct 78 out of 100
# Step 78 Loss 0.6727281 Correct 75 out of 100
# Step 79 Loss 0.67134553 Correct 74 out of 100
# Step 80 Loss 0.65014005 Correct 70 out of 100
# Step 81 Loss 0.71439177 Correct 70 out of 100
# Step 82 Loss 0.6563969 Correct 72 out of 100
# Step 83 Loss 0.646748 Correct 72 out of 100
# Step 84 Loss 0.63869154 Correct 82 out of 100
# Step 85 Loss 0.6373626 Correct 72 out of 100
# Step 86 Loss 0.75645906 Correct 63 out of 100
# Step 87 Loss 0.63037574 Correct 78 out of 100
# Step 88 Loss 0.55864227 Correct 79 out of 100
# Step 89 Loss 0.67175084 Correct 71 out of 100
# Step 90 Loss 0.57533956 Correct 81 out of 100
# Step 91 Loss 0.63520676 Correct 78 out of 100
# Step 92 Loss 0.66295373 Correct 74 out of 100
# Step 93 Loss 0.6741152 Correct 73 out of 100
# Step 94 Loss 0.64757144 Correct 77 out of 100
# Step 95 Loss 0.738248 Correct 71 out of 100
# Step 96 Loss 0.52571774 Correct 85 out of 100
# Step 97 Loss 0.5574861 Correct 79 out of 100
# Step 98 Loss 0.58324546 Correct 81 out of 100
# Step 99 Loss 0.62116945 Correct 80 out of 100
# Step 100 Loss 0.5799106 Correct 81 out of 100
# Step 101 Loss 0.6000376 Correct 77 out of 100
# Step 102 Loss 0.48301983 Correct 88 out of 100
# Step 103 Loss 0.58994406 Correct 81 out of 100
# Step 104 Loss 0.61600363 Correct 77 out of 100
# Step 105 Loss 0.7051701 Correct 72 out of 100
# Step 106 Loss 0.60879505 Correct 79 out of 100
# Step 107 Loss 0.6238847 Correct 74 out of 100
# Step 108 Loss 0.59023243 Correct 76 out of 100
# Step 109 Loss 0.584951 Correct 78 out of 100
# Step 110 Loss 0.5618493 Correct 77 out of 100
# Step 111 Loss 0.66466314 Correct 76 out of 100
# Step 112 Loss 0.5763999 Correct 77 out of 100
# Step 113 Loss 0.59932 Correct 82 out of 100
# Step 114 Loss 0.5460433 Correct 80 out of 100
# Step 115 Loss 0.5541759 Correct 82 out of 100
# Step 116 Loss 0.7028885 Correct 72 out of 100
# Step 117 Loss 0.54431725 Correct 86 out of 100
# Step 118 Loss 0.55315447 Correct 84 out of 100
# Step 119 Loss 0.5841214 Correct 80 out of 100
# Step 120 Loss 0.6312614 Correct 79 out of 100
# Step 121 Loss 0.55018616 Correct 83 out of 100
# Step 122 Loss 0.5605558 Correct 77 out of 100
# Step 123 Loss 0.5639381 Correct 83 out of 100
# Step 124 Loss 0.60130215 Correct 77 out of 100
# Step 125 Loss 0.58334565 Correct 79 out of 100
# Step 126 Loss 0.4328075 Correct 90 out of 100
# Step 127 Loss 0.5178797 Correct 85 out of 100
# Step 128 Loss 0.5637846 Correct 83 out of 100
# Step 129 Loss 0.5935975 Correct 73 out of 100
# Step 130 Loss 0.5362056 Correct 84 out of 100
# Step 131 Loss 0.5512714 Correct 81 out of 100
# Step 132 Loss 0.5777959 Correct 77 out of 100
# Step 133 Loss 0.5804668 Correct 79 out of 100
# Step 134 Loss 0.55110055 Correct 78 out of 100
# Step 135 Loss 0.51066864 Correct 86 out of 100
# Step 136 Loss 0.5748626 Correct 79 out of 100
# Step 137 Loss 0.5115479 Correct 87 out of 100
# Step 138 Loss 0.5405066 Correct 78 out of 100
# Step 139 Loss 0.5135431 Correct 81 out of 100
# Step 140 Loss 0.49829185 Correct 85 out of 100
# Step 141 Loss 0.5043706 Correct 84 out of 100
# Step 142 Loss 0.5118779 Correct 84 out of 100
# Step 143 Loss 0.47188997 Correct 86 out of 100
# Step 144 Loss 0.54164857 Correct 83 out of 100
# Step 145 Loss 0.5779324 Correct 77 out of 100
# Step 146 Loss 0.47339812 Correct 86 out of 100
# Step 147 Loss 0.5042043 Correct 86 out of 100
# Step 148 Loss 0.54295963 Correct 82 out of 100
# Step 149 Loss 0.4375432 Correct 86 out of 100
# Step 150 Loss 0.5483895 Correct 82 out of 100
# Step 151 Loss 0.5615256 Correct 80 out of 100
# Step 152 Loss 0.5234248 Correct 79 out of 100
# Step 153 Loss 0.49203414 Correct 82 out of 100
# Step 154 Loss 0.4561325 Correct 86 out of 100
# Step 155 Loss 0.5588386 Correct 77 out of 100
# Step 156 Loss 0.558999 Correct 84 out of 100
# Step 157 Loss 0.51116174 Correct 82 out of 100
# Step 158 Loss 0.49327925 Correct 83 out of 100
# Step 159 Loss 0.55299985 Correct 78 out of 100
# Step 160 Loss 0.49509338 Correct 86 out of 100
# Step 161 Loss 0.4747154 Correct 85 out of 100
# Step 162 Loss 0.5098701 Correct 83 out of 100
# Step 163 Loss 0.5383978 Correct 79 out of 100
# Step 164 Loss 0.538552 Correct 79 out of 100
# Step 165 Loss 0.48766395 Correct 86 out of 100
# Step 166 Loss 0.5454567 Correct 79 out of 100
# Step 167 Loss 0.43959835 Correct 90 out of 100
# Step 168 Loss 0.4955255 Correct 81 out of 100
# Step 169 Loss 0.5509034 Correct 78 out of 100
# Step 170 Loss 0.4574976 Correct 88 out of 100
# Step 171 Loss 0.48473823 Correct 86 out of 100
# Step 172 Loss 0.46483707 Correct 87 out of 100
# Step 173 Loss 0.4677802 Correct 83 out of 100
# Step 174 Loss 0.47815016 Correct 83 out of 100
# Step 175 Loss 0.52794546 Correct 80 out of 100
# Step 176 Loss 0.49576584 Correct 82 out of 100
# Step 177 Loss 0.5154807 Correct 82 out of 100
# Step 178 Loss 0.5329433 Correct 81 out of 100
# Step 179 Loss 0.51610005 Correct 84 out of 100
# Step 180 Loss 0.48839313 Correct 84 out of 100
# Step 181 Loss 0.46195418 Correct 85 out of 100
# Step 182 Loss 0.39556313 Correct 87 out of 100
# Step 183 Loss 0.49279124 Correct 84 out of 100
# Step 184 Loss 0.4347389 Correct 84 out of 100
# Step 185 Loss 0.47430903 Correct 83 out of 100
# Step 186 Loss 0.48221642 Correct 81 out of 100
# Step 187 Loss 0.40239543 Correct 87 out of 100
# Step 188 Loss 0.4189374 Correct 86 out of 100
# Step 189 Loss 0.4749421 Correct 82 out of 100
# Step 190 Loss 0.46221778 Correct 85 out of 100
# Step 191 Loss 0.52308613 Correct 80 out of 100
# Step 192 Loss 0.3731646 Correct 92 out of 100
# Step 193 Loss 0.39886793 Correct 85 out of 100
# Step 194 Loss 0.4892207 Correct 81 out of 100
# Step 195 Loss 0.4302889 Correct 85 out of 100
# Step 196 Loss 0.5388645 Correct 85 out of 100
# Step 197 Loss 0.5190278 Correct 80 out of 100
# Step 198 Loss 0.50275004 Correct 79 out of 100
# Step 199 Loss 0.53453237 Correct 86 out of 100
# Step 200 Loss 0.4517252 Correct 83 out of 100
# Step 201 Loss 0.45788038 Correct 85 out of 100
# Step 202 Loss 0.49468163 Correct 87 out of 100
# Step 203 Loss 0.4229502 Correct 85 out of 100
# Step 204 Loss 0.411677 Correct 88 out of 100
# Step 205 Loss 0.45962858 Correct 83 out of 100
# Step 206 Loss 0.47392982 Correct 83 out of 100
# Step 207 Loss 0.5117169 Correct 81 out of 100
# Step 208 Loss 0.41281894 Correct 89 out of 100
# Step 209 Loss 0.54856133 Correct 79 out of 100
# Step 210 Loss 0.46724463 Correct 87 out of 100
# Step 211 Loss 0.47818285 Correct 79 out of 100
# Step 212 Loss 0.4879419 Correct 85 out of 100
# Step 213 Loss 0.44516692 Correct 83 out of 100
# Step 214 Loss 0.43807936 Correct 88 out of 100
# Step 215 Loss 0.481806 Correct 85 out of 100
# Step 216 Loss 0.37512848 Correct 90 out of 100
# Step 217 Loss 0.50450987 Correct 84 out of 100
# Step 218 Loss 0.48044872 Correct 83 out of 100
# Step 219 Loss 0.44204223 Correct 82 out of 100
# Step 220 Loss 0.37862152 Correct 88 out of 100
# Step 221 Loss 0.3939598 Correct 86 out of 100
# Step 222 Loss 0.43617865 Correct 85 out of 100
# Step 223 Loss 0.570034 Correct 78 out of 100
# Step 224 Loss 0.35996866 Correct 92 out of 100
# Step 225 Loss 0.4251874 Correct 89 out of 100
# Step 226 Loss 0.46898067 Correct 85 out of 100
# Step 227 Loss 0.47607598 Correct 86 out of 100
# Step 228 Loss 0.40420836 Correct 84 out of 100
# Step 229 Loss 0.43748808 Correct 84 out of 100
# Step 230 Loss 0.4103108 Correct 86 out of 100
# Step 231 Loss 0.40025836 Correct 90 out of 100
# Step 232 Loss 0.43141487 Correct 82 out of 100
# Step 233 Loss 0.47561646 Correct 80 out of 100
# Step 234 Loss 0.45572525 Correct 80 out of 100
# Step 235 Loss 0.480841 Correct 83 out of 100
# Step 236 Loss 0.40306145 Correct 90 out of 100
# Step 237 Loss 0.46844652 Correct 81 out of 100
# Step 238 Loss 0.4899409 Correct 84 out of 100
# Step 239 Loss 0.4211148 Correct 79 out of 100
# Step 240 Loss 0.56939673 Correct 81 out of 100
# Step 241 Loss 0.43458846 Correct 88 out of 100
# Step 242 Loss 0.3421305 Correct 91 out of 100
# Step 243 Loss 0.3762146 Correct 89 out of 100
# Step 244 Loss 0.47212824 Correct 80 out of 100
# Step 245 Loss 0.44563857 Correct 83 out of 100
# Step 246 Loss 0.31293547 Correct 94 out of 100
# Step 247 Loss 0.41217172 Correct 87 out of 100
# Step 248 Loss 0.4592998 Correct 85 out of 100
# Step 249 Loss 0.44895172 Correct 84 out of 100
# Step 250 Loss 0.5371235 Correct 89 out of 100
# Step 251 Loss 0.4607479 Correct 82 out of 100
# Step 252 Loss 0.48781988 Correct 80 out of 100
# Step 253 Loss 0.3996296 Correct 92 out of 100
# Step 254 Loss 0.41657937 Correct 84 out of 100
# Step 255 Loss 0.34804764 Correct 87 out of 100
# Step 256 Loss 0.3938916 Correct 88 out of 100
# Step 257 Loss 0.4394395 Correct 83 out of 100
# Step 258 Loss 0.4903508 Correct 81 out of 100
# Step 259 Loss 0.35943183 Correct 91 out of 100
# Step 260 Loss 0.4857159 Correct 84 out of 100
# Step 261 Loss 0.3886152 Correct 90 out of 100
# Step 262 Loss 0.3134162 Correct 93 out of 100
# Step 263 Loss 0.46141726 Correct 85 out of 100
# Step 264 Loss 0.4525017 Correct 83 out of 100
# Step 265 Loss 0.37249708 Correct 91 out of 100
# Step 266 Loss 0.3863027 Correct 88 out of 100
# Step 267 Loss 0.3626496 Correct 88 out of 100
# Step 268 Loss 0.3924896 Correct 89 out of 100
# Step 269 Loss 0.35164154 Correct 89 out of 100
# Step 270 Loss 0.39908448 Correct 88 out of 100
# Step 271 Loss 0.46094164 Correct 87 out of 100
# Step 272 Loss 0.38369894 Correct 86 out of 100
# Step 273 Loss 0.41082317 Correct 86 out of 100
# Step 274 Loss 0.39169875 Correct 88 out of 100
# Step 275 Loss 0.4475531 Correct 86 out of 100
# Step 276 Loss 0.37325326 Correct 87 out of 100
# Step 277 Loss 0.36701888 Correct 89 out of 100
# Step 278 Loss 0.39024872 Correct 86 out of 100
# Step 279 Loss 0.39215228 Correct 87 out of 100
# Step 280 Loss 0.35956725 Correct 89 out of 100
# Step 281 Loss 0.48615205 Correct 84 out of 100
# Step 282 Loss 0.36683288 Correct 87 out of 100
# Step 283 Loss 0.39915267 Correct 89 out of 100
# Step 284 Loss 0.33860785 Correct 92 out of 100
# Step 285 Loss 0.48504683 Correct 82 out of 100
# Step 286 Loss 0.40538406 Correct 89 out of 100
# Step 287 Loss 0.34441504 Correct 88 out of 100
# Step 288 Loss 0.40605795 Correct 90 out of 100
# Step 289 Loss 0.43145546 Correct 85 out of 100
# Step 290 Loss 0.41019425 Correct 86 out of 100
# Step 291 Loss 0.3554516 Correct 86 out of 100
# Step 292 Loss 0.3154717 Correct 92 out of 100
# Step 293 Loss 0.4487712 Correct 84 out of 100
# Step 294 Loss 0.41335663 Correct 89 out of 100
# Step 295 Loss 0.3339207 Correct 93 out of 100
# Step 296 Loss 0.41552386 Correct 87 out of 100
# Step 297 Loss 0.33053765 Correct 89 out of 100
# Step 298 Loss 0.44901016 Correct 82 out of 100
# Step 299 Loss 0.47339392 Correct 86 out of 100
# Step 300 Loss 0.35423923 Correct 89 out of 100
# Step 301 Loss 0.39376557 Correct 84 out of 100
# Step 302 Loss 0.33431664 Correct 90 out of 100
# Step 303 Loss 0.46170864 Correct 80 out of 100
# Step 304 Loss 0.36178905 Correct 91 out of 100
# Step 305 Loss 0.34366408 Correct 92 out of 100
# Step 306 Loss 0.42924717 Correct 82 out of 100
# Step 307 Loss 0.28684914 Correct 93 out of 100
# Step 308 Loss 0.41082594 Correct 85 out of 100
# Step 309 Loss 0.30690372 Correct 88 out of 100
# Step 310 Loss 0.35522705 Correct 90 out of 100
# Step 311 Loss 0.41759306 Correct 88 out of 100
# Step 312 Loss 0.35724068 Correct 89 out of 100
# Step 313 Loss 0.43138984 Correct 85 out of 100
# Step 314 Loss 0.33847517 Correct 91 out of 100
# Step 315 Loss 0.35774615 Correct 89 out of 100
# Step 316 Loss 0.37122923 Correct 86 out of 100
# Step 317 Loss 0.3512512 Correct 88 out of 100
# Step 318 Loss 0.30658895 Correct 88 out of 100
# Step 319 Loss 0.3447998 Correct 91 out of 100
# Step 320 Loss 0.3384198 Correct 85 out of 100
# Step 321 Loss 0.5040109 Correct 80 out of 100
# Step 322 Loss 0.36223182 Correct 89 out of 100
# Step 323 Loss 0.37748542 Correct 88 out of 100
# Step 324 Loss 0.41409042 Correct 85 out of 100
# Step 325 Loss 0.31345907 Correct 91 out of 100
# Step 326 Loss 0.31692863 Correct 92 out of 100
# Step 327 Loss 0.37420312 Correct 88 out of 100
# Step 328 Loss 0.460307 Correct 81 out of 100
# Step 329 Loss 0.35515615 Correct 87 out of 100
# Step 330 Loss 0.3991729 Correct 83 out of 100
# Step 331 Loss 0.35451645 Correct 84 out of 100
# Step 332 Loss 0.3583865 Correct 90 out of 100
# Step 333 Loss 0.3558226 Correct 86 out of 100
# Step 334 Loss 0.42791542 Correct 85 out of 100
# Step 335 Loss 0.3288185 Correct 89 out of 100
# Step 336 Loss 0.4103311 Correct 90 out of 100
# Step 337 Loss 0.3553567 Correct 87 out of 100
# Step 338 Loss 0.31064245 Correct 94 out of 100
# Step 339 Loss 0.2901521 Correct 91 out of 100
# Step 340 Loss 0.31167594 Correct 91 out of 100
# Step 341 Loss 0.411285 Correct 88 out of 100
# Step 342 Loss 0.40130064 Correct 87 out of 100
# Step 343 Loss 0.30532774 Correct 91 out of 100
# Step 344 Loss 0.31297863 Correct 93 out of 100
# Step 345 Loss 0.2976768 Correct 93 out of 100
# Step 346 Loss 0.37869802 Correct 89 out of 100
# Step 347 Loss 0.28742015 Correct 94 out of 100
# Step 348 Loss 0.44403493 Correct 86 out of 100
# Step 349 Loss 0.40240157 Correct 88 out of 100
# Step 350 Loss 0.47384956 Correct 82 out of 100
# Step 351 Loss 0.34729093 Correct 87 out of 100
# Step 352 Loss 0.3170397 Correct 92 out of 100
# Step 353 Loss 0.28404352 Correct 93 out of 100
# Step 354 Loss 0.3127522 Correct 88 out of 100
# Step 355 Loss 0.24170737 Correct 93 out of 100
# Step 356 Loss 0.44464758 Correct 81 out of 100
# Step 357 Loss 0.35002878 Correct 89 out of 100
# Step 358 Loss 0.34943363 Correct 88 out of 100
# Step 359 Loss 0.3313533 Correct 89 out of 100
# Step 360 Loss 0.29680946 Correct 93 out of 100
# Step 361 Loss 0.32928056 Correct 89 out of 100
# Step 362 Loss 0.3724896 Correct 84 out of 100
# Step 363 Loss 0.28366652 Correct 92 out of 100
# Step 364 Loss 0.3697122 Correct 86 out of 100
# Step 365 Loss 0.38806522 Correct 86 out of 100
# Step 366 Loss 0.31428605 Correct 86 out of 100
# Step 367 Loss 0.33534813 Correct 89 out of 100
# Step 368 Loss 0.30318397 Correct 92 out of 100
# Step 369 Loss 0.2681706 Correct 92 out of 100
# Step 370 Loss 0.32823357 Correct 93 out of 100
# Step 371 Loss 0.36076248 Correct 90 out of 100
# Step 372 Loss 0.3092242 Correct 93 out of 100
# Step 373 Loss 0.27391085 Correct 93 out of 100
# Step 374 Loss 0.34925482 Correct 91 out of 100
# Step 375 Loss 0.31746522 Correct 91 out of 100
# Step 376 Loss 0.3141023 Correct 92 out of 100
# Step 377 Loss 0.29700717 Correct 90 out of 100
# Step 378 Loss 0.43427032 Correct 84 out of 100
# Step 379 Loss 0.31365484 Correct 92 out of 100
# Step 380 Loss 0.32277578 Correct 90 out of 100
# Step 381 Loss 0.35791263 Correct 89 out of 100
# Step 382 Loss 0.34660065 Correct 90 out of 100
# Step 383 Loss 0.29925042 Correct 91 out of 100
# Step 384 Loss 0.38792768 Correct 89 out of 100
# Step 385 Loss 0.31877646 Correct 90 out of 100
# Step 386 Loss 0.33478445 Correct 88 out of 100
# Step 387 Loss 0.35711098 Correct 87 out of 100
# Step 388 Loss 0.4095668 Correct 87 out of 100
# Step 389 Loss 0.34982634 Correct 92 out of 100
# Step 390 Loss 0.38567382 Correct 88 out of 100
# Step 391 Loss 0.3505886 Correct 91 out of 100
# Step 392 Loss 0.31330734 Correct 90 out of 100
# Step 393 Loss 0.43758202 Correct 86 out of 100
# Step 394 Loss 0.37697005 Correct 89 out of 100
# Step 395 Loss 0.31114745 Correct 92 out of 100
# Step 396 Loss 0.31599388 Correct 91 out of 100
# Step 397 Loss 0.38859144 Correct 86 out of 100
# Step 398 Loss 0.35787827 Correct 90 out of 100
# Step 399 Loss 0.40489563 Correct 85 out of 100
# Step 400 Loss 0.30699205 Correct 90 out of 100
# Step 401 Loss 0.30618125 Correct 89 out of 100
# Step 402 Loss 0.35706466 Correct 86 out of 100
# Step 403 Loss 0.359325 Correct 85 out of 100
# Step 404 Loss 0.28875956 Correct 90 out of 100
# Step 405 Loss 0.37868276 Correct 86 out of 100
# Step 406 Loss 0.35432017 Correct 86 out of 100
# Step 407 Loss 0.32154456 Correct 89 out of 100
# Step 408 Loss 0.4330101 Correct 88 out of 100
# Step 409 Loss 0.31391868 Correct 92 out of 100
# Step 410 Loss 0.32880268 Correct 88 out of 100
# Step 411 Loss 0.3662976 Correct 86 out of 100
# Step 412 Loss 0.4639047 Correct 83 out of 100
# Step 413 Loss 0.23890924 Correct 94 out of 100
# Step 414 Loss 0.32619828 Correct 87 out of 100
# Step 415 Loss 0.3630242 Correct 89 out of 100
# Step 416 Loss 0.2742644 Correct 94 out of 100
# Step 417 Loss 0.37010023 Correct 86 out of 100
# Step 418 Loss 0.3336588 Correct 89 out of 100
# Step 419 Loss 0.40988818 Correct 89 out of 100
# Step 420 Loss 0.26787013 Correct 93 out of 100
# Step 421 Loss 0.30784008 Correct 89 out of 100
# Step 422 Loss 0.3656157 Correct 90 out of 100
# Step 423 Loss 0.37602895 Correct 87 out of 100
# Step 424 Loss 0.38073647 Correct 90 out of 100
# Step 425 Loss 0.36981234 Correct 88 out of 100
# Step 426 Loss 0.25685436 Correct 95 out of 100
# Step 427 Loss 0.29209432 Correct 91 out of 100
# Step 428 Loss 0.44578475 Correct 84 out of 100
# Step 429 Loss 0.33145863 Correct 89 out of 100
# Step 430 Loss 0.37213448 Correct 88 out of 100
# Step 431 Loss 0.35485893 Correct 89 out of 100
# Step 432 Loss 0.2898873 Correct 89 out of 100
# Step 433 Loss 0.28826264 Correct 92 out of 100
# Step 434 Loss 0.32870096 Correct 89 out of 100
# Step 435 Loss 0.43601653 Correct 87 out of 100
# Step 436 Loss 0.41087332 Correct 85 out of 100
# Step 437 Loss 0.30362967 Correct 92 out of 100
# Step 438 Loss 0.21488993 Correct 95 out of 100
# Step 439 Loss 0.35466987 Correct 89 out of 100
# Step 440 Loss 0.29959655 Correct 92 out of 100
# Step 441 Loss 0.2884123 Correct 93 out of 100
# Step 442 Loss 0.38867614 Correct 87 out of 100
# Step 443 Loss 0.27793482 Correct 90 out of 100
# Step 444 Loss 0.5106067 Correct 84 out of 100
# Step 445 Loss 0.31886584 Correct 90 out of 100
# Step 446 Loss 0.2402349 Correct 96 out of 100
# Step 447 Loss 0.40458998 Correct 84 out of 100
# Step 448 Loss 0.29090884 Correct 92 out of 100
# Step 449 Loss 0.3667575 Correct 88 out of 100
# Step 450 Loss 0.319956 Correct 88 out of 100
# Step 451 Loss 0.29802546 Correct 92 out of 100
# Step 452 Loss 0.36576667 Correct 86 out of 100
# Step 453 Loss 0.38321853 Correct 90 out of 100
# Step 454 Loss 0.32694054 Correct 89 out of 100
# Step 455 Loss 0.36587223 Correct 89 out of 100
# Step 456 Loss 0.27278316 Correct 92 out of 100
# Step 457 Loss 0.38132578 Correct 85 out of 100
# Step 458 Loss 0.35851723 Correct 86 out of 100
# Step 459 Loss 0.3473924 Correct 87 out of 100
# Step 460 Loss 0.29280886 Correct 87 out of 100
# Step 461 Loss 0.2806424 Correct 91 out of 100
# Step 462 Loss 0.2963741 Correct 90 out of 100
# Step 463 Loss 0.26871836 Correct 92 out of 100
# Step 464 Loss 0.3592919 Correct 90 out of 100
# Step 465 Loss 0.33189207 Correct 91 out of 100
# Step 466 Loss 0.30415717 Correct 92 out of 100
# Step 467 Loss 0.426255 Correct 84 out of 100
# Step 468 Loss 0.24517141 Correct 94 out of 100
# Step 469 Loss 0.26043728 Correct 94 out of 100
# Step 470 Loss 0.22404064 Correct 95 out of 100
# Step 471 Loss 0.21933952 Correct 95 out of 100
# Step 472 Loss 0.27657738 Correct 93 out of 100
# Step 473 Loss 0.30976507 Correct 88 out of 100
# Step 474 Loss 0.4449313 Correct 82 out of 100
# Step 475 Loss 0.23903142 Correct 94 out of 100
# Step 476 Loss 0.34631708 Correct 87 out of 100
# Step 477 Loss 0.30633855 Correct 93 out of 100
# Step 478 Loss 0.23580842 Correct 93 out of 100
# Step 479 Loss 0.307396 Correct 89 out of 100
# Step 480 Loss 0.22910942 Correct 96 out of 100
# Step 481 Loss 0.34339863 Correct 89 out of 100
# Step 482 Loss 0.30288714 Correct 90 out of 100
# Step 483 Loss 0.23618011 Correct 94 out of 100
# Step 484 Loss 0.26990032 Correct 92 out of 100
# Step 485 Loss 0.35149276 Correct 84 out of 100
# Step 486 Loss 0.35330954 Correct 91 out of 100
# Step 487 Loss 0.26835278 Correct 89 out of 100
# Step 488 Loss 0.2775346 Correct 88 out of 100
# Step 489 Loss 0.2963923 Correct 91 out of 100
# Step 490 Loss 0.36200586 Correct 90 out of 100
# Step 491 Loss 0.36461946 Correct 86 out of 100
# Step 492 Loss 0.26629636 Correct 92 out of 100
# Step 493 Loss 0.34862366 Correct 89 out of 100
# Step 494 Loss 0.25506517 Correct 94 out of 100
# Step 495 Loss 0.35343572 Correct 89 out of 100
# Step 496 Loss 0.21263497 Correct 95 out of 100
# Step 497 Loss 0.38285613 Correct 88 out of 100
# Step 498 Loss 0.27537256 Correct 92 out of 100
# Step 499 Loss 0.35123923 Correct 86 out of 100
# Step 500 Loss 0.29498902 Correct 89 out of 100
# Step 501 Loss 0.37395626 Correct 84 out of 100
# Step 502 Loss 0.24845049 Correct 93 out of 100
# Step 503 Loss 0.32585368 Correct 89 out of 100
# Step 504 Loss 0.33384857 Correct 86 out of 100
# Step 505 Loss 0.3157649 Correct 88 out of 100
# Step 506 Loss 0.40258682 Correct 89 out of 100
# Step 507 Loss 0.3714533 Correct 87 out of 100
# Step 508 Loss 0.3276303 Correct 88 out of 100
# Step 509 Loss 0.36260387 Correct 90 out of 100
# Step 510 Loss 0.3205274 Correct 88 out of 100
# Step 511 Loss 0.32921737 Correct 89 out of 100
# Step 512 Loss 0.3288115 Correct 87 out of 100
# Step 513 Loss 0.34428832 Correct 89 out of 100
# Step 514 Loss 0.27947965 Correct 92 out of 100
# Step 515 Loss 0.24653125 Correct 93 out of 100
# Step 516 Loss 0.20226993 Correct 97 out of 100
# Step 517 Loss 0.2997407 Correct 89 out of 100
# Step 518 Loss 0.31376538 Correct 88 out of 100
# Step 519 Loss 0.30370605 Correct 87 out of 100
# Step 520 Loss 0.30840364 Correct 87 out of 100
# Step 521 Loss 0.24431953 Correct 92 out of 100
# Step 522 Loss 0.3639919 Correct 90 out of 100
# Step 523 Loss 0.275311 Correct 93 out of 100
# Step 524 Loss 0.27384588 Correct 91 out of 100
# Step 525 Loss 0.30981186 Correct 88 out of 100
# Step 526 Loss 0.34040314 Correct 90 out of 100
# Step 527 Loss 0.2521563 Correct 90 out of 100
# Step 528 Loss 0.28939945 Correct 89 out of 100
# Step 529 Loss 0.28913075 Correct 89 out of 100
# Step 530 Loss 0.36039314 Correct 90 out of 100
# Step 531 Loss 0.3473071 Correct 89 out of 100
# Step 532 Loss 0.24175684 Correct 96 out of 100
# Step 533 Loss 0.29983073 Correct 88 out of 100
# Step 534 Loss 0.28693694 Correct 91 out of 100
# Step 535 Loss 0.2688959 Correct 88 out of 100
# Step 536 Loss 0.4287066 Correct 82 out of 100
# Step 537 Loss 0.50425225 Correct 85 out of 100
# Step 538 Loss 0.29187685 Correct 90 out of 100
# Step 539 Loss 0.4407071 Correct 88 out of 100
# Step 540 Loss 0.25199556 Correct 91 out of 100
# Step 541 Loss 0.3631926 Correct 87 out of 100
# Step 542 Loss 0.25168908 Correct 93 out of 100
# Step 543 Loss 0.30936188 Correct 90 out of 100
# Step 544 Loss 0.3562027 Correct 86 out of 100
# Step 545 Loss 0.28880012 Correct 93 out of 100
# Step 546 Loss 0.31483626 Correct 91 out of 100
# Step 547 Loss 0.29112467 Correct 89 out of 100
# Step 548 Loss 0.32126868 Correct 91 out of 100
# Step 549 Loss 0.21442291 Correct 95 out of 100
# Step 550 Loss 0.24923408 Correct 90 out of 100
# Step 551 Loss 0.3144426 Correct 87 out of 100
# Step 552 Loss 0.29450443 Correct 91 out of 100
# Step 553 Loss 0.3864301 Correct 87 out of 100
# Step 554 Loss 0.23787972 Correct 94 out of 100
# Step 555 Loss 0.3105218 Correct 91 out of 100
# Step 556 Loss 0.28280511 Correct 91 out of 100
# Step 557 Loss 0.2846815 Correct 88 out of 100
# Step 558 Loss 0.23724128 Correct 93 out of 100
# Step 559 Loss 0.34323943 Correct 87 out of 100
# Step 560 Loss 0.29900634 Correct 90 out of 100
# Step 561 Loss 0.3298574 Correct 92 out of 100
# Step 562 Loss 0.27394783 Correct 92 out of 100
# Step 563 Loss 0.34919247 Correct 88 out of 100
# Step 564 Loss 0.3593238 Correct 95 out of 100
# Step 565 Loss 0.27418673 Correct 94 out of 100
# Step 566 Loss 0.18730465 Correct 97 out of 100
# Step 567 Loss 0.313889 Correct 90 out of 100
# Step 568 Loss 0.31707835 Correct 88 out of 100
# Step 569 Loss 0.3273024 Correct 89 out of 100
# Step 570 Loss 0.34016243 Correct 86 out of 100
# Step 571 Loss 0.36715958 Correct 88 out of 100
# Step 572 Loss 0.33571577 Correct 89 out of 100
# Step 573 Loss 0.30199757 Correct 89 out of 100
# Step 574 Loss 0.22848815 Correct 93 out of 100
# Step 575 Loss 0.27434054 Correct 89 out of 100
# Step 576 Loss 0.2627235 Correct 92 out of 100
# Step 577 Loss 0.3086404 Correct 92 out of 100
# Step 578 Loss 0.30482095 Correct 90 out of 100
# Step 579 Loss 0.26815197 Correct 93 out of 100
# Step 580 Loss 0.27018777 Correct 92 out of 100
# Step 581 Loss 0.25571296 Correct 92 out of 100
# Step 582 Loss 0.23132204 Correct 95 out of 100
# Step 583 Loss 0.25136283 Correct 92 out of 100
# Step 584 Loss 0.22958533 Correct 94 out of 100
# Step 585 Loss 0.22899948 Correct 95 out of 100
# Step 586 Loss 0.30655837 Correct 95 out of 100
# Step 587 Loss 0.25870994 Correct 89 out of 100
# Step 588 Loss 0.22021057 Correct 91 out of 100
# Step 589 Loss 0.23392145 Correct 91 out of 100
# Step 590 Loss 0.20961559 Correct 93 out of 100
# Step 591 Loss 0.21727897 Correct 95 out of 100
# Step 592 Loss 0.3215343 Correct 90 out of 100
# Step 593 Loss 0.26510403 Correct 92 out of 100
# Step 594 Loss 0.30007586 Correct 90 out of 100
# Step 595 Loss 0.3567482 Correct 92 out of 100
# Step 596 Loss 0.34099764 Correct 90 out of 100
# Step 597 Loss 0.32631218 Correct 89 out of 100
# Step 598 Loss 0.31696597 Correct 93 out of 100
# Step 599 Loss 0.33203155 Correct 87 out of 100
# Step 600 Loss 0.39929587 Correct 84 out of 100
# Step 601 Loss 0.2692465 Correct 90 out of 100
# Step 602 Loss 0.37076545 Correct 86 out of 100
# Step 603 Loss 0.25323108 Correct 91 out of 100
# Step 604 Loss 0.2871228 Correct 90 out of 100
# Step 605 Loss 0.22117515 Correct 94 out of 100
# Step 606 Loss 0.32097504 Correct 90 out of 100
# Step 607 Loss 0.33151075 Correct 88 out of 100
# Step 608 Loss 0.26794422 Correct 91 out of 100
# Step 609 Loss 0.2507886 Correct 91 out of 100
# Step 610 Loss 0.23457107 Correct 92 out of 100
# Step 611 Loss 0.22538297 Correct 94 out of 100
# Step 612 Loss 0.30503336 Correct 92 out of 100
# Step 613 Loss 0.32537788 Correct 89 out of 100
# Step 614 Loss 0.32912683 Correct 86 out of 100
# Step 615 Loss 0.3895016 Correct 85 out of 100
# Step 616 Loss 0.24552816 Correct 91 out of 100
# Step 617 Loss 0.27697268 Correct 90 out of 100
# Step 618 Loss 0.2294915 Correct 91 out of 100
# Step 619 Loss 0.34921524 Correct 89 out of 100
# Step 620 Loss 0.1991585 Correct 96 out of 100
# Step 621 Loss 0.26697323 Correct 90 out of 100
# Step 622 Loss 0.26343796 Correct 91 out of 100
# Step 623 Loss 0.29422018 Correct 87 out of 100
# Step 624 Loss 0.3623279 Correct 86 out of 100
# Step 625 Loss 0.19620521 Correct 94 out of 100
# Step 626 Loss 0.30071932 Correct 90 out of 100
# Step 627 Loss 0.2997079 Correct 90 out of 100
# Step 628 Loss 0.2395632 Correct 92 out of 100
# Step 629 Loss 0.22508256 Correct 95 out of 100
# Step 630 Loss 0.2407664 Correct 93 out of 100
# Step 631 Loss 0.21924905 Correct 96 out of 100
# Step 632 Loss 0.28281626 Correct 92 out of 100
# Step 633 Loss 0.32440346 Correct 86 out of 100
# Step 634 Loss 0.29613185 Correct 90 out of 100
# Step 635 Loss 0.26783827 Correct 94 out of 100
# Step 636 Loss 0.24223228 Correct 93 out of 100
# Step 637 Loss 0.21237938 Correct 93 out of 100
# Step 638 Loss 0.24058594 Correct 91 out of 100
# Step 639 Loss 0.30803818 Correct 89 out of 100
# Step 640 Loss 0.26156518 Correct 91 out of 100
# Step 641 Loss 0.21653932 Correct 94 out of 100
# Step 642 Loss 0.23169178 Correct 91 out of 100
# Step 643 Loss 0.30373985 Correct 89 out of 100
# Step 644 Loss 0.25517154 Correct 89 out of 100
# Step 645 Loss 0.2810539 Correct 89 out of 100
# Step 646 Loss 0.262903 Correct 93 out of 100
# Step 647 Loss 0.29622647 Correct 93 out of 100
# Step 648 Loss 0.20675136 Correct 96 out of 100
# Step 649 Loss 0.23740974 Correct 91 out of 100
# Step 650 Loss 0.2559039 Correct 91 out of 100
# Step 651 Loss 0.26659602 Correct 91 out of 100
# Step 652 Loss 0.29352093 Correct 91 out of 100
# Step 653 Loss 0.2648652 Correct 91 out of 100
# Step 654 Loss 0.29518244 Correct 91 out of 100
# Step 655 Loss 0.28782862 Correct 89 out of 100
# Step 656 Loss 0.34943706 Correct 89 out of 100
# Step 657 Loss 0.25940102 Correct 95 out of 100
# Step 658 Loss 0.2922105 Correct 92 out of 100
# Step 659 Loss 0.25119215 Correct 92 out of 100
# Step 660 Loss 0.20914756 Correct 93 out of 100
# Step 661 Loss 0.21174724 Correct 92 out of 100
# Step 662 Loss 0.3326477 Correct 91 out of 100
# Step 663 Loss 0.24153739 Correct 95 out of 100
# Step 664 Loss 0.18728927 Correct 96 out of 100
# Step 665 Loss 0.28213814 Correct 92 out of 100
# Step 666 Loss 0.22447258 Correct 95 out of 100
# Step 667 Loss 0.23479211 Correct 92 out of 100
# Step 668 Loss 0.26670322 Correct 93 out of 100
# Step 669 Loss 0.51724374 Correct 87 out of 100
# Step 670 Loss 0.29627553 Correct 89 out of 100
# Step 671 Loss 0.27153382 Correct 89 out of 100
# Step 672 Loss 0.29036868 Correct 90 out of 100
# Step 673 Loss 0.3139053 Correct 92 out of 100
# Step 674 Loss 0.32477352 Correct 88 out of 100
# Step 675 Loss 0.21372563 Correct 96 out of 100
# Step 676 Loss 0.37710857 Correct 89 out of 100
# Step 677 Loss 0.27018172 Correct 90 out of 100
# Step 678 Loss 0.24170096 Correct 94 out of 100
# Step 679 Loss 0.29997787 Correct 89 out of 100
# Step 680 Loss 0.23883305 Correct 91 out of 100
# Step 681 Loss 0.24754705 Correct 91 out of 100
# Step 682 Loss 0.22282179 Correct 93 out of 100
# Step 683 Loss 0.2425298 Correct 92 out of 100
# Step 684 Loss 0.1984025 Correct 94 out of 100
# Step 685 Loss 0.27668387 Correct 91 out of 100
# Step 686 Loss 0.3005253 Correct 86 out of 100
# Step 687 Loss 0.31635028 Correct 86 out of 100
# Step 688 Loss 0.26230365 Correct 89 out of 100
# Step 689 Loss 0.25791046 Correct 91 out of 100
# Step 690 Loss 0.28003687 Correct 88 out of 100
# Step 691 Loss 0.30411947 Correct 91 out of 100
# Step 692 Loss 0.31990516 Correct 91 out of 100
# Step 693 Loss 0.2460107 Correct 94 out of 100
# Step 694 Loss 0.24025191 Correct 96 out of 100
# Step 695 Loss 0.29496586 Correct 91 out of 100
# Step 696 Loss 0.2734694 Correct 89 out of 100
# Step 697 Loss 0.263542 Correct 94 out of 100
# Step 698 Loss 0.23848075 Correct 93 out of 100
# Step 699 Loss 0.26623034 Correct 92 out of 100
# Step 700 Loss 0.19658068 Correct 94 out of 100
# Step 701 Loss 0.25151515 Correct 93 out of 100
# Step 702 Loss 0.26795608 Correct 90 out of 100
# Step 703 Loss 0.26773062 Correct 93 out of 100
# Step 704 Loss 0.22913413 Correct 92 out of 100
# Step 705 Loss 0.2631581 Correct 91 out of 100
# Step 706 Loss 0.25997725 Correct 95 out of 100
# Step 707 Loss 0.32561645 Correct 89 out of 100
# Step 708 Loss 0.27751097 Correct 90 out of 100
# Step 709 Loss 0.32211167 Correct 95 out of 100
# Step 710 Loss 0.22234607 Correct 93 out of 100
# Step 711 Loss 0.2415853 Correct 94 out of 100
# Step 712 Loss 0.30055073 Correct 92 out of 100
# Step 713 Loss 0.26479587 Correct 95 out of 100
# Step 714 Loss 0.37619242 Correct 87 out of 100
# Step 715 Loss 0.2897312 Correct 94 out of 100
# Step 716 Loss 0.3193618 Correct 88 out of 100
# Step 717 Loss 0.26941973 Correct 91 out of 100
# Step 718 Loss 0.26314884 Correct 91 out of 100
# Step 719 Loss 0.34558648 Correct 88 out of 100
# Step 720 Loss 0.24355903 Correct 93 out of 100
# Step 721 Loss 0.2795616 Correct 91 out of 100
# Step 722 Loss 0.22448172 Correct 96 out of 100
# Step 723 Loss 0.2717443 Correct 91 out of 100
# Step 724 Loss 0.2629857 Correct 92 out of 100
# Step 725 Loss 0.2765821 Correct 92 out of 100
# Step 726 Loss 0.25597748 Correct 93 out of 100
# Step 727 Loss 0.22978854 Correct 93 out of 100
# Step 728 Loss 0.26546153 Correct 92 out of 100
# Step 729 Loss 0.16030253 Correct 98 out of 100
# Step 730 Loss 0.19069856 Correct 94 out of 100
# Step 731 Loss 0.25325343 Correct 90 out of 100
# Step 732 Loss 0.3504759 Correct 92 out of 100
# Step 733 Loss 0.20202543 Correct 94 out of 100
# Step 734 Loss 0.314174 Correct 88 out of 100
# Step 735 Loss 0.15573215 Correct 99 out of 100
# Step 736 Loss 0.2015953 Correct 95 out of 100
# Step 737 Loss 0.46960032 Correct 86 out of 100
# Step 738 Loss 0.24977589 Correct 90 out of 100
# Step 739 Loss 0.29736033 Correct 90 out of 100
# Step 740 Loss 0.32815245 Correct 90 out of 100
# Step 741 Loss 0.2326745 Correct 93 out of 100
# Step 742 Loss 0.25028288 Correct 93 out of 100
# Step 743 Loss 0.2056728 Correct 93 out of 100
# Step 744 Loss 0.22065966 Correct 93 out of 100
# Step 745 Loss 0.33532172 Correct 89 out of 100
# Step 746 Loss 0.2584786 Correct 88 out of 100
# Step 747 Loss 0.2953308 Correct 89 out of 100
# Step 748 Loss 0.2859135 Correct 89 out of 100
# Step 749 Loss 0.2298973 Correct 92 out of 100
# Step 750 Loss 0.30427772 Correct 89 out of 100
# Step 751 Loss 0.305701 Correct 89 out of 100
# Step 752 Loss 0.3297701 Correct 87 out of 100
# Step 753 Loss 0.29959264 Correct 92 out of 100
# Step 754 Loss 0.2386116 Correct 91 out of 100
# Step 755 Loss 0.32142746 Correct 93 out of 100
# Step 756 Loss 0.19098891 Correct 98 out of 100
# Step 757 Loss 0.18885146 Correct 97 out of 100
# Step 758 Loss 0.29901037 Correct 86 out of 100
# Step 759 Loss 0.2489605 Correct 90 out of 100
# Step 760 Loss 0.21763737 Correct 95 out of 100
# Step 761 Loss 0.2476253 Correct 92 out of 100
# Step 762 Loss 0.3034037 Correct 90 out of 100
# Step 763 Loss 0.34751198 Correct 87 out of 100
# Step 764 Loss 0.20136078 Correct 95 out of 100
# Step 765 Loss 0.16826111 Correct 96 out of 100
# Step 766 Loss 0.16947527 Correct 94 out of 100
# Step 767 Loss 0.19915254 Correct 96 out of 100
# Step 768 Loss 0.27615494 Correct 88 out of 100
# Step 769 Loss 0.2862671 Correct 88 out of 100
# Step 770 Loss 0.20257576 Correct 94 out of 100
# Step 771 Loss 0.32662567 Correct 85 out of 100
# Step 772 Loss 0.2718497 Correct 91 out of 100
# Step 773 Loss 0.30666324 Correct 92 out of 100
# Step 774 Loss 0.2942656 Correct 91 out of 100
# Step 775 Loss 0.22485246 Correct 92 out of 100
# Step 776 Loss 0.20901363 Correct 94 out of 100
# Step 777 Loss 0.20962483 Correct 94 out of 100
# Step 778 Loss 0.21012771 Correct 94 out of 100
# Step 779 Loss 0.3121743 Correct 90 out of 100
# Step 780 Loss 0.22690277 Correct 93 out of 100
# Step 781 Loss 0.18540849 Correct 94 out of 100
# Step 782 Loss 0.26906076 Correct 91 out of 100
# Step 783 Loss 0.2673678 Correct 89 out of 100
# Step 784 Loss 0.23283915 Correct 91 out of 100
# Step 785 Loss 0.22931941 Correct 95 out of 100
# Step 786 Loss 0.14778501 Correct 97 out of 100
# Step 787 Loss 0.30158657 Correct 90 out of 100
# Step 788 Loss 0.29246727 Correct 92 out of 100
# Step 789 Loss 0.25378978 Correct 93 out of 100
# Step 790 Loss 0.31004292 Correct 87 out of 100
# Step 791 Loss 0.2623155 Correct 89 out of 100
# Step 792 Loss 0.22578895 Correct 94 out of 100
# Step 793 Loss 0.3242757 Correct 84 out of 100
# Step 794 Loss 0.35604674 Correct 90 out of 100
# Step 795 Loss 0.2684786 Correct 92 out of 100
# Step 796 Loss 0.30029178 Correct 91 out of 100
# Step 797 Loss 0.2645981 Correct 90 out of 100
# Step 798 Loss 0.18231128 Correct 95 out of 100
# Step 799 Loss 0.19765678 Correct 94 out of 100
# Step 800 Loss 0.29632032 Correct 88 out of 100
# Step 801 Loss 0.2621692 Correct 97 out of 100
# Step 802 Loss 0.2633352 Correct 92 out of 100
# Step 803 Loss 0.32006088 Correct 87 out of 100
# Step 804 Loss 0.25755525 Correct 90 out of 100
# Step 805 Loss 0.1655563 Correct 95 out of 100
# Step 806 Loss 0.2483845 Correct 92 out of 100
# Step 807 Loss 0.27324882 Correct 91 out of 100
# Step 808 Loss 0.24645373 Correct 92 out of 100
# Step 809 Loss 0.2372095 Correct 94 out of 100
# Step 810 Loss 0.20784725 Correct 95 out of 100
# Step 811 Loss 0.2671253 Correct 91 out of 100
# Step 812 Loss 0.22824608 Correct 91 out of 100
# Step 813 Loss 0.1916711 Correct 94 out of 100
# Step 814 Loss 0.22096446 Correct 93 out of 100
# Step 815 Loss 0.20059165 Correct 93 out of 100
# Step 816 Loss 0.22783098 Correct 95 out of 100
# Step 817 Loss 0.21542612 Correct 93 out of 100
# Step 818 Loss 0.17602545 Correct 95 out of 100
# Step 819 Loss 0.2728629 Correct 89 out of 100
# Step 820 Loss 0.2201379 Correct 93 out of 100
# Step 821 Loss 0.2615913 Correct 92 out of 100
# Step 822 Loss 0.33774322 Correct 89 out of 100
# Step 823 Loss 0.24647506 Correct 97 out of 100
# Step 824 Loss 0.2121226 Correct 95 out of 100
# Step 825 Loss 0.3748733 Correct 87 out of 100
# Step 826 Loss 0.18688244 Correct 95 out of 100
# Step 827 Loss 0.2518074 Correct 95 out of 100
# Step 828 Loss 0.2049345 Correct 95 out of 100
# Step 829 Loss 0.1924592 Correct 93 out of 100
# Step 830 Loss 0.2344984 Correct 96 out of 100
# Step 831 Loss 0.2233784 Correct 92 out of 100
# Step 832 Loss 0.19461177 Correct 94 out of 100
# Step 833 Loss 0.26384804 Correct 91 out of 100
# Step 834 Loss 0.23610131 Correct 92 out of 100
# Step 835 Loss 0.23613757 Correct 90 out of 100
# Step 836 Loss 0.29024178 Correct 90 out of 100
# Step 837 Loss 0.20282204 Correct 97 out of 100
# Step 838 Loss 0.26171988 Correct 91 out of 100
# Step 839 Loss 0.211417 Correct 92 out of 100
# Step 840 Loss 0.21904117 Correct 95 out of 100
# Step 841 Loss 0.31144702 Correct 92 out of 100
# Step 842 Loss 0.19576497 Correct 95 out of 100
# Step 843 Loss 0.22271718 Correct 95 out of 100
# Step 844 Loss 0.20496342 Correct 94 out of 100
# Step 845 Loss 0.3104928 Correct 92 out of 100
# Step 846 Loss 0.13262112 Correct 97 out of 100
# Step 847 Loss 0.33488077 Correct 89 out of 100
# Step 848 Loss 0.23399517 Correct 90 out of 100
# Step 849 Loss 0.289424 Correct 89 out of 100
# Step 850 Loss 0.43465194 Correct 92 out of 100
# Step 851 Loss 0.26271862 Correct 92 out of 100
# Step 852 Loss 0.26995656 Correct 91 out of 100
# Step 853 Loss 0.25943938 Correct 89 out of 100
# Step 854 Loss 0.17792736 Correct 93 out of 100
# Step 855 Loss 0.22722478 Correct 96 out of 100
# Step 856 Loss 0.22998074 Correct 94 out of 100
# Step 857 Loss 0.25601605 Correct 87 out of 100
# Step 858 Loss 0.22434863 Correct 92 out of 100
# Step 859 Loss 0.25637087 Correct 92 out of 100
# Step 860 Loss 0.19937569 Correct 93 out of 100
# Step 861 Loss 0.17586301 Correct 95 out of 100
# Step 862 Loss 0.15948315 Correct 95 out of 100
# Step 863 Loss 0.24487665 Correct 93 out of 100
# Step 864 Loss 0.23813671 Correct 91 out of 100
# Step 865 Loss 0.18538612 Correct 96 out of 100
# Step 866 Loss 0.29411346 Correct 90 out of 100
# Step 867 Loss 0.28838074 Correct 92 out of 100
# Step 868 Loss 0.32724705 Correct 92 out of 100
# Step 869 Loss 0.2968728 Correct 91 out of 100
# Step 870 Loss 0.22290252 Correct 95 out of 100
# Step 871 Loss 0.17159568 Correct 97 out of 100
# Step 872 Loss 0.17020409 Correct 95 out of 100
# Step 873 Loss 0.23092782 Correct 92 out of 100
# Step 874 Loss 0.23772128 Correct 92 out of 100
# Step 875 Loss 0.23119418 Correct 94 out of 100
# Step 876 Loss 0.19120163 Correct 95 out of 100
# Step 877 Loss 0.25687674 Correct 90 out of 100
# Step 878 Loss 0.23562026 Correct 93 out of 100
# Step 879 Loss 0.21822344 Correct 92 out of 100
# Step 880 Loss 0.24946205 Correct 92 out of 100
# Step 881 Loss 0.36617878 Correct 87 out of 100
# Step 882 Loss 0.21916889 Correct 93 out of 100
# Step 883 Loss 0.23605914 Correct 94 out of 100
# Step 884 Loss 0.20443483 Correct 92 out of 100
# Step 885 Loss 0.2505408 Correct 91 out of 100
# Step 886 Loss 0.16749473 Correct 96 out of 100
# Step 887 Loss 0.25994048 Correct 90 out of 100
# Step 888 Loss 0.20256779 Correct 94 out of 100
# Step 889 Loss 0.191172 Correct 95 out of 100
# Step 890 Loss 0.13192649 Correct 99 out of 100
# Step 891 Loss 0.21209362 Correct 95 out of 100
# Step 892 Loss 0.19459686 Correct 93 out of 100
# Step 893 Loss 0.18449087 Correct 95 out of 100
# Step 894 Loss 0.21879904 Correct 94 out of 100
# Step 895 Loss 0.22228229 Correct 92 out of 100
# Step 896 Loss 0.20302646 Correct 97 out of 100
# Step 897 Loss 0.26808506 Correct 88 out of 100
# Step 898 Loss 0.22358958 Correct 95 out of 100
# Step 899 Loss 0.23579404 Correct 91 out of 100
# Step 900 Loss 0.2585894 Correct 92 out of 100
# Step 901 Loss 0.18968788 Correct 95 out of 100
# Step 902 Loss 0.32943335 Correct 87 out of 100
# Step 903 Loss 0.13578108 Correct 96 out of 100
# Step 904 Loss 0.3178617 Correct 90 out of 100
# Step 905 Loss 0.24327795 Correct 89 out of 100
# Step 906 Loss 0.2224524 Correct 94 out of 100
# Step 907 Loss 0.23771136 Correct 92 out of 100
# Step 908 Loss 0.29875538 Correct 91 out of 100
# Step 909 Loss 0.2231594 Correct 93 out of 100
# Step 910 Loss 0.21881339 Correct 91 out of 100
# Step 911 Loss 0.43822727 Correct 90 out of 100
# Step 912 Loss 0.19772655 Correct 93 out of 100
# Step 913 Loss 0.24461226 Correct 94 out of 100
# Step 914 Loss 0.20031372 Correct 95 out of 100
# Step 915 Loss 0.20458107 Correct 94 out of 100
# Step 916 Loss 0.23697515 Correct 94 out of 100
# Step 917 Loss 0.25504035 Correct 95 out of 100
# Step 918 Loss 0.18901849 Correct 94 out of 100
# Step 919 Loss 0.20227464 Correct 92 out of 100
# Step 920 Loss 0.22470573 Correct 94 out of 100
# Step 921 Loss 0.20463885 Correct 94 out of 100
# Step 922 Loss 0.26760194 Correct 91 out of 100
# Step 923 Loss 0.1534206 Correct 95 out of 100
# Step 924 Loss 0.32944107 Correct 92 out of 100
# Step 925 Loss 0.35003865 Correct 87 out of 100
# Step 926 Loss 0.21026067 Correct 93 out of 100
# Step 927 Loss 0.21077581 Correct 93 out of 100
# Step 928 Loss 0.21199748 Correct 92 out of 100
# Step 929 Loss 0.29602522 Correct 90 out of 100
# Step 930 Loss 0.23337038 Correct 91 out of 100
# Step 931 Loss 0.23664415 Correct 93 out of 100
# Step 932 Loss 0.35385558 Correct 85 out of 100
# Step 933 Loss 0.23551828 Correct 92 out of 100
# Step 934 Loss 0.24272926 Correct 94 out of 100
# Step 935 Loss 0.25238267 Correct 96 out of 100
# Step 936 Loss 0.1858793 Correct 96 out of 100
# Step 937 Loss 0.23184872 Correct 96 out of 100
# Step 938 Loss 0.19565418 Correct 93 out of 100
# Step 939 Loss 0.28031376 Correct 91 out of 100
# Step 940 Loss 0.2624943 Correct 91 out of 100
# Step 941 Loss 0.27176914 Correct 92 out of 100
# Step 942 Loss 0.15606432 Correct 96 out of 100
# Step 943 Loss 0.23860103 Correct 93 out of 100
# Step 944 Loss 0.21182884 Correct 92 out of 100
# Step 945 Loss 0.23219211 Correct 93 out of 100
# Step 946 Loss 0.23318033 Correct 93 out of 100
# Step 947 Loss 0.2430022 Correct 92 out of 100
# Step 948 Loss 0.22072127 Correct 92 out of 100
# Step 949 Loss 0.22589234 Correct 95 out of 100
# Step 950 Loss 0.3359303 Correct 89 out of 100
# Step 951 Loss 0.27330944 Correct 90 out of 100
# Step 952 Loss 0.2283848 Correct 93 out of 100
# Step 953 Loss 0.2302285 Correct 94 out of 100
# Step 954 Loss 0.18650089 Correct 94 out of 100
# Step 955 Loss 0.28642806 Correct 91 out of 100
# Step 956 Loss 0.24290688 Correct 92 out of 100
# Step 957 Loss 0.16058666 Correct 97 out of 100
# Step 958 Loss 0.19501238 Correct 94 out of 100
# Step 959 Loss 0.3366935 Correct 86 out of 100
# Step 960 Loss 0.31382534 Correct 88 out of 100
# Step 961 Loss 0.17357868 Correct 94 out of 100
# Step 962 Loss 0.26349863 Correct 93 out of 100
# Step 963 Loss 0.30092135 Correct 88 out of 100
# Step 964 Loss 0.20929247 Correct 94 out of 100
# Step 965 Loss 0.28083313 Correct 92 out of 100
# Step 966 Loss 0.27423987 Correct 93 out of 100
# Step 967 Loss 0.23872031 Correct 89 out of 100
# Step 968 Loss 0.22635017 Correct 92 out of 100
# Step 969 Loss 0.29604614 Correct 88 out of 100
# Step 970 Loss 0.18858123 Correct 95 out of 100
# Step 971 Loss 0.18613842 Correct 95 out of 100
# Step 972 Loss 0.27700657 Correct 88 out of 100
# Step 973 Loss 0.29649365 Correct 92 out of 100
# Step 974 Loss 0.39961138 Correct 87 out of 100
# Step 975 Loss 0.2127561 Correct 96 out of 100
# Step 976 Loss 0.2991768 Correct 89 out of 100
# Step 977 Loss 0.2690454 Correct 89 out of 100
# Step 978 Loss 0.2031859 Correct 92 out of 100
# Step 979 Loss 0.2010569 Correct 94 out of 100
# Step 980 Loss 0.2660778 Correct 91 out of 100
# Step 981 Loss 0.29762813 Correct 90 out of 100
# Step 982 Loss 0.24468534 Correct 88 out of 100
# Step 983 Loss 0.24529237 Correct 94 out of 100
# Step 984 Loss 0.24394019 Correct 92 out of 100
# Step 985 Loss 0.22716537 Correct 92 out of 100
# Step 986 Loss 0.18232884 Correct 95 out of 100
# Step 987 Loss 0.20857623 Correct 94 out of 100
# Step 988 Loss 0.22798643 Correct 94 out of 100
# Step 989 Loss 0.28639838 Correct 91 out of 100
# Step 990 Loss 0.19473675 Correct 92 out of 100
# Step 991 Loss 0.19287363 Correct 92 out of 100
# Step 992 Loss 0.17960395 Correct 95 out of 100
# Step 993 Loss 0.37799087 Correct 86 out of 100
# Step 994 Loss 0.21888055 Correct 93 out of 100
# Step 995 Loss 0.16524395 Correct 94 out of 100
# Step 996 Loss 0.27771527 Correct 90 out of 100
# Step 997 Loss 0.1996226 Correct 93 out of 100
# Step 998 Loss 0.3710205 Correct 87 out of 100
# Step 999 Loss 0.20669264 Correct 95 out of 100
# 2021-12-05 14:52:20.509453: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Loss for 3000 randomly chosen documents is  0.25178956985473633  number of correct labels is  2760  out of 3000

# %% [markdown]
# ## Task 4: Modifying the “Time Warping” RNN to Use a Convolution

# %% [markdown]
#  - Rather than processing one character at a time, you will process ten characters at a time. That is, consider the sentence “This is my cool string”. You will process not the sequence of characters ‘T’, ‘h’, ‘i’, etc., but instead you will process the sequence of strings “This is my”, “his is my ”, “is is my c”, “s is my co”, and so on.
#  - The idea in “convolutional ﬁltering” is that you process each sequence by mapping it down to a single value (if you view the sequence of 10 characters as a 256 × 10-dimensional vector, you can map it down to a single value using a dot product with a 256 × 10-dimensional vector (this is a convolutional ﬁlter; “convolutional” refers to the sliding window). If you multiply with a matrix that contains eight, 256 × 10-dimensional vectors, you process the window with eight ﬁlers and obtains eight values. It is this resulting vector of eight values that is input into the RNN at each time tick, rather than the single character.

# %%
# create the data dictionary

maxSeqLen = 0
data = {}

# load up the three data sets
(maxSeqLen, data) = addToData (maxSeqLen, data, "Holmes.txt", 0, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "war.txt", 1, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "william.txt", 2, 10000)

# pad each entry in the dictionary with empty characters as needed so
# that the sequences are all of the same length
# 裏面transpose變成 256 * maxSeqLen 的shape
data = pad (maxSeqLen, data)
allDataID = [i for i in range(len(data))]
# print(len(data))    25041
testDataID = random.sample(allDataID[0:7000], 1000) + random.sample(allDataID[10000:18000], 1000) + random.sample(allDataID[19500:], 1000)
trainDataID = list(set(allDataID) - set(testDataID))
data_train = dict()
data_test = dict()
for train_id in trainDataID:
    data_train[train_id] = data[train_id]
for test_id in testDataID:
    data_test[test_id] = data[test_id]

        
# now we build the TensorFlow computation... there are two inputs, 
# a batch of text lines and a batch of labels
inputX = tf.placeholder(tf.float32, [batchSize, 256, maxSeqLen])
inputY = tf.placeholder(tf.int32, [batchSize])

# this is the inital state of the RNN, before processing any data
initialState = tf.placeholder(tf.float32, [batchSize, hiddenUnits])  # (100, 500)

# the weight matrix that maps the inputs and hidden state to a set of values
# W is modified to include the hidden state at t-10 -> so 256 + hiddenUnits + hiddenUnits
W = tf.Variable(np.random.normal(0, 0.05, (8 + hiddenUnits + hiddenUnits, hiddenUnits)), dtype=tf.float32)

# weight matrix for 8 channels of filter
W_filters = [tf.Variable(np.random.normal(0, 0.05, (256, 10)), dtype=tf.float32) for i in range(numOfChannels)]
for i in range(numOfChannels):
    W_filters[i] = tf.stack([W_filters[i]]*100)


# biaes for the hidden values
b = tf.Variable(np.zeros((1, hiddenUnits)), dtype=tf.float32)

# weights and bias for the final classification
W2 = tf.Variable(np.random.normal (0, 0.05, (hiddenUnits, numClasses)),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,numClasses)), dtype=tf.float32)

# unpack the input sequences so that we have a series of matrices,
# each of which has a one-hot encoding of the current character from
# every input sequence
sequenceOfLetters = tf.unstack(inputX, axis=2)      # sequenceOfLetters[0].shape = (100, 256)

# now we implement the forward pass
currentState = initialState
timeWarpStates = [initialState] * 10
for idx,timeTick in enumerate(sequenceOfLetters):
    if idx + 10 < len(sequenceOfLetters):
        currentWindow = sequenceOfLetters[idx:idx+10]       # [(100, 256), ..., (100, 256)]
        currentWindow = tf.stack(currentWindow, axis=2)     # shape of currentWindow: (100, 256, 10)
        dotResult = [0] * numOfChannels
        for channel in range(numOfChannels):
            c = tf.reduce_sum( tf.multiply( currentWindow, W_filters[channel]), axis=[1,2],keep_dims=False )
            dotResult[channel] = c

        dotResult = tf.stack(dotResult, axis=1)
        # concatenate the state with the input, then compute the next state
        # Add time warpping -> append the state at t-10 as input
        inputPlusState = tf.concat([dotResult, currentState, timeWarpStates[idx%10]], 1)     # shape: batchsize * (256 + hiddenUnits + hiddenUnits)
        next_state = tf.tanh(tf.matmul(inputPlusState, W) + b)      # W shape: (256 + hiddenUnits + hiddenUnits) * hiddenUnits
        currentState = next_state
        timeWarpStates[idx%10] = next_state    # Update the previous 10 states for future time warp


# compute the set of outputs
outputs = tf.matmul(currentState, W2) + b2

predictions = tf.nn.softmax(outputs)

# compute the loss
losses = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=outputs, labels=inputY)
totalLoss = tf.reduce_mean(losses)  # take mean of losses

# use gradient descent to train
#trainingAlg = tf.train.GradientDescentOptimizer(0.02).minimize(totalLoss)
trainingAlg = tf.train.AdagradOptimizer(0.02).minimize(totalLoss)

# and train!!
with tf.Session() as sess:
    #
    # initialize everything
    sess.run(tf.global_variables_initializer())
    #
    # and run the training iters
    # _finalState = np.zeros((batchSize, hiddenUnits))
    for epoch in range(10000):
        # 
        # get some data
        x, y = generateDataRNN(maxSeqLen, data_train)

        #
        # do the training epoch
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _trainingAlg, _currentState, _predictions, _outputs = sess.run(
                [totalLoss, trainingAlg, currentState, predictions, outputs],
                feed_dict={
                    inputX:x,
                    inputY:y,
                    initialState:_currentState
                })

        #
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y)):
           maxPos = -1
           maxVal = 0.0
           for j in range (numClasses):
               if maxVal < _predictions[i][j]:
                   maxVal = _predictions[i][j]
                   maxPos = j
           if maxPos == y[i]:
               numCorrect = numCorrect + 1
        #
        # print out to the screen
        print("Step", epoch, "Loss", _totalLoss, "Correct", numCorrect, "out of", batchSize)


    
    # Testing
    _avgTestLoss = 0
    totalNumCorrect = 0
    x_test, y_test = generateDataRNN(maxSeqLen, data_test)
    _currentState = np.zeros((batchSize, hiddenUnits))
    for i in range(30):
        _testLoss, _testPredictions = sess.run([totalLoss, predictions], feed_dict = {
                            inputX:x_test,
                            inputY:y_test,
                            initialState:_currentState
                            })
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y_test)):
            maxPos = -1
            maxVal = 0.0
            for j in range (numClasses):
                if maxVal < _testPredictions[i][j]:
                    maxVal = _testPredictions[i][j]
                    maxPos = j
            if maxPos == y_test[i]:
                numCorrect = numCorrect + 1
        totalNumCorrect += numCorrect
        _avgTestLoss += _testLoss
        
    _avgTestLoss /= 30
    print("Loss for 3000 randomly chosen documents is ", _avgTestLoss, " number of correct labels is ", totalNumCorrect, " out of 3000")
# Out:
# /var/folders/76/0jylnbrx4p7_yl5fmv0d39yr0000gn/T/ipykernel_63689/2724516542.py:24: DeprecationWarning: This function is deprecated. Please call randint(0, 13051 + 1) instead
#   myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
# /var/folders/76/0jylnbrx4p7_yl5fmv0d39yr0000gn/T/ipykernel_63689/2724516542.py:24: DeprecationWarning: This function is deprecated. Please call randint(0, 65334 + 1) instead
#   myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
# /var/folders/76/0jylnbrx4p7_yl5fmv0d39yr0000gn/T/ipykernel_63689/2724516542.py:24: DeprecationWarning: This function is deprecated. Please call randint(0, 124795 + 1) instead
#   myInts = np.random.random_integers(0, len(content) - 1, linesToUse)
# 2021-12-06 20:56:23.267598: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-12-06 20:56:23.267625: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-12-06 20:56:23.524697: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-12-06 20:56:23.686950: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Step 0 Loss 1.2138585 Correct 37 out of 100
# Step 1 Loss 1.392019 Correct 29 out of 100
# Step 2 Loss 2.338253 Correct 40 out of 100
# Step 3 Loss 1.4862965 Correct 31 out of 100
# Step 4 Loss 1.9058383 Correct 34 out of 100
# Step 5 Loss 5.2703404 Correct 35 out of 100
# Step 6 Loss 3.7493734 Correct 41 out of 100
# Step 7 Loss 2.436378 Correct 35 out of 100
# Step 8 Loss 4.108468 Correct 29 out of 100
# Step 9 Loss 2.5080469 Correct 37 out of 100
# Step 10 Loss 3.4213953 Correct 32 out of 100
# Step 11 Loss 2.4537735 Correct 29 out of 100
# Step 12 Loss 1.8301388 Correct 23 out of 100
# Step 13 Loss 1.8656504 Correct 44 out of 100
# Step 14 Loss 1.1835592 Correct 41 out of 100
# Step 15 Loss 1.1118584 Correct 34 out of 100
# Step 16 Loss 1.2389128 Correct 39 out of 100
# Step 17 Loss 1.4700769 Correct 29 out of 100
# Step 18 Loss 1.2581239 Correct 42 out of 100
# Step 19 Loss 1.1120366 Correct 39 out of 100
# Step 20 Loss 1.1023881 Correct 39 out of 100
# Step 21 Loss 1.2419515 Correct 38 out of 100
# Step 22 Loss 1.3946911 Correct 34 out of 100
# Step 23 Loss 1.3245637 Correct 34 out of 100
# Step 24 Loss 1.6122079 Correct 32 out of 100
# Step 25 Loss 1.6628636 Correct 36 out of 100
# Step 26 Loss 1.3699319 Correct 34 out of 100
# Step 27 Loss 1.3338125 Correct 39 out of 100
# Step 28 Loss 1.3427001 Correct 32 out of 100
# Step 29 Loss 1.6858084 Correct 33 out of 100
# Step 30 Loss 1.4815598 Correct 38 out of 100
# Step 31 Loss 1.2925409 Correct 27 out of 100
# Step 32 Loss 1.4701405 Correct 30 out of 100
# Step 33 Loss 1.4113748 Correct 37 out of 100
# Step 34 Loss 1.2867227 Correct 20 out of 100
# Step 35 Loss 1.5404953 Correct 37 out of 100
# Step 36 Loss 1.2863293 Correct 29 out of 100
# Step 37 Loss 1.2599839 Correct 33 out of 100
# Step 38 Loss 1.214053 Correct 27 out of 100
# Step 39 Loss 1.1533965 Correct 47 out of 100
# Step 40 Loss 1.1071194 Correct 40 out of 100
# Step 41 Loss 1.1118622 Correct 38 out of 100
# Step 42 Loss 1.1262296 Correct 25 out of 100
# Step 43 Loss 1.3213565 Correct 37 out of 100
# Step 44 Loss 1.2178663 Correct 44 out of 100
# Step 45 Loss 1.2237562 Correct 26 out of 100
# Step 46 Loss 1.2512517 Correct 34 out of 100
# Step 47 Loss 1.172513 Correct 37 out of 100
# Step 48 Loss 1.131702 Correct 29 out of 100
# Step 49 Loss 1.200633 Correct 32 out of 100
# Step 50 Loss 1.1809512 Correct 40 out of 100
# Step 51 Loss 1.2054102 Correct 37 out of 100
# Step 52 Loss 1.117226 Correct 44 out of 100
# Step 53 Loss 1.101343 Correct 32 out of 100
# Step 54 Loss 1.0971227 Correct 40 out of 100
# Step 55 Loss 1.106557 Correct 28 out of 100
# Step 56 Loss 1.2037274 Correct 30 out of 100
# Step 57 Loss 1.1922977 Correct 33 out of 100
# Step 58 Loss 1.1486871 Correct 32 out of 100
# Step 59 Loss 1.2008338 Correct 28 out of 100
# Step 60 Loss 1.3025094 Correct 25 out of 100
# Step 61 Loss 1.1979367 Correct 39 out of 100
# Step 62 Loss 1.1087301 Correct 34 out of 100
# Step 63 Loss 1.1440161 Correct 29 out of 100
# Step 64 Loss 1.1759845 Correct 34 out of 100
# Step 65 Loss 1.1559049 Correct 33 out of 100
# Step 66 Loss 1.151777 Correct 30 out of 100
# Step 67 Loss 1.1874679 Correct 32 out of 100
# Step 68 Loss 1.1269011 Correct 36 out of 100
# Step 69 Loss 1.0951922 Correct 37 out of 100
# Step 70 Loss 1.1107607 Correct 28 out of 100
# Step 71 Loss 1.1232432 Correct 40 out of 100
# Step 72 Loss 1.1446038 Correct 24 out of 100
# Step 73 Loss 1.1653922 Correct 40 out of 100
# Step 74 Loss 1.1166921 Correct 32 out of 100
# Step 75 Loss 1.1160389 Correct 28 out of 100
# Step 76 Loss 1.1476741 Correct 40 out of 100
# Step 77 Loss 1.2120675 Correct 23 out of 100
# Step 78 Loss 1.1349211 Correct 35 out of 100
# Step 79 Loss 1.2048259 Correct 25 out of 100
# Step 80 Loss 1.293161 Correct 34 out of 100
# Step 81 Loss 1.1383066 Correct 31 out of 100
# Step 82 Loss 1.2131106 Correct 32 out of 100
# Step 83 Loss 1.138992 Correct 40 out of 100
# Step 84 Loss 1.1069533 Correct 24 out of 100
# Step 85 Loss 1.1649755 Correct 37 out of 100
# Step 86 Loss 1.1934441 Correct 32 out of 100
# Step 87 Loss 1.1879656 Correct 39 out of 100
# Step 88 Loss 1.1717218 Correct 30 out of 100
# Step 89 Loss 1.1788436 Correct 34 out of 100
# Step 90 Loss 1.1664759 Correct 33 out of 100
# Step 91 Loss 1.1476406 Correct 35 out of 100
# Step 92 Loss 1.1163297 Correct 32 out of 100
# Step 93 Loss 1.0850586 Correct 46 out of 100
# Step 94 Loss 1.178492 Correct 35 out of 100
# Step 95 Loss 1.1470102 Correct 36 out of 100
# Step 96 Loss 1.1577545 Correct 30 out of 100
# Step 97 Loss 1.2124546 Correct 36 out of 100
# Step 98 Loss 1.1576984 Correct 38 out of 100
# Step 99 Loss 1.1570983 Correct 29 out of 100
# Step 100 Loss 1.2094673 Correct 27 out of 100
# Step 101 Loss 1.2384653 Correct 27 out of 100
# Step 102 Loss 1.1815283 Correct 35 out of 100
# Step 103 Loss 1.2119715 Correct 26 out of 100
# Step 104 Loss 1.2466992 Correct 27 out of 100
# Step 105 Loss 1.185 Correct 32 out of 100
# Step 106 Loss 1.1304721 Correct 37 out of 100
# Step 107 Loss 1.1444356 Correct 35 out of 100
# Step 108 Loss 1.0852537 Correct 41 out of 100
# Step 109 Loss 1.1149106 Correct 35 out of 100
# Step 110 Loss 1.1387925 Correct 25 out of 100
# Step 111 Loss 1.1659455 Correct 32 out of 100
# Step 112 Loss 1.1664324 Correct 36 out of 100
# Step 113 Loss 1.1269065 Correct 35 out of 100
# Step 114 Loss 1.1041127 Correct 35 out of 100
# Step 115 Loss 1.0814006 Correct 44 out of 100
# Step 116 Loss 1.1887283 Correct 25 out of 100
# Step 117 Loss 1.2200462 Correct 30 out of 100
# Step 118 Loss 1.1558886 Correct 38 out of 100
# Step 119 Loss 1.1333114 Correct 27 out of 100
# Step 120 Loss 1.0818613 Correct 39 out of 100
# Step 121 Loss 1.0958486 Correct 39 out of 100
# Step 122 Loss 1.095053 Correct 34 out of 100
# Step 123 Loss 1.1037475 Correct 33 out of 100
# Step 124 Loss 1.1075393 Correct 33 out of 100
# Step 125 Loss 1.1132222 Correct 30 out of 100
# Step 126 Loss 1.1016669 Correct 38 out of 100
# Step 127 Loss 1.0982717 Correct 34 out of 100
# Step 128 Loss 1.1268135 Correct 31 out of 100
# Step 129 Loss 1.1346751 Correct 34 out of 100
# Step 130 Loss 1.1355186 Correct 32 out of 100
# Step 131 Loss 1.1032863 Correct 40 out of 100
# Step 132 Loss 1.1166142 Correct 44 out of 100
# Step 133 Loss 1.1930205 Correct 38 out of 100
# Step 134 Loss 1.1116128 Correct 23 out of 100
# Step 135 Loss 1.2036309 Correct 32 out of 100
# Step 136 Loss 1.1645936 Correct 29 out of 100
# Step 137 Loss 1.1017941 Correct 28 out of 100
# Step 138 Loss 1.2271894 Correct 29 out of 100
# Step 139 Loss 1.3016858 Correct 30 out of 100
# Step 140 Loss 1.2853184 Correct 31 out of 100
# Step 141 Loss 1.1366786 Correct 34 out of 100
# Step 142 Loss 1.0827014 Correct 42 out of 100
# Step 143 Loss 1.0984164 Correct 41 out of 100
# Step 144 Loss 1.1049491 Correct 40 out of 100
# Step 145 Loss 1.1134719 Correct 40 out of 100
# Step 146 Loss 1.0978976 Correct 32 out of 100
# Step 147 Loss 1.1399045 Correct 34 out of 100
# Step 148 Loss 1.1080259 Correct 39 out of 100
# Step 149 Loss 1.1070336 Correct 34 out of 100
# Step 150 Loss 1.0992478 Correct 32 out of 100
# Step 151 Loss 1.1069586 Correct 29 out of 100
# Step 152 Loss 1.1116848 Correct 37 out of 100
# Step 153 Loss 1.1174476 Correct 31 out of 100
# Step 154 Loss 1.123785 Correct 31 out of 100
# Step 155 Loss 1.1479797 Correct 30 out of 100
# Step 156 Loss 1.1720918 Correct 31 out of 100
# Step 157 Loss 1.1947757 Correct 31 out of 100
# Step 158 Loss 1.0931221 Correct 39 out of 100
# Step 159 Loss 1.1799045 Correct 25 out of 100
# Step 160 Loss 1.1666985 Correct 25 out of 100
# Step 161 Loss 1.157212 Correct 41 out of 100
# Step 162 Loss 1.0742652 Correct 43 out of 100
# Step 163 Loss 1.1635196 Correct 31 out of 100
# Step 164 Loss 1.1003989 Correct 37 out of 100
# Step 165 Loss 1.0918051 Correct 43 out of 100
# Step 166 Loss 1.20462 Correct 27 out of 100
# Step 167 Loss 1.152372 Correct 35 out of 100
# Step 168 Loss 1.0985333 Correct 35 out of 100
# Step 169 Loss 1.0983058 Correct 40 out of 100
# Step 170 Loss 1.1006911 Correct 31 out of 100
# Step 171 Loss 1.0753307 Correct 44 out of 100
# Step 172 Loss 1.1110994 Correct 38 out of 100
# Step 173 Loss 1.1040287 Correct 33 out of 100
# Step 174 Loss 1.1181046 Correct 31 out of 100
# Step 175 Loss 1.1145378 Correct 40 out of 100
# Step 176 Loss 1.1249913 Correct 35 out of 100
# Step 177 Loss 1.1058128 Correct 28 out of 100
# Step 178 Loss 1.1283411 Correct 26 out of 100
# Step 179 Loss 1.1357287 Correct 38 out of 100
# Step 180 Loss 1.1032562 Correct 37 out of 100
# Step 181 Loss 1.105782 Correct 33 out of 100
# Step 182 Loss 1.0981798 Correct 36 out of 100
# Step 183 Loss 1.1076286 Correct 32 out of 100
# Step 184 Loss 1.1227362 Correct 40 out of 100
# Step 185 Loss 1.0957642 Correct 37 out of 100
# Step 186 Loss 1.121344 Correct 30 out of 100
# Step 187 Loss 1.136583 Correct 33 out of 100
# Step 188 Loss 1.1028751 Correct 29 out of 100
# Step 189 Loss 1.0850827 Correct 43 out of 100
# Step 190 Loss 1.0863677 Correct 42 out of 100
# Step 191 Loss 1.1372622 Correct 30 out of 100
# Step 192 Loss 1.1721597 Correct 32 out of 100
# Step 193 Loss 1.1943227 Correct 33 out of 100
# Step 194 Loss 1.1105081 Correct 34 out of 100
# Step 195 Loss 1.1065873 Correct 31 out of 100
# Step 196 Loss 1.1277181 Correct 37 out of 100
# Step 197 Loss 1.1261961 Correct 32 out of 100
# Step 198 Loss 1.1008792 Correct 40 out of 100
# Step 199 Loss 1.1120182 Correct 28 out of 100
# Step 200 Loss 1.1292167 Correct 32 out of 100
# Step 201 Loss 1.1018941 Correct 36 out of 100
# Step 202 Loss 1.1005943 Correct 34 out of 100
# Step 203 Loss 1.1044964 Correct 35 out of 100
# Step 204 Loss 1.0976186 Correct 35 out of 100
# Step 205 Loss 1.0999873 Correct 25 out of 100
# Step 206 Loss 1.0980606 Correct 40 out of 100
# Step 207 Loss 1.0916039 Correct 36 out of 100
# Step 208 Loss 1.1069527 Correct 41 out of 100
# Step 209 Loss 1.115787 Correct 37 out of 100
# Step 210 Loss 1.0997119 Correct 35 out of 100
# Step 211 Loss 1.1014308 Correct 34 out of 100
# Step 212 Loss 1.1149024 Correct 29 out of 100
# Step 213 Loss 1.0745075 Correct 38 out of 100
# Step 214 Loss 1.1227438 Correct 33 out of 100
# Step 215 Loss 1.1062149 Correct 31 out of 100
# Step 216 Loss 1.1198773 Correct 27 out of 100
# Step 217 Loss 1.1244079 Correct 35 out of 100
# Step 218 Loss 1.1069752 Correct 29 out of 100
# Step 219 Loss 1.1499212 Correct 34 out of 100
# Step 220 Loss 1.1353537 Correct 29 out of 100
# Step 221 Loss 1.1202028 Correct 32 out of 100
# Step 222 Loss 1.1304663 Correct 29 out of 100
# Step 223 Loss 1.0860789 Correct 41 out of 100
# Step 224 Loss 1.1564437 Correct 29 out of 100
# Step 225 Loss 1.1849179 Correct 35 out of 100
# Step 226 Loss 1.1041325 Correct 36 out of 100
# Step 227 Loss 1.096761 Correct 39 out of 100
# Step 228 Loss 1.0975955 Correct 40 out of 100
# Step 229 Loss 1.1079262 Correct 31 out of 100
# Step 230 Loss 1.108894 Correct 31 out of 100
# Step 231 Loss 1.1072682 Correct 31 out of 100
# Step 232 Loss 1.1032665 Correct 38 out of 100
# Step 233 Loss 1.0938418 Correct 36 out of 100
# Step 234 Loss 1.089642 Correct 41 out of 100
# Step 235 Loss 1.1083964 Correct 36 out of 100
# Step 236 Loss 1.0957284 Correct 36 out of 100
# Step 237 Loss 1.1385897 Correct 36 out of 100
# Step 238 Loss 1.1007408 Correct 34 out of 100
# Step 239 Loss 1.1022401 Correct 39 out of 100
# Step 240 Loss 1.1058013 Correct 39 out of 100
# Step 241 Loss 1.1555282 Correct 25 out of 100
# Step 242 Loss 1.1327614 Correct 37 out of 100
# Step 243 Loss 1.0998217 Correct 32 out of 100
# Step 244 Loss 1.0894371 Correct 38 out of 100
# Step 245 Loss 1.1227559 Correct 23 out of 100
# Step 246 Loss 1.157256 Correct 28 out of 100
# Step 247 Loss 1.1628311 Correct 38 out of 100
# Step 248 Loss 1.0987248 Correct 40 out of 100
# Step 249 Loss 1.1018139 Correct 35 out of 100
# Step 250 Loss 1.1165289 Correct 29 out of 100
# Step 251 Loss 1.1671548 Correct 30 out of 100
# Step 252 Loss 1.1719598 Correct 37 out of 100
# Step 253 Loss 1.1194792 Correct 31 out of 100
# Step 254 Loss 1.0583558 Correct 49 out of 100
# Step 255 Loss 1.1343985 Correct 39 out of 100
# Step 256 Loss 1.0988984 Correct 35 out of 100
# Step 257 Loss 1.0967028 Correct 34 out of 100
# Step 258 Loss 1.0879766 Correct 41 out of 100
# Step 259 Loss 1.1267219 Correct 31 out of 100
# Step 260 Loss 1.1423572 Correct 28 out of 100
# Step 261 Loss 1.1186076 Correct 35 out of 100
# Step 262 Loss 1.1001376 Correct 36 out of 100
# Step 263 Loss 1.0742753 Correct 42 out of 100
# Step 264 Loss 1.136574 Correct 31 out of 100
# Step 265 Loss 1.1270579 Correct 33 out of 100
# Step 266 Loss 1.131019 Correct 33 out of 100
# Step 267 Loss 1.1498288 Correct 30 out of 100
# Step 268 Loss 1.1899835 Correct 28 out of 100
# Step 269 Loss 1.1622392 Correct 30 out of 100
# Step 270 Loss 1.1172671 Correct 33 out of 100
# Step 271 Loss 1.1045692 Correct 30 out of 100
# Step 272 Loss 1.0944548 Correct 40 out of 100
# Step 273 Loss 1.1539668 Correct 20 out of 100
# Step 274 Loss 1.1670998 Correct 29 out of 100
# Step 275 Loss 1.0631388 Correct 45 out of 100
# Step 276 Loss 1.1708561 Correct 28 out of 100
# Step 277 Loss 1.1584634 Correct 31 out of 100
# Step 278 Loss 1.1107299 Correct 35 out of 100
# Step 279 Loss 1.0986309 Correct 27 out of 100
# Step 280 Loss 1.1226242 Correct 36 out of 100
# Step 281 Loss 1.090083 Correct 43 out of 100
# Step 282 Loss 1.1478853 Correct 32 out of 100
# Step 283 Loss 1.1139908 Correct 34 out of 100
# Step 284 Loss 1.0845909 Correct 41 out of 100
# Step 285 Loss 1.1138589 Correct 38 out of 100
# Step 286 Loss 1.1032413 Correct 32 out of 100
# Step 287 Loss 1.0966507 Correct 37 out of 100
# Step 288 Loss 1.0922507 Correct 41 out of 100
# Step 289 Loss 1.1064365 Correct 36 out of 100
# Step 290 Loss 1.0900784 Correct 41 out of 100
# Step 291 Loss 1.095246 Correct 40 out of 100
# Step 292 Loss 1.1299068 Correct 41 out of 100
# Step 293 Loss 1.1477075 Correct 37 out of 100
# Step 294 Loss 1.1336838 Correct 31 out of 100
# Step 295 Loss 1.1216567 Correct 32 out of 100
# Step 296 Loss 1.1326087 Correct 29 out of 100
# Step 297 Loss 1.1313797 Correct 24 out of 100
# Step 298 Loss 1.1571177 Correct 34 out of 100
# Step 299 Loss 1.111176 Correct 31 out of 100
# Step 300 Loss 1.0911238 Correct 40 out of 100
# Step 301 Loss 1.0982212 Correct 36 out of 100
# Step 302 Loss 1.0992478 Correct 33 out of 100
# Step 303 Loss 1.101017 Correct 34 out of 100
# Step 304 Loss 1.0914972 Correct 44 out of 100
# Step 305 Loss 1.0912796 Correct 42 out of 100
# Step 306 Loss 1.0960442 Correct 37 out of 100
# Step 307 Loss 1.077751 Correct 34 out of 100
# Step 308 Loss 1.0809817 Correct 44 out of 100
# Step 309 Loss 1.1370986 Correct 31 out of 100
# Step 310 Loss 1.1503596 Correct 30 out of 100
# Step 311 Loss 1.1352855 Correct 33 out of 100
# Step 312 Loss 1.1110973 Correct 32 out of 100
# Step 313 Loss 1.145707 Correct 27 out of 100
# Step 314 Loss 1.1884091 Correct 31 out of 100
# Step 315 Loss 1.1355505 Correct 36 out of 100
# Step 316 Loss 1.0932546 Correct 33 out of 100
# Step 317 Loss 1.1544409 Correct 30 out of 100
# Step 318 Loss 1.1131692 Correct 39 out of 100
# Step 319 Loss 1.1084061 Correct 33 out of 100
# Step 320 Loss 1.103898 Correct 31 out of 100
# Step 321 Loss 1.1048344 Correct 34 out of 100
# Step 322 Loss 1.09638 Correct 28 out of 100
# Step 323 Loss 1.1032908 Correct 40 out of 100
# Step 324 Loss 1.0901859 Correct 40 out of 100
# Step 325 Loss 1.1354921 Correct 28 out of 100
# Step 326 Loss 1.1841971 Correct 27 out of 100
# Step 327 Loss 1.1289252 Correct 36 out of 100
# Step 328 Loss 1.0989107 Correct 32 out of 100
# Step 329 Loss 1.0926471 Correct 42 out of 100
# Step 330 Loss 1.1373258 Correct 31 out of 100
# Step 331 Loss 1.1475093 Correct 30 out of 100
# Step 332 Loss 1.1188136 Correct 33 out of 100
# Step 333 Loss 1.1030197 Correct 37 out of 100
# Step 334 Loss 1.1312686 Correct 27 out of 100
# Step 335 Loss 1.13856 Correct 31 out of 100
# Step 336 Loss 1.0964863 Correct 36 out of 100
# Step 337 Loss 1.117773 Correct 29 out of 100
# Step 338 Loss 1.11066 Correct 36 out of 100
# Step 339 Loss 1.0944184 Correct 35 out of 100
# Step 340 Loss 1.0834966 Correct 39 out of 100
# Step 341 Loss 1.1358343 Correct 28 out of 100
# Step 342 Loss 1.1334175 Correct 31 out of 100
# Step 343 Loss 1.120454 Correct 32 out of 100
# Step 344 Loss 1.1048644 Correct 33 out of 100
# Step 345 Loss 1.1025437 Correct 31 out of 100
# Step 346 Loss 1.1132427 Correct 30 out of 100
# Step 347 Loss 1.1248525 Correct 31 out of 100
# Step 348 Loss 1.1113695 Correct 34 out of 100
# Step 349 Loss 1.1211585 Correct 23 out of 100
# Step 350 Loss 1.1850106 Correct 29 out of 100
# Step 351 Loss 1.1381462 Correct 32 out of 100
# Step 352 Loss 1.0971203 Correct 40 out of 100
# Step 353 Loss 1.151717 Correct 37 out of 100
# Step 354 Loss 1.0935949 Correct 34 out of 100
# Step 355 Loss 1.0965096 Correct 36 out of 100
# Step 356 Loss 1.1124223 Correct 34 out of 100
# Step 357 Loss 1.1365157 Correct 29 out of 100
# Step 358 Loss 1.100139 Correct 39 out of 100
# Step 359 Loss 1.0925016 Correct 40 out of 100
# Step 360 Loss 1.1272007 Correct 30 out of 100
# Step 361 Loss 1.1141869 Correct 34 out of 100
# Step 362 Loss 1.0945967 Correct 38 out of 100
# Step 363 Loss 1.0819192 Correct 44 out of 100
# Step 364 Loss 1.127804 Correct 36 out of 100
# Step 365 Loss 1.0952905 Correct 40 out of 100
# Step 366 Loss 1.1131017 Correct 31 out of 100
# Step 367 Loss 1.1378986 Correct 33 out of 100
# Step 368 Loss 1.142751 Correct 26 out of 100
# Step 369 Loss 1.1352363 Correct 38 out of 100
# Step 370 Loss 1.1025398 Correct 34 out of 100
# Step 371 Loss 1.1118066 Correct 35 out of 100
# Step 372 Loss 1.1159476 Correct 25 out of 100
# Step 373 Loss 1.1548233 Correct 31 out of 100
# Step 374 Loss 1.129989 Correct 27 out of 100
# Step 375 Loss 1.12482 Correct 32 out of 100
# Step 376 Loss 1.1084496 Correct 26 out of 100
# Step 377 Loss 1.0902357 Correct 32 out of 100
# Step 378 Loss 1.1512823 Correct 29 out of 100
# Step 379 Loss 1.1253103 Correct 32 out of 100
# Step 380 Loss 1.1022935 Correct 29 out of 100
# Step 381 Loss 1.1193553 Correct 31 out of 100
# Step 382 Loss 1.1071022 Correct 28 out of 100
# Step 383 Loss 1.1354065 Correct 25 out of 100
# Step 384 Loss 1.1311078 Correct 30 out of 100
# Step 385 Loss 1.1086048 Correct 33 out of 100
# Step 386 Loss 1.0911857 Correct 38 out of 100
# Step 387 Loss 1.1102897 Correct 41 out of 100
# Step 388 Loss 1.1755881 Correct 25 out of 100
# Step 389 Loss 1.1232455 Correct 36 out of 100
# Step 390 Loss 1.1026082 Correct 35 out of 100
# Step 391 Loss 1.0983136 Correct 29 out of 100
# Step 392 Loss 1.0768971 Correct 43 out of 100
# Step 393 Loss 1.1148942 Correct 31 out of 100
# Step 394 Loss 1.1325893 Correct 33 out of 100
# Step 395 Loss 1.0737665 Correct 44 out of 100
# Step 396 Loss 1.0869737 Correct 41 out of 100
# Step 397 Loss 1.1100732 Correct 33 out of 100
# Step 398 Loss 1.1069739 Correct 28 out of 100
# Step 399 Loss 1.1078876 Correct 39 out of 100
# Step 400 Loss 1.0804018 Correct 47 out of 100
# Step 401 Loss 1.1852559 Correct 31 out of 100
# Step 402 Loss 1.1427575 Correct 38 out of 100
# Step 403 Loss 1.1729786 Correct 40 out of 100
# Step 404 Loss 1.144988 Correct 34 out of 100
# Step 405 Loss 1.0944792 Correct 38 out of 100
# Step 406 Loss 1.1236935 Correct 29 out of 100
# Step 407 Loss 1.133777 Correct 31 out of 100
# Step 408 Loss 1.0953289 Correct 35 out of 100
# Step 409 Loss 1.0940226 Correct 36 out of 100
# Step 410 Loss 1.1067461 Correct 31 out of 100
# Step 411 Loss 1.1052063 Correct 30 out of 100
# Step 412 Loss 1.0908334 Correct 34 out of 100
# Step 413 Loss 1.1312989 Correct 29 out of 100
# Step 414 Loss 1.1475021 Correct 29 out of 100
# Step 415 Loss 1.1139178 Correct 38 out of 100
# Step 416 Loss 1.1094043 Correct 33 out of 100
# Step 417 Loss 1.117992 Correct 30 out of 100
# Step 418 Loss 1.1191831 Correct 30 out of 100
# Step 419 Loss 1.1149374 Correct 31 out of 100
# Step 420 Loss 1.0994008 Correct 36 out of 100
# Step 421 Loss 1.0969734 Correct 34 out of 100
# Step 422 Loss 1.0966074 Correct 34 out of 100
# Step 423 Loss 1.0922753 Correct 38 out of 100
# Step 424 Loss 1.0890117 Correct 42 out of 100
# Step 425 Loss 1.0903105 Correct 40 out of 100
# Step 426 Loss 1.0726165 Correct 44 out of 100
# Step 427 Loss 1.1410607 Correct 33 out of 100
# Step 428 Loss 1.1184036 Correct 30 out of 100
# Step 429 Loss 1.0709511 Correct 45 out of 100
# Step 430 Loss 1.1160675 Correct 37 out of 100
# Step 431 Loss 1.0997323 Correct 32 out of 100
# Step 432 Loss 1.0936526 Correct 38 out of 100
# Step 433 Loss 1.0900608 Correct 43 out of 100
# Step 434 Loss 1.1341835 Correct 40 out of 100
# Step 435 Loss 1.0868421 Correct 45 out of 100
# Step 436 Loss 1.1090192 Correct 40 out of 100
# Step 437 Loss 1.1764883 Correct 32 out of 100
# Step 438 Loss 1.1985184 Correct 29 out of 100
# Step 439 Loss 1.1575968 Correct 32 out of 100
# Step 440 Loss 1.1184458 Correct 28 out of 100
# Step 441 Loss 1.1665828 Correct 31 out of 100
# Step 442 Loss 1.1303959 Correct 35 out of 100
# Step 443 Loss 1.096196 Correct 40 out of 100
# Step 444 Loss 1.0991735 Correct 36 out of 100
# Step 445 Loss 1.1016504 Correct 30 out of 100
# Step 446 Loss 1.1006563 Correct 32 out of 100
# Step 447 Loss 1.0985333 Correct 34 out of 100
# Step 448 Loss 1.0897617 Correct 40 out of 100
# Step 449 Loss 1.1388361 Correct 30 out of 100
# Step 450 Loss 1.1468513 Correct 25 out of 100
# Step 451 Loss 1.1135517 Correct 45 out of 100
# Step 452 Loss 1.1306282 Correct 37 out of 100
# Step 453 Loss 1.097144 Correct 36 out of 100
# Step 454 Loss 1.0897965 Correct 41 out of 100
# Step 455 Loss 1.0998634 Correct 38 out of 100
# Step 456 Loss 1.1020496 Correct 30 out of 100
# Step 457 Loss 1.1222408 Correct 28 out of 100
# Step 458 Loss 1.1435903 Correct 31 out of 100
# Step 459 Loss 1.1052983 Correct 37 out of 100
# Step 460 Loss 1.0932649 Correct 44 out of 100
# Step 461 Loss 1.1526128 Correct 31 out of 100
# Step 462 Loss 1.1252831 Correct 27 out of 100
# Step 463 Loss 1.0969435 Correct 46 out of 100
# Step 464 Loss 1.1375663 Correct 34 out of 100
# Step 465 Loss 1.1283065 Correct 28 out of 100
# Step 466 Loss 1.0939026 Correct 42 out of 100
# Step 467 Loss 1.1014493 Correct 38 out of 100
# Step 468 Loss 1.0777991 Correct 45 out of 100
# Step 469 Loss 1.110209 Correct 42 out of 100
# Step 470 Loss 1.120246 Correct 42 out of 100
# Step 471 Loss 1.0979055 Correct 38 out of 100
# Step 472 Loss 1.0888647 Correct 37 out of 100
# Step 473 Loss 1.1178225 Correct 29 out of 100
# Step 474 Loss 1.1295543 Correct 36 out of 100
# Step 475 Loss 1.1797853 Correct 30 out of 100
# Step 476 Loss 1.11392 Correct 30 out of 100
# Step 477 Loss 1.1176033 Correct 29 out of 100
# Step 478 Loss 1.0770209 Correct 44 out of 100
# Step 479 Loss 1.1295841 Correct 30 out of 100
# Step 480 Loss 1.1167995 Correct 29 out of 100
# Step 481 Loss 1.1061891 Correct 44 out of 100
# Step 482 Loss 1.110542 Correct 33 out of 100
# Step 483 Loss 1.1796292 Correct 22 out of 100
# Step 484 Loss 1.2316456 Correct 26 out of 100
# Step 485 Loss 1.0669974 Correct 40 out of 100
# Step 486 Loss 1.1067735 Correct 37 out of 100
# Step 487 Loss 1.095103 Correct 38 out of 100
# Step 488 Loss 1.0982792 Correct 36 out of 100
# Step 489 Loss 1.1007756 Correct 30 out of 100
# Step 490 Loss 1.1014647 Correct 34 out of 100
# Step 491 Loss 1.0993447 Correct 30 out of 100
# Step 492 Loss 1.1152043 Correct 33 out of 100
# Step 493 Loss 1.0965124 Correct 35 out of 100
# Step 494 Loss 1.1063555 Correct 32 out of 100
# Step 495 Loss 1.0934356 Correct 38 out of 100
# Step 496 Loss 1.098558 Correct 36 out of 100
# Step 497 Loss 1.0882314 Correct 39 out of 100
# Step 498 Loss 1.0759438 Correct 33 out of 100
# Step 499 Loss 1.1432369 Correct 34 out of 100
# Step 500 Loss 1.1072923 Correct 26 out of 100
# Step 501 Loss 1.1372931 Correct 29 out of 100
# Step 502 Loss 1.1128396 Correct 25 out of 100
# Step 503 Loss 1.1562287 Correct 27 out of 100
# Step 504 Loss 1.1167967 Correct 37 out of 100
# Step 505 Loss 1.1063397 Correct 32 out of 100
# Step 506 Loss 1.1003094 Correct 34 out of 100
# Step 507 Loss 1.0931367 Correct 35 out of 100
# Step 508 Loss 1.1500304 Correct 36 out of 100
# Step 509 Loss 1.116989 Correct 32 out of 100
# Step 510 Loss 1.0994136 Correct 31 out of 100
# Step 511 Loss 1.1148256 Correct 30 out of 100
# Step 512 Loss 1.111 Correct 33 out of 100
# Step 513 Loss 1.0945503 Correct 38 out of 100
# Step 514 Loss 1.1253474 Correct 39 out of 100
# Step 515 Loss 1.0875169 Correct 39 out of 100
# Step 516 Loss 1.1059831 Correct 32 out of 100
# Step 517 Loss 1.0819784 Correct 43 out of 100
# Step 518 Loss 1.1359552 Correct 31 out of 100
# Step 519 Loss 1.0895054 Correct 34 out of 100
# Step 520 Loss 1.0732977 Correct 47 out of 100
# Step 521 Loss 1.1220858 Correct 38 out of 100
# Step 522 Loss 1.0973481 Correct 35 out of 100
# Step 523 Loss 1.0952156 Correct 37 out of 100
# Step 524 Loss 1.0823193 Correct 41 out of 100
# Step 525 Loss 1.0965306 Correct 37 out of 100
# Step 526 Loss 1.1086843 Correct 24 out of 100
# Step 527 Loss 1.1452464 Correct 33 out of 100
# Step 528 Loss 1.1102829 Correct 30 out of 100
# Step 529 Loss 1.1099106 Correct 35 out of 100
# Step 530 Loss 1.1206409 Correct 29 out of 100
# Step 531 Loss 1.0906286 Correct 34 out of 100
# Step 532 Loss 1.1157299 Correct 32 out of 100
# Step 533 Loss 1.1185607 Correct 20 out of 100
# Step 534 Loss 1.1199198 Correct 40 out of 100
# Step 535 Loss 1.1043131 Correct 35 out of 100
# Step 536 Loss 1.1085303 Correct 35 out of 100
# Step 537 Loss 1.1220661 Correct 31 out of 100
# Step 538 Loss 1.0962591 Correct 37 out of 100
# Step 539 Loss 1.1065701 Correct 34 out of 100
# Step 540 Loss 1.1006583 Correct 30 out of 100
# Step 541 Loss 1.1085356 Correct 36 out of 100
# Step 542 Loss 1.0989412 Correct 29 out of 100
# Step 543 Loss 1.0785093 Correct 42 out of 100
# Step 544 Loss 1.1339694 Correct 33 out of 100
# Step 545 Loss 1.0855583 Correct 41 out of 100
# Step 546 Loss 1.0933741 Correct 41 out of 100
# Step 547 Loss 1.1165818 Correct 32 out of 100
# Step 548 Loss 1.1078556 Correct 37 out of 100
# Step 549 Loss 1.1411725 Correct 35 out of 100
# Step 550 Loss 1.0818346 Correct 42 out of 100
# Step 551 Loss 1.1220303 Correct 34 out of 100
# Step 552 Loss 1.1131396 Correct 34 out of 100
# Step 553 Loss 1.1013892 Correct 33 out of 100
# Step 554 Loss 1.1438218 Correct 30 out of 100
# Step 555 Loss 1.1534376 Correct 34 out of 100
# Step 556 Loss 1.1115022 Correct 34 out of 100
# Step 557 Loss 1.1190187 Correct 35 out of 100
# Step 558 Loss 1.1097984 Correct 26 out of 100
# Step 559 Loss 1.0751147 Correct 46 out of 100
# Step 560 Loss 1.1128694 Correct 38 out of 100
# Step 561 Loss 1.1015823 Correct 33 out of 100
# Step 562 Loss 1.1153793 Correct 25 out of 100
# Step 563 Loss 1.1240565 Correct 34 out of 100
# Step 564 Loss 1.1754208 Correct 18 out of 100
# Step 565 Loss 1.2207142 Correct 31 out of 100
# Step 566 Loss 1.1184615 Correct 28 out of 100
# Step 567 Loss 1.0621014 Correct 48 out of 100
# Step 568 Loss 1.1642536 Correct 34 out of 100
# Step 569 Loss 1.1007507 Correct 36 out of 100
# Step 570 Loss 1.0804203 Correct 40 out of 100
# Step 571 Loss 1.1079878 Correct 42 out of 100
# Step 572 Loss 1.0924214 Correct 40 out of 100
# Step 573 Loss 1.0831838 Correct 42 out of 100
# Step 574 Loss 1.0794019 Correct 41 out of 100
# Step 575 Loss 1.1418202 Correct 35 out of 100
# Step 576 Loss 1.1013802 Correct 33 out of 100
# Step 577 Loss 1.1117525 Correct 34 out of 100
# Step 578 Loss 1.1016731 Correct 32 out of 100
# Step 579 Loss 1.0993686 Correct 42 out of 100
# Step 580 Loss 1.1075044 Correct 24 out of 100
# Step 581 Loss 1.149742 Correct 32 out of 100
# Step 582 Loss 1.0889367 Correct 27 out of 100
# Step 583 Loss 1.1886712 Correct 34 out of 100
# Step 584 Loss 1.1244087 Correct 33 out of 100
# Step 585 Loss 1.1130242 Correct 37 out of 100
# Step 586 Loss 1.0906981 Correct 43 out of 100
# Step 587 Loss 1.0769459 Correct 42 out of 100
# Step 588 Loss 1.0740706 Correct 39 out of 100
# Step 589 Loss 1.1646155 Correct 27 out of 100
# Step 590 Loss 1.1296656 Correct 33 out of 100
# Step 591 Loss 1.1124792 Correct 26 out of 100
# Step 592 Loss 1.089622 Correct 35 out of 100
# Step 593 Loss 1.1159753 Correct 39 out of 100
# Step 594 Loss 1.1448435 Correct 28 out of 100
# Step 595 Loss 1.1028181 Correct 39 out of 100
# Step 596 Loss 1.0979428 Correct 33 out of 100
# Step 597 Loss 1.1175767 Correct 32 out of 100
# Step 598 Loss 1.0826032 Correct 44 out of 100
# Step 599 Loss 1.1597842 Correct 28 out of 100
# Step 600 Loss 1.1122407 Correct 37 out of 100
# Step 601 Loss 1.1006908 Correct 37 out of 100
# Step 602 Loss 1.1198866 Correct 30 out of 100
# Step 603 Loss 1.0963305 Correct 41 out of 100
# Step 604 Loss 1.0722083 Correct 49 out of 100
# Step 605 Loss 1.1381773 Correct 38 out of 100
# Step 606 Loss 1.0953166 Correct 33 out of 100
# Step 607 Loss 1.1012785 Correct 36 out of 100
# Step 608 Loss 1.0952551 Correct 40 out of 100
# Step 609 Loss 1.104905 Correct 37 out of 100
# Step 610 Loss 1.0910324 Correct 36 out of 100
# Step 611 Loss 1.0828209 Correct 41 out of 100
# Step 612 Loss 1.1240286 Correct 33 out of 100
# Step 613 Loss 1.0963603 Correct 32 out of 100
# Step 614 Loss 1.085022 Correct 41 out of 100
# Step 615 Loss 1.1269491 Correct 28 out of 100
# Step 616 Loss 1.1192967 Correct 34 out of 100
# Step 617 Loss 1.0976783 Correct 35 out of 100
# Step 618 Loss 1.0948735 Correct 48 out of 100
# Step 619 Loss 1.1594733 Correct 33 out of 100
# Step 620 Loss 1.1111833 Correct 24 out of 100
# Step 621 Loss 1.0919442 Correct 39 out of 100
# Step 622 Loss 1.0761857 Correct 44 out of 100
# Step 623 Loss 1.099453 Correct 38 out of 100
# Step 624 Loss 1.084357 Correct 39 out of 100
# Step 625 Loss 1.0885248 Correct 35 out of 100
# Step 626 Loss 1.1119795 Correct 34 out of 100
# Step 627 Loss 1.0986652 Correct 35 out of 100
# Step 628 Loss 1.1305451 Correct 40 out of 100
# Step 629 Loss 1.1560948 Correct 30 out of 100
# Step 630 Loss 1.1229154 Correct 25 out of 100
# Step 631 Loss 1.121328 Correct 32 out of 100
# Step 632 Loss 1.1008453 Correct 31 out of 100
# Step 633 Loss 1.088715 Correct 37 out of 100
# Step 634 Loss 1.0956268 Correct 33 out of 100
# Step 635 Loss 1.114806 Correct 29 out of 100
# Step 636 Loss 1.0878576 Correct 40 out of 100
# Step 637 Loss 1.1116779 Correct 31 out of 100
# Step 638 Loss 1.0853153 Correct 38 out of 100
# Step 639 Loss 1.1242675 Correct 29 out of 100
# Step 640 Loss 1.1019584 Correct 31 out of 100
# Step 641 Loss 1.0998143 Correct 35 out of 100
# Step 642 Loss 1.0973516 Correct 40 out of 100
# Step 643 Loss 1.1126494 Correct 32 out of 100
# Step 644 Loss 1.1135349 Correct 28 out of 100
# Step 645 Loss 1.1165434 Correct 34 out of 100
# Step 646 Loss 1.1090989 Correct 24 out of 100
# Step 647 Loss 1.14696 Correct 34 out of 100
# Step 648 Loss 1.1207314 Correct 25 out of 100
# Step 649 Loss 1.0493517 Correct 44 out of 100
# Step 650 Loss 1.1356692 Correct 34 out of 100
# Step 651 Loss 1.1025356 Correct 29 out of 100
# Step 652 Loss 1.1006835 Correct 36 out of 100
# Step 653 Loss 1.1020944 Correct 37 out of 100
# Step 654 Loss 1.1012412 Correct 30 out of 100
# Step 655 Loss 1.1118171 Correct 31 out of 100
# Step 656 Loss 1.1027236 Correct 34 out of 100
# Step 657 Loss 1.1036633 Correct 32 out of 100
# Step 658 Loss 1.1166749 Correct 22 out of 100
# Step 659 Loss 1.1791906 Correct 34 out of 100
# Step 660 Loss 1.1192524 Correct 31 out of 100
# Step 661 Loss 1.0987763 Correct 33 out of 100
# Step 662 Loss 1.1065649 Correct 30 out of 100
# Step 663 Loss 1.1262684 Correct 28 out of 100
# Step 664 Loss 1.0597522 Correct 51 out of 100
# Step 665 Loss 1.1444628 Correct 37 out of 100
# Step 666 Loss 1.0923736 Correct 39 out of 100
# Step 667 Loss 1.1097839 Correct 32 out of 100
# Step 668 Loss 1.1136562 Correct 30 out of 100
# Step 669 Loss 1.1087486 Correct 38 out of 100
# Step 670 Loss 1.1034648 Correct 36 out of 100
# Step 671 Loss 1.1048697 Correct 27 out of 100
# Step 672 Loss 1.0738837 Correct 42 out of 100
# Step 673 Loss 1.1462153 Correct 35 out of 100
# Step 674 Loss 1.130925 Correct 30 out of 100
# Step 675 Loss 1.0876688 Correct 40 out of 100
# Step 676 Loss 1.0896217 Correct 40 out of 100
# Step 677 Loss 1.1012814 Correct 39 out of 100
# Step 678 Loss 1.1236719 Correct 39 out of 100
# Step 679 Loss 1.1154159 Correct 35 out of 100
# Step 680 Loss 1.0999218 Correct 38 out of 100
# Step 681 Loss 1.1739374 Correct 25 out of 100
# Step 682 Loss 1.1138597 Correct 26 out of 100
# Step 683 Loss 1.0878301 Correct 41 out of 100
# Step 684 Loss 1.0840816 Correct 42 out of 100
# Step 685 Loss 1.1266974 Correct 32 out of 100
# Step 686 Loss 1.1306053 Correct 31 out of 100
# Step 687 Loss 1.0973197 Correct 39 out of 100
# Step 688 Loss 1.0887762 Correct 41 out of 100
# Step 689 Loss 1.1179405 Correct 30 out of 100
# Step 690 Loss 1.2388074 Correct 25 out of 100
# Step 691 Loss 1.1291652 Correct 39 out of 100
# Step 692 Loss 1.0863465 Correct 42 out of 100
# Step 693 Loss 1.091268 Correct 39 out of 100
# Step 694 Loss 1.1032983 Correct 32 out of 100
# Step 695 Loss 1.1017063 Correct 34 out of 100
# Step 696 Loss 1.104299 Correct 33 out of 100
# Step 697 Loss 1.1033652 Correct 31 out of 100
# Step 698 Loss 1.1219637 Correct 31 out of 100
# Step 699 Loss 1.117187 Correct 28 out of 100
# Step 700 Loss 1.1202989 Correct 35 out of 100
# Step 701 Loss 1.10162 Correct 29 out of 100
# Step 702 Loss 1.1513124 Correct 29 out of 100
# Step 703 Loss 1.1246595 Correct 36 out of 100
# Step 704 Loss 1.1213602 Correct 36 out of 100
# Step 705 Loss 1.0901345 Correct 32 out of 100
# Step 706 Loss 1.1341764 Correct 32 out of 100
# Step 707 Loss 1.1184126 Correct 27 out of 100
# Step 708 Loss 1.104309 Correct 30 out of 100
# Step 709 Loss 1.0848894 Correct 41 out of 100
# Step 710 Loss 1.0897655 Correct 40 out of 100
# Step 711 Loss 1.1271561 Correct 30 out of 100
# Step 712 Loss 1.1034175 Correct 35 out of 100
# Step 713 Loss 1.0969834 Correct 34 out of 100
# Step 714 Loss 1.104809 Correct 30 out of 100
# Step 715 Loss 1.1217221 Correct 29 out of 100
# Step 716 Loss 1.0828193 Correct 36 out of 100
# Step 717 Loss 1.0860221 Correct 40 out of 100
# Step 718 Loss 1.1212921 Correct 32 out of 100
# Step 719 Loss 1.0895339 Correct 39 out of 100
# Step 720 Loss 1.1069778 Correct 32 out of 100
# Step 721 Loss 1.0967637 Correct 36 out of 100
# Step 722 Loss 1.0937468 Correct 38 out of 100
# Step 723 Loss 1.099625 Correct 41 out of 100
# Step 724 Loss 1.0875175 Correct 39 out of 100
# Step 725 Loss 1.0902205 Correct 39 out of 100
# Step 726 Loss 1.1112827 Correct 34 out of 100
# Step 727 Loss 1.0987915 Correct 33 out of 100
# Step 728 Loss 1.1145992 Correct 26 out of 100
# Step 729 Loss 1.1671417 Correct 31 out of 100
# Step 730 Loss 1.0903887 Correct 39 out of 100
# Step 731 Loss 1.1007248 Correct 35 out of 100
# Step 732 Loss 1.1025969 Correct 21 out of 100
# Step 733 Loss 1.1901582 Correct 29 out of 100
# Step 734 Loss 1.1027291 Correct 38 out of 100
# Step 735 Loss 1.0926895 Correct 40 out of 100
# Step 736 Loss 1.0992879 Correct 38 out of 100
# Step 737 Loss 1.0917516 Correct 37 out of 100
# Step 738 Loss 1.0992968 Correct 49 out of 100
# Step 739 Loss 1.0866177 Correct 41 out of 100
# Step 740 Loss 1.0797246 Correct 28 out of 100
# Step 741 Loss 1.1062709 Correct 42 out of 100
# Step 742 Loss 1.1036941 Correct 34 out of 100
# Step 743 Loss 1.0999203 Correct 28 out of 100
# Step 744 Loss 1.0950094 Correct 36 out of 100
# Step 745 Loss 1.0964794 Correct 35 out of 100
# Step 746 Loss 1.096152 Correct 43 out of 100
# Step 747 Loss 1.1333647 Correct 30 out of 100
# Step 748 Loss 1.1207625 Correct 32 out of 100
# Step 749 Loss 1.1105299 Correct 30 out of 100
# Step 750 Loss 1.1215863 Correct 26 out of 100
# Step 751 Loss 1.1194214 Correct 33 out of 100
# Step 752 Loss 1.0986195 Correct 34 out of 100
# Step 753 Loss 1.0979019 Correct 36 out of 100
# Step 754 Loss 1.1026464 Correct 37 out of 100
# Step 755 Loss 1.0933036 Correct 31 out of 100
# Step 756 Loss 1.1234667 Correct 33 out of 100
# Step 757 Loss 1.0975661 Correct 31 out of 100
# Step 758 Loss 1.0868046 Correct 45 out of 100
# Step 759 Loss 1.1226788 Correct 37 out of 100
# Step 760 Loss 1.0951617 Correct 38 out of 100
# Step 761 Loss 1.1010109 Correct 34 out of 100
# Step 762 Loss 1.0946836 Correct 36 out of 100
# Step 763 Loss 1.094725 Correct 28 out of 100
# Step 764 Loss 1.1427217 Correct 30 out of 100
# Step 765 Loss 1.1183989 Correct 30 out of 100
# Step 766 Loss 1.0895875 Correct 39 out of 100
# Step 767 Loss 1.1119968 Correct 30 out of 100
# Step 768 Loss 1.0892007 Correct 46 out of 100
# Step 769 Loss 1.1665267 Correct 29 out of 100
# Step 770 Loss 1.0865815 Correct 40 out of 100
# Step 771 Loss 1.105027 Correct 34 out of 100
# Step 772 Loss 1.0980145 Correct 35 out of 100
# Step 773 Loss 1.0881268 Correct 42 out of 100
# Step 774 Loss 1.072892 Correct 42 out of 100
# Step 775 Loss 1.0801579 Correct 42 out of 100
# Step 776 Loss 1.1469051 Correct 29 out of 100
# Step 777 Loss 1.115465 Correct 33 out of 100
# Step 778 Loss 1.1038655 Correct 34 out of 100
# Step 779 Loss 1.1039625 Correct 36 out of 100
# Step 780 Loss 1.096733 Correct 41 out of 100
# Step 781 Loss 1.1257595 Correct 36 out of 100
# Step 782 Loss 1.0945518 Correct 32 out of 100
# Step 783 Loss 1.1152722 Correct 28 out of 100
# Step 784 Loss 1.0947274 Correct 39 out of 100
# Step 785 Loss 1.0965958 Correct 37 out of 100
# Step 786 Loss 1.1043136 Correct 34 out of 100
# Step 787 Loss 1.106483 Correct 41 out of 100
# Step 788 Loss 1.0913434 Correct 40 out of 100
# Step 789 Loss 1.0895809 Correct 37 out of 100
# Step 790 Loss 1.1212449 Correct 31 out of 100
# Step 791 Loss 1.1184596 Correct 36 out of 100
# Step 792 Loss 1.0983374 Correct 35 out of 100
# Step 793 Loss 1.1026391 Correct 34 out of 100
# Step 794 Loss 1.1069442 Correct 29 out of 100
# Step 795 Loss 1.1098763 Correct 30 out of 100
# Step 796 Loss 1.113017 Correct 33 out of 100
# Step 797 Loss 1.1130009 Correct 32 out of 100
# Step 798 Loss 1.0928888 Correct 37 out of 100
# Step 799 Loss 1.101282 Correct 34 out of 100
# Step 800 Loss 1.0940374 Correct 35 out of 100
# Step 801 Loss 1.0773473 Correct 46 out of 100
# Step 802 Loss 1.1015567 Correct 40 out of 100
# Step 803 Loss 1.0816159 Correct 46 out of 100
# Step 804 Loss 1.0805663 Correct 45 out of 100
# Step 805 Loss 1.0911082 Correct 40 out of 100
# Step 806 Loss 1.0927666 Correct 38 out of 100
# Step 807 Loss 1.0911158 Correct 38 out of 100
# Step 808 Loss 1.1017184 Correct 38 out of 100
# Step 809 Loss 1.1465763 Correct 34 out of 100
# Step 810 Loss 1.1427678 Correct 27 out of 100
# Step 811 Loss 1.092628 Correct 39 out of 100
# Step 812 Loss 1.0848644 Correct 42 out of 100
# Step 813 Loss 1.1056709 Correct 36 out of 100
# Step 814 Loss 1.0949671 Correct 40 out of 100
# Step 815 Loss 1.1024826 Correct 40 out of 100
# Step 816 Loss 1.1198876 Correct 34 out of 100
# Step 817 Loss 1.1096228 Correct 29 out of 100
# Step 818 Loss 1.0897007 Correct 37 out of 100
# Step 819 Loss 1.1157365 Correct 33 out of 100
# Step 820 Loss 1.0992308 Correct 34 out of 100
# Step 821 Loss 1.0950087 Correct 36 out of 100
# Step 822 Loss 1.0957121 Correct 37 out of 100
# Step 823 Loss 1.0963329 Correct 33 out of 100
# Step 824 Loss 1.103288 Correct 34 out of 100
# Step 825 Loss 1.1167787 Correct 28 out of 100
# Step 826 Loss 1.1013203 Correct 33 out of 100
# Step 827 Loss 1.0963633 Correct 36 out of 100
# Step 828 Loss 1.0979645 Correct 33 out of 100
# Step 829 Loss 1.0927272 Correct 34 out of 100
# Step 830 Loss 1.0934845 Correct 35 out of 100
# Step 831 Loss 1.0697408 Correct 41 out of 100
# Step 832 Loss 1.0535691 Correct 45 out of 100
# Step 833 Loss 1.0849997 Correct 40 out of 100
# Step 834 Loss 1.1070892 Correct 38 out of 100
# Step 835 Loss 1.1088561 Correct 32 out of 100
# Step 836 Loss 1.1030807 Correct 35 out of 100
# Step 837 Loss 1.1006252 Correct 33 out of 100
# Step 838 Loss 1.1023672 Correct 33 out of 100
# Step 839 Loss 1.1021279 Correct 29 out of 100
# Step 840 Loss 1.097879 Correct 39 out of 100
# Step 841 Loss 1.1009425 Correct 37 out of 100
# Step 842 Loss 1.0883232 Correct 38 out of 100
# Step 843 Loss 1.0900276 Correct 39 out of 100
# Step 844 Loss 1.0995655 Correct 34 out of 100
# Step 845 Loss 1.1136109 Correct 29 out of 100
# Step 846 Loss 1.1080602 Correct 26 out of 100
# Step 847 Loss 1.1026886 Correct 37 out of 100
# Step 848 Loss 1.0955784 Correct 49 out of 100
# Step 849 Loss 1.1052464 Correct 35 out of 100
# Step 850 Loss 1.1069831 Correct 35 out of 100
# Step 851 Loss 1.089382 Correct 41 out of 100
# Step 852 Loss 1.0973891 Correct 37 out of 100
# Step 853 Loss 1.107546 Correct 29 out of 100
# Step 854 Loss 1.1092923 Correct 27 out of 100
# Step 855 Loss 1.1445788 Correct 32 out of 100
# Step 856 Loss 1.1905252 Correct 26 out of 100
# Step 857 Loss 1.1341467 Correct 35 out of 100
# Step 858 Loss 1.098425 Correct 30 out of 100
# Step 859 Loss 1.1061554 Correct 33 out of 100
# Step 860 Loss 1.096551 Correct 35 out of 100
# Step 861 Loss 1.0924929 Correct 36 out of 100
# Step 862 Loss 1.0741851 Correct 42 out of 100
# Step 863 Loss 1.1424496 Correct 25 out of 100
# Step 864 Loss 1.1551464 Correct 33 out of 100
# Step 865 Loss 1.1077589 Correct 34 out of 100
# Step 866 Loss 1.1247151 Correct 23 out of 100
# Step 867 Loss 1.1261958 Correct 40 out of 100
# Step 868 Loss 1.0876162 Correct 37 out of 100
# Step 869 Loss 1.0935917 Correct 36 out of 100
# Step 870 Loss 1.1060265 Correct 30 out of 100
# Step 871 Loss 1.0959169 Correct 38 out of 100
# Step 872 Loss 1.121036 Correct 25 out of 100
# Step 873 Loss 1.105735 Correct 33 out of 100
# Step 874 Loss 1.0928597 Correct 37 out of 100
# Step 875 Loss 1.1065817 Correct 31 out of 100
# Step 876 Loss 1.1429503 Correct 31 out of 100
# Step 877 Loss 1.070105 Correct 44 out of 100
# Step 878 Loss 1.1464688 Correct 37 out of 100
# Step 879 Loss 1.0903476 Correct 41 out of 100
# Step 880 Loss 1.0994598 Correct 37 out of 100
# Step 881 Loss 1.095968 Correct 35 out of 100
# Step 882 Loss 1.0925736 Correct 37 out of 100
# Step 883 Loss 1.1125335 Correct 49 out of 100
# Step 884 Loss 1.0874147 Correct 37 out of 100
# Step 885 Loss 1.0947812 Correct 51 out of 100
# Step 886 Loss 1.1160809 Correct 29 out of 100
# Step 887 Loss 1.097295 Correct 39 out of 100
# Step 888 Loss 1.0907487 Correct 36 out of 100
# Step 889 Loss 1.0950369 Correct 44 out of 100
# Step 890 Loss 1.0851535 Correct 41 out of 100
# Step 891 Loss 1.1244887 Correct 30 out of 100
# Step 892 Loss 1.1581428 Correct 25 out of 100
# Step 893 Loss 1.0909587 Correct 38 out of 100
# Step 894 Loss 1.0941108 Correct 41 out of 100
# Step 895 Loss 1.0918971 Correct 35 out of 100
# Step 896 Loss 1.0872989 Correct 42 out of 100
# Step 897 Loss 1.1020736 Correct 36 out of 100
# Step 898 Loss 1.1202277 Correct 29 out of 100
# Step 899 Loss 1.0836991 Correct 40 out of 100
# Step 900 Loss 1.1187781 Correct 27 out of 100
# Step 901 Loss 1.0945425 Correct 36 out of 100
# Step 902 Loss 1.089161 Correct 31 out of 100
# Step 903 Loss 1.1149654 Correct 37 out of 100
# Step 904 Loss 1.0959891 Correct 34 out of 100
# Step 905 Loss 1.0933887 Correct 42 out of 100
# Step 906 Loss 1.0978663 Correct 40 out of 100
# Step 907 Loss 1.1041188 Correct 33 out of 100
# Step 908 Loss 1.0927495 Correct 33 out of 100
# Step 909 Loss 1.1117833 Correct 31 out of 100
# Step 910 Loss 1.1129221 Correct 25 out of 100
# Step 911 Loss 1.1282299 Correct 33 out of 100
# Step 912 Loss 1.0934826 Correct 36 out of 100
# Step 913 Loss 1.1040668 Correct 27 out of 100
# Step 914 Loss 1.1389058 Correct 21 out of 100
# Step 915 Loss 1.1380827 Correct 36 out of 100
# Step 916 Loss 1.0950638 Correct 32 out of 100
# Step 917 Loss 1.1078863 Correct 32 out of 100
# Step 918 Loss 1.0918349 Correct 50 out of 100
# Step 919 Loss 1.1032594 Correct 35 out of 100
# Step 920 Loss 1.0961014 Correct 34 out of 100
# Step 921 Loss 1.0930285 Correct 34 out of 100
# Step 922 Loss 1.1068003 Correct 22 out of 100
# Step 923 Loss 1.1153423 Correct 38 out of 100
# Step 924 Loss 1.1001796 Correct 29 out of 100
# Step 925 Loss 1.1491593 Correct 29 out of 100
# Step 926 Loss 1.1040412 Correct 34 out of 100
# Step 927 Loss 1.0962791 Correct 35 out of 100
# Step 928 Loss 1.0961577 Correct 31 out of 100
# Step 929 Loss 1.0980209 Correct 31 out of 100
# Step 930 Loss 1.135938 Correct 26 out of 100
# Step 931 Loss 1.1072959 Correct 34 out of 100
# Step 932 Loss 1.1020652 Correct 35 out of 100
# Step 933 Loss 1.1047591 Correct 27 out of 100
# Step 934 Loss 1.0638752 Correct 44 out of 100
# Step 935 Loss 1.1472954 Correct 37 out of 100
# Step 936 Loss 1.1231914 Correct 31 out of 100
# Step 937 Loss 1.083834 Correct 42 out of 100
# Step 938 Loss 1.1041757 Correct 36 out of 100
# Step 939 Loss 1.1202378 Correct 28 out of 100
# Step 940 Loss 1.1162953 Correct 32 out of 100
# Step 941 Loss 1.1021962 Correct 32 out of 100
# Step 942 Loss 1.1003679 Correct 31 out of 100
# Step 943 Loss 1.1015822 Correct 33 out of 100
# Step 944 Loss 1.0978214 Correct 38 out of 100
# Step 945 Loss 1.1347549 Correct 35 out of 100
# Step 946 Loss 1.0968256 Correct 45 out of 100
# Step 947 Loss 1.0946957 Correct 36 out of 100
# Step 948 Loss 1.1110343 Correct 28 out of 100
# Step 949 Loss 1.0995091 Correct 40 out of 100
# Step 950 Loss 1.1175482 Correct 29 out of 100
# Step 951 Loss 1.111592 Correct 31 out of 100
# Step 952 Loss 1.1063265 Correct 45 out of 100
# Step 953 Loss 1.0851363 Correct 40 out of 100
# Step 954 Loss 1.0780602 Correct 43 out of 100
# Step 955 Loss 1.1254241 Correct 32 out of 100
# Step 956 Loss 1.0922971 Correct 38 out of 100
# Step 957 Loss 1.0848229 Correct 36 out of 100
# Step 958 Loss 1.1165448 Correct 35 out of 100
# Step 959 Loss 1.0968281 Correct 27 out of 100
# Step 960 Loss 1.1011921 Correct 38 out of 100
# Step 961 Loss 1.1027813 Correct 29 out of 100
# Step 962 Loss 1.1239783 Correct 34 out of 100
# Step 963 Loss 1.1087588 Correct 31 out of 100
# Step 964 Loss 1.0800424 Correct 43 out of 100
# Step 965 Loss 1.1282823 Correct 32 out of 100
# Step 966 Loss 1.1020547 Correct 32 out of 100
# Step 967 Loss 1.1255296 Correct 32 out of 100
# Step 968 Loss 1.0991055 Correct 39 out of 100
# Step 969 Loss 1.0929955 Correct 38 out of 100
# Step 970 Loss 1.1014615 Correct 33 out of 100
# Step 971 Loss 1.0928569 Correct 36 out of 100
# Step 972 Loss 1.0774478 Correct 43 out of 100
# Step 973 Loss 1.1607287 Correct 27 out of 100
# Step 974 Loss 1.1409001 Correct 29 out of 100
# Step 975 Loss 1.1014673 Correct 44 out of 100
# Step 976 Loss 1.1025838 Correct 31 out of 100
# Step 977 Loss 1.1377338 Correct 29 out of 100
# Step 978 Loss 1.1354808 Correct 30 out of 100
# Step 979 Loss 1.0970341 Correct 38 out of 100
# Step 980 Loss 1.0902022 Correct 37 out of 100
# Step 981 Loss 1.097525 Correct 31 out of 100
# Step 982 Loss 1.111812 Correct 30 out of 100
# Step 983 Loss 1.07304 Correct 44 out of 100
# Step 984 Loss 1.1244775 Correct 34 out of 100
# Step 985 Loss 1.1112467 Correct 28 out of 100
# Step 986 Loss 1.113315 Correct 30 out of 100
# Step 987 Loss 1.0739465 Correct 45 out of 100
# Step 988 Loss 1.1236206 Correct 35 out of 100
# Step 989 Loss 1.0954341 Correct 34 out of 100
# Step 990 Loss 1.0928315 Correct 37 out of 100
# Step 991 Loss 1.0942059 Correct 34 out of 100
# Step 992 Loss 1.0842999 Correct 38 out of 100
# Step 993 Loss 1.0980064 Correct 46 out of 100
# Step 994 Loss 1.0956095 Correct 36 out of 100
# Step 995 Loss 1.1014252 Correct 41 out of 100
# Step 996 Loss 1.1094708 Correct 21 out of 100
# Step 997 Loss 1.0990864 Correct 40 out of 100
# Step 998 Loss 1.1002963 Correct 32 out of 100
# Step 999 Loss 1.1158012 Correct 30 out of 100
# Step 1000 Loss 1.1101893 Correct 34 out of 100
# Step 1001 Loss 1.1019335 Correct 30 out of 100
# Step 1002 Loss 1.1093638 Correct 32 out of 100
# Step 1003 Loss 1.0952102 Correct 37 out of 100
# Step 1004 Loss 1.1115928 Correct 27 out of 100
# Step 1005 Loss 1.1038613 Correct 36 out of 100
# Step 1006 Loss 1.0960838 Correct 29 out of 100
# Step 1007 Loss 1.104138 Correct 36 out of 100
# Step 1008 Loss 1.097802 Correct 39 out of 100
# Step 1009 Loss 1.1050183 Correct 32 out of 100
# Step 1010 Loss 1.1030567 Correct 34 out of 100
# Step 1011 Loss 1.0929261 Correct 38 out of 100
# Step 1012 Loss 1.0939399 Correct 39 out of 100
# Step 1013 Loss 1.1036458 Correct 35 out of 100
# ...
# Step 9671 Loss 0.19681308 Correct 93 out of 100
# Step 9672 Loss 0.24067023 Correct 89 out of 100
# Step 9673 Loss 0.27081582 Correct 88 out of 100
# Step 9674 Loss 0.18498322 Correct 95 out of 100
# Step 9675 Loss 0.23062213 Correct 91 out of 100
# Step 9676 Loss 0.31938422 Correct 86 out of 100
# Step 9677 Loss 0.22563314 Correct 92 out of 100
# Step 9678 Loss 0.21823612 Correct 94 out of 100
# Step 9679 Loss 0.21704099 Correct 93 out of 100
# Step 9680 Loss 0.21355686 Correct 91 out of 100
# Step 9681 Loss 0.3202938 Correct 89 out of 100
# Step 9682 Loss 0.18127143 Correct 96 out of 100
# Step 9683 Loss 0.17307994 Correct 95 out of 100
# Step 9684 Loss 0.24309781 Correct 91 out of 100
# Step 9685 Loss 0.27173802 Correct 90 out of 100
# Step 9686 Loss 0.29151493 Correct 89 out of 100
# Step 9687 Loss 0.31342527 Correct 88 out of 100
# Step 9688 Loss 0.18837762 Correct 94 out of 100
# Step 9689 Loss 0.2573225 Correct 92 out of 100
# Step 9690 Loss 0.22155748 Correct 92 out of 100
# Step 9691 Loss 0.28338975 Correct 94 out of 100
# Step 9692 Loss 0.19397473 Correct 92 out of 100
# Step 9693 Loss 0.26260218 Correct 88 out of 100
# Step 9694 Loss 0.2783598 Correct 91 out of 100
# Step 9695 Loss 0.30279166 Correct 87 out of 100
# Step 9696 Loss 0.20666893 Correct 94 out of 100
# Step 9697 Loss 0.24307941 Correct 89 out of 100
# Step 9698 Loss 0.2367957 Correct 93 out of 100
# Step 9699 Loss 0.28525895 Correct 90 out of 100
# Step 9700 Loss 0.22439086 Correct 91 out of 100
# Step 9701 Loss 0.27113435 Correct 93 out of 100
# Step 9702 Loss 0.3219173 Correct 88 out of 100
# Step 9703 Loss 0.3048484 Correct 88 out of 100
# Step 9704 Loss 0.21137123 Correct 91 out of 100
# Step 9705 Loss 0.32438973 Correct 88 out of 100
# Step 9706 Loss 0.15850261 Correct 96 out of 100
# Step 9707 Loss 0.32958156 Correct 89 out of 100
# Step 9708 Loss 0.22720365 Correct 89 out of 100
# Step 9709 Loss 0.23343867 Correct 89 out of 100
# Step 9710 Loss 0.2732772 Correct 87 out of 100
# Step 9711 Loss 0.25672492 Correct 91 out of 100
# Step 9712 Loss 0.24048649 Correct 94 out of 100
# Step 9713 Loss 0.23513079 Correct 90 out of 100
# Step 9714 Loss 0.3381945 Correct 85 out of 100
# Step 9715 Loss 0.19009659 Correct 94 out of 100
# Step 9716 Loss 0.23195274 Correct 91 out of 100
# Step 9717 Loss 0.12343928 Correct 96 out of 100
# Step 9718 Loss 0.24795173 Correct 90 out of 100
# Step 9719 Loss 0.2592731 Correct 94 out of 100
# Step 9720 Loss 0.2370787 Correct 92 out of 100
# Step 9721 Loss 0.42908219 Correct 88 out of 100
# Step 9722 Loss 0.2814671 Correct 87 out of 100
# Step 9723 Loss 0.4634481 Correct 82 out of 100
# Step 9724 Loss 0.17452303 Correct 93 out of 100
# Step 9725 Loss 0.18945022 Correct 92 out of 100
# Step 9726 Loss 0.20875116 Correct 93 out of 100
# Step 9727 Loss 0.30155522 Correct 87 out of 100
# Step 9728 Loss 0.16826047 Correct 95 out of 100
# Step 9729 Loss 0.36802813 Correct 90 out of 100
# Step 9730 Loss 0.26891246 Correct 93 out of 100
# Step 9731 Loss 0.26962313 Correct 93 out of 100
# Step 9732 Loss 0.2815696 Correct 89 out of 100
# Step 9733 Loss 0.1765562 Correct 94 out of 100
# Step 9734 Loss 0.21750519 Correct 93 out of 100
# Step 9735 Loss 0.17055474 Correct 96 out of 100
# Step 9736 Loss 0.29915145 Correct 90 out of 100
# Step 9737 Loss 0.28819013 Correct 86 out of 100
# Step 9738 Loss 0.25992885 Correct 88 out of 100
# Step 9739 Loss 0.2250803 Correct 92 out of 100
# Step 9740 Loss 0.26206324 Correct 90 out of 100
# Step 9741 Loss 0.29448116 Correct 91 out of 100
# Step 9742 Loss 0.22002651 Correct 92 out of 100
# Step 9743 Loss 0.29432485 Correct 87 out of 100
# Step 9744 Loss 0.29433483 Correct 90 out of 100
# Step 9745 Loss 0.33470112 Correct 87 out of 100
# Step 9746 Loss 0.19386238 Correct 93 out of 100
# Step 9747 Loss 0.2462915 Correct 91 out of 100
# Step 9748 Loss 0.27580968 Correct 93 out of 100
# Step 9749 Loss 0.28500736 Correct 90 out of 100
# Step 9750 Loss 0.18758333 Correct 95 out of 100
# Step 9751 Loss 0.24684352 Correct 90 out of 100
# Step 9752 Loss 0.23549339 Correct 94 out of 100
# Step 9753 Loss 0.18457752 Correct 91 out of 100
# Step 9754 Loss 0.10853193 Correct 97 out of 100
# Step 9755 Loss 0.19194409 Correct 93 out of 100
# Step 9756 Loss 0.25583804 Correct 88 out of 100
# Step 9757 Loss 0.23761348 Correct 91 out of 100
# Step 9758 Loss 0.15154447 Correct 93 out of 100
# Step 9759 Loss 0.18986626 Correct 94 out of 100
# Step 9760 Loss 0.17380115 Correct 92 out of 100
# Step 9761 Loss 0.29387078 Correct 89 out of 100
# Step 9762 Loss 0.17022228 Correct 95 out of 100
# Step 9763 Loss 0.18142533 Correct 92 out of 100
# Step 9764 Loss 0.27730402 Correct 90 out of 100
# Step 9765 Loss 0.23461296 Correct 94 out of 100
# Step 9766 Loss 0.28118405 Correct 90 out of 100
# Step 9767 Loss 0.185583 Correct 91 out of 100
# Step 9768 Loss 0.19618866 Correct 95 out of 100
# Step 9769 Loss 0.22832577 Correct 93 out of 100
# Step 9770 Loss 0.37534508 Correct 87 out of 100
# Step 9771 Loss 0.20594938 Correct 89 out of 100
# Step 9772 Loss 0.23446257 Correct 88 out of 100
# Step 9773 Loss 0.10349688 Correct 97 out of 100
# Step 9774 Loss 0.18727706 Correct 93 out of 100
# Step 9775 Loss 0.16383159 Correct 95 out of 100
# Step 9776 Loss 0.38501608 Correct 87 out of 100
# Step 9777 Loss 0.1483905 Correct 97 out of 100
# Step 9778 Loss 0.27182525 Correct 91 out of 100
# Step 9779 Loss 0.29385287 Correct 89 out of 100
# Step 9780 Loss 0.20860423 Correct 91 out of 100
# Step 9781 Loss 0.26957247 Correct 89 out of 100
# Step 9782 Loss 0.27950826 Correct 86 out of 100
# Step 9783 Loss 0.2277892 Correct 91 out of 100
# Step 9784 Loss 0.31644696 Correct 89 out of 100
# Step 9785 Loss 0.21618445 Correct 92 out of 100
# Step 9786 Loss 0.268085 Correct 89 out of 100
# Step 9787 Loss 0.281685 Correct 89 out of 100
# Step 9788 Loss 0.25996363 Correct 92 out of 100
# Step 9789 Loss 0.3967072 Correct 86 out of 100
# Step 9790 Loss 0.37250942 Correct 86 out of 100
# Step 9791 Loss 0.24613851 Correct 91 out of 100
# Step 9792 Loss 0.28328177 Correct 89 out of 100
# Step 9793 Loss 0.18029948 Correct 92 out of 100
# Step 9794 Loss 0.14712538 Correct 95 out of 100
# Step 9795 Loss 0.2359949 Correct 90 out of 100
# Step 9796 Loss 0.24825324 Correct 89 out of 100
# Step 9797 Loss 0.27801707 Correct 89 out of 100
# Step 9798 Loss 0.2251855 Correct 93 out of 100
# Step 9799 Loss 0.2935035 Correct 88 out of 100
# Step 9800 Loss 0.15683882 Correct 95 out of 100
# Step 9801 Loss 0.17816478 Correct 92 out of 100
# Step 9802 Loss 0.2688704 Correct 87 out of 100
# Step 9803 Loss 0.2992587 Correct 89 out of 100
# Step 9804 Loss 0.24469407 Correct 93 out of 100
# Step 9805 Loss 0.2415821 Correct 94 out of 100
# Step 9806 Loss 0.19242157 Correct 91 out of 100
# Step 9807 Loss 0.26687893 Correct 92 out of 100
# Step 9808 Loss 0.24624145 Correct 89 out of 100
# Step 9809 Loss 0.29988903 Correct 89 out of 100
# Step 9810 Loss 0.39932826 Correct 84 out of 100
# Step 9811 Loss 0.24387722 Correct 89 out of 100
# Step 9812 Loss 0.25841305 Correct 92 out of 100
# Step 9813 Loss 0.3066483 Correct 87 out of 100
# Step 9814 Loss 0.15830104 Correct 97 out of 100
# Step 9815 Loss 0.21987392 Correct 91 out of 100
# Step 9816 Loss 0.26208442 Correct 92 out of 100
# Step 9817 Loss 0.50392526 Correct 87 out of 100
# Step 9818 Loss 0.26731184 Correct 87 out of 100
# Step 9819 Loss 0.1779929 Correct 91 out of 100
# Step 9820 Loss 0.5068193 Correct 82 out of 100
# Step 9821 Loss 0.21163896 Correct 93 out of 100
# Step 9822 Loss 0.22642033 Correct 91 out of 100
# Step 9823 Loss 0.19969814 Correct 95 out of 100
# Step 9824 Loss 0.16579372 Correct 93 out of 100
# Step 9825 Loss 0.32031712 Correct 91 out of 100
# Step 9826 Loss 0.24663848 Correct 89 out of 100
# Step 9827 Loss 0.30050904 Correct 87 out of 100
# Step 9828 Loss 0.17008896 Correct 92 out of 100
# Step 9829 Loss 0.21675193 Correct 91 out of 100
# Step 9830 Loss 0.2710225 Correct 90 out of 100
# Step 9831 Loss 0.3184238 Correct 89 out of 100
# Step 9832 Loss 0.15543878 Correct 93 out of 100
# Step 9833 Loss 0.20355052 Correct 94 out of 100
# Step 9834 Loss 0.26234385 Correct 89 out of 100
# Step 9835 Loss 0.31913823 Correct 87 out of 100
# Step 9836 Loss 0.23599845 Correct 92 out of 100
# Step 9837 Loss 0.19532982 Correct 93 out of 100
# Step 9838 Loss 0.31858075 Correct 91 out of 100
# Step 9839 Loss 0.2645346 Correct 88 out of 100
# Step 9840 Loss 0.19986738 Correct 92 out of 100
# Step 9841 Loss 0.2384416 Correct 91 out of 100
# Step 9842 Loss 0.27816892 Correct 88 out of 100
# Step 9843 Loss 0.20619246 Correct 90 out of 100
# Step 9844 Loss 0.22300273 Correct 89 out of 100
# Step 9845 Loss 0.29122373 Correct 86 out of 100
# Step 9846 Loss 0.3734066 Correct 87 out of 100
# Step 9847 Loss 0.18263309 Correct 94 out of 100
# Step 9848 Loss 0.40655312 Correct 84 out of 100
# Step 9849 Loss 0.3205168 Correct 89 out of 100
# Step 9850 Loss 0.3103254 Correct 86 out of 100
# Step 9851 Loss 0.15607974 Correct 95 out of 100
# Step 9852 Loss 0.20374309 Correct 92 out of 100
# Step 9853 Loss 0.2680204 Correct 91 out of 100
# Step 9854 Loss 0.24967863 Correct 91 out of 100
# Step 9855 Loss 0.18858503 Correct 93 out of 100
# Step 9856 Loss 0.1614151 Correct 95 out of 100
# Step 9857 Loss 0.26476824 Correct 88 out of 100
# Step 9858 Loss 0.23556267 Correct 92 out of 100
# Step 9859 Loss 0.28324822 Correct 87 out of 100
# Step 9860 Loss 0.25254345 Correct 87 out of 100
# Step 9861 Loss 0.25634143 Correct 95 out of 100
# Step 9862 Loss 0.2819335 Correct 91 out of 100
# Step 9863 Loss 0.2992632 Correct 87 out of 100
# Step 9864 Loss 0.22935146 Correct 91 out of 100
# Step 9865 Loss 0.22252485 Correct 93 out of 100
# Step 9866 Loss 0.30566406 Correct 85 out of 100
# Step 9867 Loss 0.38679805 Correct 86 out of 100
# Step 9868 Loss 0.26750246 Correct 92 out of 100
# Step 9869 Loss 0.3799308 Correct 84 out of 100
# Step 9870 Loss 0.21082935 Correct 91 out of 100
# Step 9871 Loss 0.2604429 Correct 90 out of 100
# Step 9872 Loss 0.21220367 Correct 90 out of 100
# Step 9873 Loss 0.17759483 Correct 93 out of 100
# Step 9874 Loss 0.16395818 Correct 94 out of 100
# Step 9875 Loss 0.29118526 Correct 91 out of 100
# Step 9876 Loss 0.20012385 Correct 95 out of 100
# Step 9877 Loss 0.19584283 Correct 94 out of 100
# Step 9878 Loss 0.29414642 Correct 88 out of 100
# Step 9879 Loss 0.252391 Correct 89 out of 100
# Step 9880 Loss 0.18063241 Correct 93 out of 100
# Step 9881 Loss 0.13658342 Correct 97 out of 100
# Step 9882 Loss 0.30134803 Correct 83 out of 100
# Step 9883 Loss 0.29603675 Correct 90 out of 100
# Step 9884 Loss 0.20486274 Correct 91 out of 100
# Step 9885 Loss 0.30574253 Correct 85 out of 100
# Step 9886 Loss 0.19235706 Correct 92 out of 100
# Step 9887 Loss 0.2686012 Correct 94 out of 100
# Step 9888 Loss 0.301758 Correct 90 out of 100
# Step 9889 Loss 0.34632972 Correct 89 out of 100
# Step 9890 Loss 0.2142538 Correct 92 out of 100
# Step 9891 Loss 0.25068188 Correct 91 out of 100
# Step 9892 Loss 0.21602783 Correct 89 out of 100
# Step 9893 Loss 0.22532527 Correct 95 out of 100
# Step 9894 Loss 0.22264034 Correct 89 out of 100
# Step 9895 Loss 0.18243323 Correct 94 out of 100
# Step 9896 Loss 0.18797149 Correct 92 out of 100
# Step 9897 Loss 0.3193422 Correct 89 out of 100
# Step 9898 Loss 0.20494604 Correct 92 out of 100
# Step 9899 Loss 0.26552677 Correct 93 out of 100
# Step 9900 Loss 0.45412147 Correct 81 out of 100
# Step 9901 Loss 0.3742958 Correct 80 out of 100
# Step 9902 Loss 0.23873775 Correct 92 out of 100
# Step 9903 Loss 0.46846664 Correct 81 out of 100
# Step 9904 Loss 0.33565974 Correct 86 out of 100
# Step 9905 Loss 0.44805166 Correct 82 out of 100
# Step 9906 Loss 0.35256088 Correct 87 out of 100
# Step 9907 Loss 0.21101268 Correct 92 out of 100
# Step 9908 Loss 0.32092574 Correct 88 out of 100
# Step 9909 Loss 0.39012396 Correct 87 out of 100
# Step 9910 Loss 0.24820468 Correct 91 out of 100
# Step 9911 Loss 0.23461501 Correct 92 out of 100
# Step 9912 Loss 0.4276585 Correct 82 out of 100
# Step 9913 Loss 0.29732522 Correct 90 out of 100
# Step 9914 Loss 0.41202486 Correct 85 out of 100
# Step 9915 Loss 0.45044035 Correct 83 out of 100
# Step 9916 Loss 0.20642124 Correct 92 out of 100
# Step 9917 Loss 0.32512146 Correct 86 out of 100
# Step 9918 Loss 0.2448854 Correct 89 out of 100
# Step 9919 Loss 0.27328834 Correct 88 out of 100
# Step 9920 Loss 0.2585301 Correct 89 out of 100
# Step 9921 Loss 0.2970097 Correct 90 out of 100
# Step 9922 Loss 0.32759774 Correct 87 out of 100
# Step 9923 Loss 0.18599804 Correct 93 out of 100
# Step 9924 Loss 0.2628947 Correct 91 out of 100
# Step 9925 Loss 0.29831913 Correct 90 out of 100
# Step 9926 Loss 0.36483082 Correct 85 out of 100
# Step 9927 Loss 0.42193726 Correct 84 out of 100
# Step 9928 Loss 0.31523773 Correct 90 out of 100
# Step 9929 Loss 0.32215545 Correct 91 out of 100
# Step 9930 Loss 0.2927283 Correct 90 out of 100
# Step 9931 Loss 0.28193212 Correct 89 out of 100
# Step 9932 Loss 0.13484001 Correct 95 out of 100
# Step 9933 Loss 0.31238326 Correct 89 out of 100
# Step 9934 Loss 0.2750188 Correct 92 out of 100
# Step 9935 Loss 0.23802964 Correct 89 out of 100
# Step 9936 Loss 0.39044258 Correct 90 out of 100
# Step 9937 Loss 0.29340655 Correct 88 out of 100
# Step 9938 Loss 0.40486017 Correct 85 out of 100
# Step 9939 Loss 0.28327042 Correct 90 out of 100
# Step 9940 Loss 0.18625076 Correct 96 out of 100
# Step 9941 Loss 0.23012604 Correct 92 out of 100
# Step 9942 Loss 0.26412806 Correct 88 out of 100
# Step 9943 Loss 0.21852857 Correct 90 out of 100
# Step 9944 Loss 0.28152803 Correct 89 out of 100
# Step 9945 Loss 0.25376168 Correct 91 out of 100
# Step 9946 Loss 0.2636145 Correct 93 out of 100
# Step 9947 Loss 0.2463942 Correct 87 out of 100
# Step 9948 Loss 0.36310953 Correct 88 out of 100
# Step 9949 Loss 0.19292215 Correct 94 out of 100
# Step 9950 Loss 0.21028182 Correct 95 out of 100
# Step 9951 Loss 0.24402572 Correct 92 out of 100
# Step 9952 Loss 0.29444098 Correct 92 out of 100
# Step 9953 Loss 0.20904517 Correct 91 out of 100
# Step 9954 Loss 0.16574603 Correct 95 out of 100
# Step 9955 Loss 0.28950903 Correct 90 out of 100
# Step 9956 Loss 0.21505329 Correct 94 out of 100
# Step 9957 Loss 0.20795843 Correct 94 out of 100
# Step 9958 Loss 0.29748595 Correct 90 out of 100
# Step 9959 Loss 0.18615623 Correct 96 out of 100
# Step 9960 Loss 0.28534046 Correct 92 out of 100
# Step 9961 Loss 0.24567913 Correct 90 out of 100
# Step 9962 Loss 0.24377666 Correct 85 out of 100
# Step 9963 Loss 0.25275046 Correct 89 out of 100
# Step 9964 Loss 0.21578199 Correct 93 out of 100
# Step 9965 Loss 0.3214421 Correct 85 out of 100
# Step 9966 Loss 0.316352 Correct 89 out of 100
# Step 9967 Loss 0.1978927 Correct 92 out of 100
# Step 9968 Loss 0.23578842 Correct 89 out of 100
# Step 9969 Loss 0.18927944 Correct 91 out of 100
# Step 9970 Loss 0.17611499 Correct 92 out of 100
# Step 9971 Loss 0.26139224 Correct 87 out of 100
# Step 9972 Loss 0.256809 Correct 91 out of 100
# Step 9973 Loss 0.22864547 Correct 92 out of 100
# Step 9974 Loss 0.31845313 Correct 91 out of 100
# Step 9975 Loss 0.20904347 Correct 94 out of 100
# Step 9976 Loss 0.19006431 Correct 93 out of 100
# Step 9977 Loss 0.42627594 Correct 86 out of 100
# Step 9978 Loss 0.26243284 Correct 94 out of 100
# Step 9979 Loss 0.26322204 Correct 90 out of 100
# Step 9980 Loss 0.22832264 Correct 92 out of 100
# Step 9981 Loss 0.1980749 Correct 91 out of 100
# Step 9982 Loss 0.2588394 Correct 88 out of 100
# Step 9983 Loss 0.1595338 Correct 95 out of 100
# Step 9984 Loss 0.21845971 Correct 92 out of 100
# Step 9985 Loss 0.25823995 Correct 91 out of 100
# Step 9986 Loss 0.20452301 Correct 90 out of 100
# Step 9987 Loss 0.20386887 Correct 92 out of 100
# Step 9988 Loss 0.15459238 Correct 94 out of 100
# Step 9989 Loss 0.11890478 Correct 96 out of 100
# Step 9990 Loss 0.22700427 Correct 92 out of 100
# Step 9991 Loss 0.24397296 Correct 91 out of 100
# Step 9992 Loss 0.15112437 Correct 94 out of 100
# Step 9993 Loss 0.19337499 Correct 92 out of 100
# Step 9994 Loss 0.42100665 Correct 84 out of 100
# Step 9995 Loss 0.27576557 Correct 89 out of 100
# Step 9996 Loss 0.15610091 Correct 97 out of 100
# Step 9997 Loss 0.20152704 Correct 90 out of 100
# Step 9998 Loss 0.21657597 Correct 91 out of 100
# Step 9999 Loss 0.23623408 Correct 91 out of 100
# 2021-12-06 21:33:12.865154: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Loss for 3000 randomly chosen documents is  0.3585411608219147  number of correct labels is  2700  out of 3000
